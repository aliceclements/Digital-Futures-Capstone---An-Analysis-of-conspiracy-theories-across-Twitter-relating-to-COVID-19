# %% [markdown]
# #Data Loading and Cleaning

# %% [markdown]
# ## Downloads

# %%
# imports
import os
import itertools
import collections
from collections import Counter
import re
import numpy as np
import config

import tweepy as tw
import pandas as pd
import string

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

import nltk 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import LancasterStemmer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# download stopwords, punkt and wordnet packages
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# API key
api_key = config.api_key
secret = config.secret

# %%
auth = tw.AppAuthHandler(api_key, secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ## Define the Key Search Terms

# %%
# define hashtag search terms
# NB: they are case sensitive
search_coronavirus = '#coronavirus'
search_covid = '#covid'
search_covid19 = '#covid19'
search_virus = '#virus'
search_vaccine = '#vaccine'
search_pandemic = '#pandemic'

# # Other Options to search
# search_vaccine = '#vaccine'
# search_vaccinated = '#vaccinated'
# search_vaccination = '#vaccination'
# search_jab = '#jab'
# search_pfizer = '#pfizer'
# search_astrazeneca = '#astrazeneca'
# search_moderna = '#moderna'

# %% [markdown]
# ## Functions

# %%
# REGEX function
def regex_clean(txt, regex):
    """Replace any text matching the regex

    Parameters
    ----------
    txt : string
        A text string that you want to parse and remove matches
    regex : string 
        A text string of the regex pattern you want to match

    Returns
    -------
    The same txt string with the matches removes
    """

    return " ".join(re.sub(regex, "", txt).split())

# %%
## lemmatize tweet
lemmatizer = WordNetLemmatizer()
stpwrd = nltk.corpus.stopwords.words('english')
stpwrd.extend(string.punctuation)

def lemmatize_data(n):
    """Cleans up a review!
    
    Parameters
    ------------
    review: string
      A text string that you want to parse and remove matches

    Returns
    ----------
    Cleaned up string - tokenise and stemmed!
    """

    ## Pre Token Cleaning - Stuff that applies to a string.
    
    n = n.lower() 
    n = regex_clean(n, r'\s\d+\s')

    ## Go-Go-Token-Rangers
    n = word_tokenize(n)

    ## Post Token Cleaning - Stuff that applies to a list 
        
    n = [lemmatizer.lemmatize(word) for word in n]
    n = [lemmatizer.lemmatize(word) for word in n if word not in stpwrd]
    
    return n

# %%
# stem tweet
p_stemmer = PorterStemmer()

def stem_data(n):
    """Cleans up a review!
    
    Parameters
    ------------
    review: string
      A text string that you want to parse and remove matches

    Returns
    ----------
    Cleaned up string - tokenise and stemmed!
    """

    ## Pre Token Cleaning - Stuff that applies to a string.
    
    n = n.lower() 
    n = regex_clean(n, r'\s\d+\s')

    ## Go-Go-Token-Rangers
    n = word_tokenize(n)

    ## Post Token Cleaning - Stuff that applies to a list 
        
    n = [p_stemmer.stem(word) for word in n]
    n = [p_stemmer.stem(word) for word in n if word not in stpwrd]
    
    return n

# %%
# lancaster stem tweet
def lanc_stemmed(df):
    """Cleans up answers!
    
    Parameters
    ------------
    review: string
      A text string that you want to parse and remove matches

    Returns
    ----------
    Cleaned up string - split and stemmed!
    """

    df['split'] = df['cleaned'].apply(lambda x: str(x).lower())
    
    df['split'] = df.split
    df['split'].replace('^[0-9]+$','',inplace=True)
    
    for punc in string.punctuation:
        df['split'] = df.split.str.replace(punc,'')
        
        
    df['split'] = df['split'].apply(lambda x: [item for item in str(x).split() if item not in stopwords.words('english')])
    df['split'] = df['split'].apply(lambda x: [LancasterStemmer().stem(a) for a in x])

    return df

# %%
# remove emojis from the text
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F" # emoticons
                           u"\U0001F300-\U0001F5FF" # symbols & pictographs
                           u"\U0001F680-\U0001F6FF" # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF" # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %% [markdown]
# # Dataframes Cleaned and Saved

# %% [markdown]
# ## Coronavirus Dataframe Cleaned and Saved

# %%
## call a cursor item in the twitter library
# use api search
# this item generator collects 1000 items and if we loop through it we can collect all 1000 of our tweets in a dataframe
######### SORT DATES
tweets_coronavirus = tw.Cursor(api.search,
                   q = search_coronavirus,
                   lang ='en',
                   fromDate = '202002010000',
                   toDate = '202118060000',
                   tweet_mode = 'extended',
                   min_retweets = 50,
                   result_type = 'mixed').items(1000)

tweets_coronavirus

# %%
# create dataframe
tweet_coronavirus = pd.DataFrame(data=[[tweet.full_text, tweet.user.screen_name, tweet.user.location, tweet.created_at, tweet.id, tweet.source, tweet.favorite_count, tweet.retweet_count, len(tweet.full_text)]for tweet in tweets_coronavirus])

# %%
# rename dataframe columns
tweet_coronavirus.columns = ['tweet', 'user', 'location', 'date', 'id', 'source', 'favourites', 'retweets', 'tweet_length']

# %%
# find all hashtags
tweet_coronavirus['hashtag'] = tweet_coronavirus['tweet'].apply(lambda x: re.findall(r"#(\w+)", x))

# %%
# clean tweet
tweet_coronavirus['cleaned'] = tweet_coronavirus['tweet'].apply(str.lower)

regex_to_clean = ['(@.+?)\s',
                  '\s\d+\s']

for reg in regex_to_clean:
  tweet_coronavirus['cleaned'] = tweet_coronavirus['cleaned'].apply(regex_clean, regex=reg)
  tweet_coronavirus['cleaned'] = tweet_coronavirus['cleaned'].apply(remove_emoji)

# %%
# tokenize tweet
tweet_coronavirus['tokens'] = tweet_coronavirus['cleaned'].apply(word_tokenize)

# %%
# lemmatize tweet
tweet_coronavirus['lemmatized'] = tweet_coronavirus['cleaned'].apply(lemmatize_data)

# %%
# stem tweet
tweet_coronavirus['stemmed'] = tweet_coronavirus['cleaned'].apply(lemmatize_data)

# %%
# lancaster stem tweet
tweet_coronavirus = lanc_stemmed(tweet_coronavirus)

# %%
#explore datatypes
tweet_coronavirus.dtypes
# Out:
# tweet                   object
# user                    object
# location                object
# date            datetime64[ns]
# id                       int64
# source                  object
# favourites               int64
# retweets                 int64
# tweet_length             int64
# hashtag                 object
# cleaned                 object
# tokens                  object
# lemmatized              object
# stemmed                 object
# split                   object
# dtype: object

# %%
tweet_coronavirus
# Out:
#                                                  tweet  ...                                              split
# 0    New daily cases &amp; deaths of #coronavirus i...  ...  [new, dai, cas, amp, death, coronavir, gaz, ev...
# 1    #coronavirus   I’m feeling emotionally very fr...  ...  [coronavir, i’m, feel, emot, frail, breakthrou...
# 2    Communist China produced a very inferior vacci...  ...  [commun, chin, produc, infery, vaccin, distrib...
# 3    RT @CoronaRecovery: 303044 people recovered fr...  ...  [rtpeople, recov, coron, today, tot, coron, vi...
# 4    303044 people recovered from Corona today. Tot...  ...  [303044, peopl, recov, coron, today, tot, coro...
# ..                                                 ...  ...                                                ...
# 995  Motto of the story: Don't trust #China #corona...  ...  [motto, story, dont, trust, chin, coronavir, h...
# 996  🚨 27 people died of #COVID19 in the #UK in the...  ...  [peopl, died, covid19, uk, pasthr, bring, tot,...
# 997  Get the #vaccine dumbass;\n\n A #coronavirus o...  ...  [get, vaccin, dumbass, coronavir, outbreak, hi...
# 998  RT @IndiaToday: Experts have said that the #De...  ...  [rt, expert, said, deltaplusv, could, evad, va...
# 999  Daily #COVID19 watch as reported by World Mete...  ...  [dai, covid19, watch, report, world, met, coro...
#
# [1000 rows x 15 columns]

# %%
#save dataframe to csv
from google.colab import files
tweet_coronavirus.to_csv('tweet_coronavirus.csv')
files.download("tweet_coronavirus.csv")

# %% [markdown]
# ## Covid Dataframe Cleaned and Saved

# %%
tweets_covid = tw.Cursor(api.search,
                   q = search_covid,
                   lang ='en',
                   fromDate = '2020/02/01',
                   toDate = '2020/12/31',
                   tweet_mode = 'extended',
                   min_retweets = 50,
                   result_type = 'mixed').items(1000)

tweets_covid

# %%
tweet_covid = pd.DataFrame(data=[[tweet.full_text, tweet.user.screen_name, tweet.user.location, tweet.created_at, tweet.id, tweet.source, tweet.favorite_count, tweet.retweet_count, len(tweet.full_text)]for tweet in tweets_covid])

# %%
tweet_covid.columns = ['tweet', 'user', 'location', 'date', 'id', 'source', 'favourites', 'retweets', 'tweet_length']

# %%
def tweet_cleaning(df):
    df['hashtag'] = df['tweet'].apply(lambda x: re.findall(r"#(\w+)", x))
    df['cleaned'] = df['tweet'].apply(str.lower)
  
    regex_to_clean = ['(@.+?)\s',
                      '\s\d+\s']
    for reg in regex_to_clean:
        df['cleaned'] = df['cleaned'].apply(regex_clean, regex=reg)
        df['cleaned'] = df['cleaned'].apply(remove_emoji)
    
    df['tokens'] = df['cleaned'].apply(word_tokenize)
    df['lemmatized'] = df['cleaned'].apply(lemmatize_data)
    df['stemmed'] = df['cleaned'].apply(lemmatize_data)
    df = lanc_stemmed(df)

    return df

# %%
tweet_covid = tweet_cleaning(tweet_covid)
tweet_covid
# Out:
#                                                  tweet  ...                                              split
# 0    I’m re-reading Jacques Ellul’s classic “Propag...  ...  [i’m, reread, jacqu, ellul’s, class, “propagan...
# 1    Who rewrote their #Covid vaccine recommendatio...  ...  [rewrot, covid, vaccin, recommend, get, caught...
# 2    70% of @KingCountyWA residents 12+ have now co...  ...  [70, resid, 12, complet, covid, vaccin, series...
# 3    RT @HackneyCarers: ➡️ Have you had your first ...  ...  [rt, first, dos, astrazenec, covid19, vaccin, ...
# 4    RT @pravenovice: Totally safe bro #covid #vacc...  ...  [rt, tot, saf, bro, covid, vaccin, httpstconby...
# ..                                                 ...  ...                                                ...
# 995  RT @DavidHarrisAJC: When I wonder how long we’...  ...  [rt, wond, long, we’ll, covid, lockdown, think...
# 996  RT @AlexBerenson: THREAD\n\n19-year-old Simone...  ...  [rt, thread, 19yearold, simon, scot, excit, ge...
# 997  RT @chiefsforchange: CFC member @SchwinnTeach ...  ...  [rt, cfc, memb, say, covid, recovery, work, gr...
# 998  RT @_lokeshsharma: #Rajasthan #CoronaUpdate\n\...  ...  [rt, rajasth, coronaupdatecovid, cas, report, ...
# 999  RT @AlexBerenson: So are @youtube and @faceboo...  ...  [rt, gonn, cens, disinform, recommend, on, und...
#
# [1000 rows x 15 columns]

# %%
# save to new csv
from google.colab import files
tweet_covid.to_csv('tweet_covid.csv')
files.download("tweet_covid.csv")

# %% [markdown]
# ## Covid19 Dataframe Cleaned and Saved

# %%
tweets_covid19 = tw.Cursor(api.search,
                   q = search_covid19,
                   lang ='en',
                   fromDate = '2020/02/01',
                   toDate = '2020/12/31',
                   tweet_mode = 'extended',
                   min_retweets = 50,
                   result_type = 'mixed').items(1000)

tweets_covid19

# %%
tweet_covid19 = pd.DataFrame(data=[[tweet.full_text, tweet.user.screen_name, tweet.user.location, tweet.created_at, tweet.id, tweet.source, tweet.favorite_count, tweet.retweet_count, len(tweet.full_text)]for tweet in tweets_covid19])

# %%
tweet_covid19.columns = ['tweet', 'user', 'location', 'date', 'id', 'source', 'favourites', 'retweets', 'tweet_length']

# %%
tweet_covid19 = tweet_cleaning(tweet_covid19)
tweet_covid19
# Out:
#                                                  tweet  ...                                              split
# 0    Terkini. 23 Jun. Kes baharu hari ini 5️⃣2️⃣4️⃣...  ...  [terkinijun, kes, baharu, har, in, 5⃣2⃣4⃣4⃣, c...
# 1    The idea behind our White Paper report on #COV...  ...  [ide, behind, whit, pap, report, covid19, prov...
# 2    Terkini. 22 Jun. Kes baharu hari ini 4️⃣7️⃣4️⃣...  ...  [terkinijun, kes, baharu, har, in, 4⃣7⃣4⃣3⃣, c...
# 3    RT @kawataru_j: Tokyo reported 619 / 6,773 (Av...  ...  [rt, tokyo, report, 6773, av, numb, pcr, test,...
# 4    RT @KrishnanAmrish: I have been waiting for a ...  ...  [rt, wait, journ, ask, typ, quest, covid19, fi...
# ..                                                 ...  ...                                                ...
# 995  Reports suggest that the Republic of #Congo ha...  ...  [report, suggest, republ, congo, success, requ...
# 996  RT @WorldBank: Why is vaccination critical for...  ...  [rt, vaccin, crit, country, econom, recovery, ...
# 997  RT @COVIDNewsByMIB: #IndiaFightsCorona:\n\n📍𝑴𝒐...  ...      [rt, indiafightscoron, 8616373, togeth, can…]
# 998  RT @earth_yug: Scientists have found that 414 ...  ...  [rt, sci, found, thatmil, plast, wast, item, w...
# 999  Movements between districts and to or from the...  ...  [mov, district, capit, kigal, froz, direct, re...
#
# [1000 rows x 15 columns]

# %%
# save to new csv
from google.colab import files
tweet_covid19.to_csv('tweet_covid19.csv')
files.download("tweet_covid19.csv")

# %% [markdown]
# ## Virus Dataframe Cleaned and Saved

# %%
tweets_virus = tw.Cursor(api.search,
                   q = search_virus,
                   lang ='en',
                   fromDate = '2020/02/01',
                   toDate = '2020/12/31',
                   tweet_mode = 'extended',
                   min_retweets = 50,
                   result_type = 'mixed').items(1000)

tweets_virus

# %%
tweet_virus = pd.DataFrame(data=[[tweet.full_text, tweet.user.screen_name, tweet.user.location, tweet.created_at, tweet.id, tweet.source, tweet.favorite_count, tweet.retweet_count, len(tweet.full_text)]for tweet in tweets_virus])

# %%
tweet_virus.columns = ['tweet', 'user', 'location', 'date', 'id', 'source', 'favourites', 'retweets', 'tweet_length']

# %%
tweet_virus = tweet_cleaning(tweet_virus)
tweet_virus
# Out:
#                                                  tweet  ...                                              split
# 0    🦠 The #COVID19 pandemic continues to worry pub...  ...  [🦠, covid19, pandem, continu, worry, publ, hea...
# 1    #Mosquitoes infected with the West Nile Fever ...  ...  [mosquito, infect, west, nil, fev, vir, found,...
# 2    RT @DrSusanNasif: #vQuiz\nNAME THE #VIRUS🤓\n \...  ...  [rt, vqu, nam, virus🤓, est, lifelong, lat, asy...
# 3    Drs. Tom &amp; Andy EXPOSE the PSEUDOSCIENCE o...  ...  [drs, tom, amp, andy, expos, pseudoscy, vir, m...
# 4    RT @TerryTyler4: July 26th, 2024: the day the ...  ...  [rt, july, 26th, 2024, day, world, chang, fore...
# ..                                                 ...  ...                                                ...
# 995  Played #Virus 6 times  on 2021-06-20  https://...  ...  [play, virustim, 20210620, httpstcoxfl35tqyl3,...
# 996  RT @PanguF: Section II \n（2/5）attack between t...  ...  [rt, sect, ii, 25attack, end, sum, begin, fal,...
# 997  UK Scientists Warn of ‘Miserable Winter’ Due t...  ...  [uk, sci, warn, ‘miserable, winter’, due, new,...
# 998  RT @sunitanar: In the deadly race between the ...  ...  [rt, dead, rac, vir, vary, vaccin, pric, deter...
# 999  #ThirdWave Inevitable, Could hit India in 6 to...  ...  [thirdwav, inevit, could, hit, ind, intoweek, ...
#
# [1000 rows x 15 columns]

# %%
# save to new csv
from google.colab import files
tweet_virus.to_csv('tweet_virus.csv')
files.download("tweet_virus.csv")

# %% [markdown]
# ## Vaccine Dataframe Cleaned and Saved

# %%
tweets_vaccine = tw.Cursor(api.search,
                   q = search_vaccine,
                   lang ='en',
                   fromDate = '2020/02/01',
                   toDate = '2020/12/31',
                   tweet_mode = 'extended',
                   min_retweets = 50,
                   result_type = 'mixed').items(1000)

tweets_vaccine

# %%
tweet_vaccine = pd.DataFrame(data=[[tweet.full_text, tweet.user.screen_name, tweet.user.location, tweet.created_at, tweet.id, tweet.source, tweet.favorite_count, tweet.retweet_count, len(tweet.full_text)]for tweet in tweets_vaccine])

# %%
tweet_vaccine.columns = ['tweet', 'user', 'location', 'date', 'id', 'source', 'favourites', 'retweets', 'tweet_length']

# %%
tweet_vaccine = tweet_cleaning(tweet_vaccine)
tweet_vaccine
# Out:
#                                                  tweet  ...                                              split
# 0    #Twitter locked the account of conservative-le...  ...  [twit, lock, account, conservativel, new, webs...
# 1    Another big #vaccine day. Over 5.2 Million dos...  ...  [anoth, big, vaccin, day, 52, mil, dos, atpm, ...
# 2    These are the only #vaccine numbers we should ...  ...  [vaccin, numb, focus, vaccin, start, dat, jant...
# 3    #VladimirPutin may come in from the cold.\n\nA...  ...  [vladimirputin, may, com, cold, afric, fac, th...
# 4    RT @PHE_uk: The #COVID19 Dashboard has been up...  ...  [rt, covid19, dashboard, upd, httpstcoxhspoytg...
# ..                                                 ...  ...                                                ...
# 995  RT @ArmonaiteA: #Lithuania will share 20K Astr...  ...  [rt, lithuan, shar, 20k, astrazenec, vaccin, d...
# 996  Christian living today is absorbed from the #v...  ...  [christian, liv, today, absorb, vir, vaccin, p...
# 997  RT @21WIRE: The myth of the 'asymptomatic spre...  ...  [rt, myth, asymptom, spread, amp, asymptom, su...
# 998  RT @ArmonaiteA: #Lithuania will share 20K Astr...  ...  [rt, lithuan, shar, 20k, astrazenec, vaccin, d...
# 999  RT @sri50: Just in  #Covaxin the #Indian #COVI...  ...  [rt, covaxin, ind, covid19, vaccin, show, 778,...
#
# [1000 rows x 15 columns]

# %%
# save to new csv
from google.colab import files
tweet_vaccine.to_csv('tweet_vaccine.csv')
files.download("tweet_vaccine.csv")

# %% [markdown]
# ## Pandemic Dataframe Cleaned and Saved

# %%
tweets_pandemic = tw.Cursor(api.search,
                   q = search_pandemic,
                   lang ='en',
                   fromDate = '2020/02/01',
                   toDate = '2020/12/31',
                   tweet_mode = 'extended',
                   min_retweets = 50,
                   result_type = 'mixed').items(1000)

tweets_pandemic

# %%
tweet_pandemic = pd.DataFrame(data=[[tweet.full_text, tweet.user.screen_name, tweet.user.location, tweet.created_at, tweet.id, tweet.source, tweet.favorite_count, tweet.retweet_count, len(tweet.full_text)]for tweet in tweets_pandemic])

# %%
tweet_pandemic.columns = ['tweet', 'user', 'location', 'date', 'id', 'source', 'favourites', 'retweets', 'tweet_length']

# %%
tweet_pandemic = tweet_cleaning(tweet_pandemic)
tweet_pandemic
# Out:
#                                                  tweet  ...                                              split
# 0    On #TravelDayOfAction, I will join the industr...  ...  [traveldayofact, join, industry, speakupfortra...
# 1    Govt led by Hon'ble PM Sh @narendramodi Ji is ...  ...  [govt, led, honbl, pm, sh, ji, receiv, constru...
# 2    The 🇫🇷🇮🇳🇦🇺 trilateral dialogue now expands to ...  ...  [tril, dialog, expand, g20, coordin, today, se...
# 3    @crypto A First Wave-The Emergence. Pandemic R...  ...  [first, waveth, emerg, pandem, rom, shelby, si...
# 4    RT @ResearchSleep: A study of twins led by Was...  ...  [rt, study, twin, led, washington, stat, unive...
# ..                                                 ...  ...                                                ...
# 995  RT @frontline_india: Before the #pandemic, int...  ...  [rt, pandem, int, intracountry, ineq, intol, d...
# 996  RT @frontline_india: Before the #pandemic, int...  ...  [rt, pandem, int, intracountry, ineq, intol, d...
# 997  RT @Robyn_Grote: Shocking apparently  #legal #...  ...  [rt, shock, app, leg, ag, discrimin, ndi, also...
# 998  RT @ThinkCREA: The #pandemic expedited CREA’s ...  ...  [rt, pandem, expedit, crea’s, ongo, transform,...
# 999  RT @Article14live: 6 men accused of killing Ju...  ...  [rtmen, accus, kil, junaid, 15, trainyr, ago, ...
#
# [1000 rows x 15 columns]

# %%
# save to new csv
from google.colab import files
tweet_pandemic.to_csv('tweet_pandemic.csv')
files.download("tweet_pandemic.csv")

# %% [markdown]
# ## TO DO

# %% [markdown]
# To DO:
# 1. Load Seperate Datasets: coronavirus, covid, covid19, pandemic, virus
# 2. Save these Datasets to individual files
# 3. Clean the data: - remove stopwords, remove punctuation, make new column for hashtags,
# 4. Explore all retweets: date and location
# 5. Identify hashtags that are indicative of conspiracy theories: make word cloud of these hashtags e.g. anti semitism, anti-chinese rhetoric, bat soup, general cover up, 5G
# 6. Isolate the tweets that have these hashtags and explore
# 7. conspiracies, hate speech and incitement to violence
# 8. group according to 5g, anti-chinese rhetoric, anti-semitic etc.. and have time series graph

# %% [markdown]
# #Hashtag EDA

# %% [markdown]
# ## Hashtag EDA Coronvairus

# %%
# Create List with all hashtags in
def hashtags(df):

    hashtag_list = []

    for item in df:
        for value in item:
            hashtag_list.append(value)

    return hashtag_list

# %%
hashtags_list = hashtags(tweet_coronavirus.hashtag)

# %%
# convert all hashtags to lowercase to help filter duplicates
def lowercase(list):
    for i in range(len(list)):
        list[i] = list[i].lower()

    return list

# %%
hashtags_list = lowercase(hashtags_list)
hashtags_list
# Out:
# ['coronavirus',
#  'gaza',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'staysafe',
#  'covid19',
#  'covidvaccine',
#  'deltavariant',
#  'vaccineswork',
#  'vaccinated',
#  'healthcare',
#  'coronavirus',
#  'coronavirus',
#  'immunology',
#  'breakingne',
#  'coronavirus',
#  'sandrasturm',
#  'fu',
#  'coronavirus',
#  'fun',
#  'love',
#  'b1010',
#  'dvd',
#  'v',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'covid19',
#  'sierraleone',
#  'pandemic',
#  'positive',
#  'covid',
#  'coronavirus',
#  'covid19',
#  'covid_19',
#  'covid19',
#  'coronavirus',
#  'breaking',
#  'covid19',
#  'jeffzients',
#  'coronavirus',
#  'coronavirus',
#  'oxygenexpress',
#  'train',
#  'jamnagar',
#  'oxygen',
#  'rahulgandhi',
#  'covid19',
#  'asia',
#  'covid19',
#  'coronavirus',
#  'corona',
#  'covid19nsw',
#  'covidvaccination',
#  'vaccine',
#  'vaccineforall',
#  'coronavirusupdates',
#  'ravishkumar',
#  'godimedia',
#  'coronavirus',
#  'britain',
#  'brexit',
#  'borishasfailedbritain',
#  'borisjohnson',
#  'loc',
#  'massachusetts',
#  'coronavirus',
#  'vaccinated',
#  'amazon',
#  'primeday',
#  'numerator',
#  'stockmarketnews',
#  'shoppingevent',
#  'adobe',
#  'coronavirus',
#  'coronavirus',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'covid',
#  'covid19',
#  'coronavirus',
#  'endthelockdown',
#  'lockdownsmustend',
#  'coronavirus',
#  'iran',
#  'breaking',
#  'covid19',
#  'jeffzients',
#  'coronavirus',
#  'madhyapradesh',
#  'covid19',
#  'coronavirus',
#  '22jun2021',
#  'mpfightscorona',
#  'coronavirusupdates',
#  'vaccine',
#  'businesses',
#  'coronavirus',
#  'breaking',
#  'covid19',
#  'jeffzients',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'sarscov2',
#  'coronavirus',
#  'level5',
#  'scotland',
#  'coronavirus',
#  'britain',
#  'brexit',
#  'borishasfailedbritain',
#  'borisjohnson',
#  'lockdown',
#  'covid19',
#  'covid19uk',
#  'voteofnoconfidence',
#  'staythefhome',
#  'covid',
#  'covid19',
#  'coronavirus',
#  'covid_19',
#  'coronavirus',
#  'covid19',
#  'covidvaccination',
#  'wakeup',
#  'covid19',
#  'coronavirus',
#  'لعبة_الأمم',
#  'nationesgame',
#  'antivaccine',
#  'antivaxx',
#  'antivaccinepas',
#  'endgainoffunctionfunding',
#  'coronavirus',
#  'nih',
#  'coronavirus',
#  'suriya',
#  'coronavirus',
#  'india',
#  'covid19',
#  'vaccines',
#  'coronavirus',
#  'tmc',
#  'saudiarabia',
#  'covid',
#  'breaking',
#  'covid19',
#  'jeffzients',
#  'coronavirus',
#  'philippine',
#  'rodrigoduterte',
#  'coronavirus',
#  'suriya',
#  'china',
#  'cor',
#  'vaccine',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'india',
#  'covid19',
#  'vaccines',
#  'covid19',
#  'coronavirus',
#  'stayhome',
#  'recoveryloanscheme',
#  'rls',
#  'coronavirus',
#  'covid',
#  'pandemic',
#  'recovery',
#  'business',
#  'coronavirus',
#  'coronavirus',
#  'suriya',
#  'breaking',
#  'covid19',
#  'jeffzients',
#  'coronavirus',
#  'politics',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'iran',
#  'coronavirus',
#  'wpro',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'palestinian',
#  'israel',
#  'coronavirus',
#  'iran',
#  'suriya',
#  'coronavirus',
#  'coronavirus',
#  'newnormal',
#  'marketing',
#  'abdala',
#  'coronavirus',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'countydurham',
#  'coronavirus',
#  'india',
#  'covid19',
#  'vaccines',
#  'vaccine',
#  'largestvaccinedrive',
#  'indiafightscorona',
#  'coronavirus',
#  'corona',
#  'kbkinfographics',
#  'coronavirus',
#  'saudiarabia',
#  'vaccine',
#  'covid',
#  'covid19',
#  'corona',
#  'coronavirus',
#  'cyprus',
#  'coronavirus',
#  'covid19',
#  'assam',
#  'corona',
#  'china',
#  'cor',
#  'suriya',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'art',
#  'prints',
#  'awesome',
#  'lipreading',
#  'lipreaders',
#  'hardofhearing',
#  'hearingloss',
#  'gifts',
#  'covid_19',
#  'covid',
#  'china',
#  'cor',
#  'mask',
#  'deaf',
#  'deaf',
#  'hardofhearing',
#  'coronavirus',
#  'pandemic',
#  'diversit',
#  'deaf',
#  'deaf',
#  'lipreading',
#  'lipreaders',
#  'hardofhearing',
#  'hearingloss',
#  'gifts',
#  'masks',
#  'art',
#  'prints',
#  'awesome',
#  'products',
#  'rbandme',
#  'findyourthing',
#  'communication',
#  'deaf',
#  'deaf',
#  'hardofhearing',
#  'bedeafaware',
#  'deafaware',
#  'suriya',
#  'riverside',
#  'coronavirus',
#  'vaccine',
#  'coronavirus',
#  'oxygenexpress',
#  'train',
#  'jamnagar',
#  'oxygen',
#  'beast',
#  'beastsecondlook',
#  'beastfl',
#  'தன',
#  'coronavirus',
#  'thalapathy66',
#  'covid19uk',
#  'covid19',
#  'coronavirus',
#  'china',
#  'cor',
#  'coronavirus',
#  'nicolasturgeon',
#  'coronavirus',
#  'coronavirus',
#  'iran',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'covid19',
#  'coronavirus',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'thingstodo',
#  'coronavirus',
#  'quarantine',
#  'coronavirus',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'coronavirus',
#  'coronavirus',
#  'businesses',
#  'usa',
#  'covid19',
#  'coronavirus',
#  'c',
#  'healthyaa',
#  'coronavirus',
#  'cases',
#  'covid',
#  'testing',
#  'pcr',
#  'pandemic',
#  'travel',
#  'flights',
#  'virus',
#  'news',
#  'health',
#  'today',
#  'leicester',
#  'breaking',
#  'covid19',
#  'jeffzients',
#  'fourthofjuly',
#  'coronavirus',
#  'uk',
#  'wales',
#  'britain',
#  'nithyananda',
#  'kailasa',
#  'nithyananda',
#  'kailasa',
#  'covid19',
#  'goc',
#  'coronavirus',
#  'coronavirus',
#  'nithyananda',
#  'kailasa',
#  'coronavirus',
#  'nithyananda',
#  'kailasa',
#  'usa',
#  'covid19',
#  'coronavirus',
#  'covid',
#  'coronavirus',
#  'iran',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'cancelexamssavestudent',
#  'pakistan',
#  'cancel_allboard_exams',
#  'justiceforbalochistanstudents',
#  'coronavirus',
#  'imrankhanplz',
#  'nithyananda',
#  'kailasa',
#  'trending',
#  'india',
#  'vegan',
#  'indiafightsback',
#  'stayhomestaysafe',
#  'covid19',
#  'yoga',
#  'fitness',
#  'nutrition',
#  'stayhomestaysafe',
#  'staystrongindia',
#  'coronavirus',
#  'natural',
#  'nuts',
#  'gevalley',
#  'internationaldayofyoga',
#  'india',
#  'naturephotography',
#  'nithyananda',
#  'kailasa',
#  'coronavirus',
#  'florida',
#  'vaccinated',
#  'fail',
#  'nithyananda',
#  'kailasa',
#  'aiadmk',
#  'coronavirus',
#  'israel',
#  'usa',
#  'canada',
#  'uk',
#  'france',
#  'australia',
#  'belgium',
#  'coronavirus',
#  'coronavirus',
#  'coronavirus',
#  'greece',
#  'suriya',
#  'abdala',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'suriya',
#  'fifawc2022',
#  'srilanka',
#  'lka',
#  'covid19',
#  'coronavirus',
#  'covid19sl',
#  'coronavirus',
#  'covid_19',
#  'deltaplus',
#  'covid19',
#  'india',
#  'ratnagiri',
#  'jalgaon',
#  'maharashtra',
#  'madhyapradesh',
#  'kerala',
#  'coronavirus',
#  'deltavariant',
#  'theweek',
#  'coronavirus',
#  'iran',
#  'covid19',
#  'coronavirus',
#  'coronavirus',
#  'srilanka',
#  'lka',
#  'covid19',
#  'coronavirus',
#  'covid19sl',
#  'coronavirus',
#  'covidvaccineworks',
#  'getvaccinated',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'coronavirus',
#  'namibia',
#  'africa',
#  'fortnite',
#  'fortniteinvasion',
#  'retweeet',
#  'help',
#  'gamedev',
#  'gamer',
#  'helpm',
#  'fortnite',
#  'fortniteinvasion',
#  'retweeet',
#  'help',
#  'gamedev',
#  'gamer',
#  'helpm',
#  'turkey',
#  'coronavirus',
#  'covid19',
#  'srilanka',
#  'coronavirus',
#  'himachalpradesh',
#  'lahaul',
#  'spiti',
#  'covid',
#  'vaccination',
#  'coro',
#  'israel',
#  'israe',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'deltaplusvariant',
#  'coronavirus',
#  'fauci',
#  'coronavirus',
#  'wuhan',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'israel',
#  'hyderabad',
#  'tankbund',
#  'covid19',
#  'coronavirus',
#  'stayhome',
#  'stayhomesta',
#  'golf',
#  'srinagar',
#  'besafe',
#  'coronavirus',
#  'india',
#  'danger',
#  'coronavirus',
#  'covid19',
#  'goc',
#  'coronavirus',
#  'vaccine',
#  'gettheshot',
#  'vaccinate',
#  'covid',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'vaccineforall',
#  'mikeyeadon',
#  'pfizer',
#  'vaccine',
#  'cowin',
#  'coronavirus',
#  'coronavirusupdates',
#  'covid19vaccination',
#  'coronavirus',
#  'covid',
#  'coronavirus',
#  'covid',
#  'vaccine',
#  'florida',
#  'coronavirus',
#  'deltavariant',
#  'coronavirus',
#  'covid_19',
#  'covid19',
#  'corona',
#  'uae',
#  'emirates',
#  'wtc21final',
#  'bitcoin',
#  'hodl',
#  'cryptocrash',
#  'مجلس_الامه',
#  'tamilnadu',
#  'covid19',
#  'tncoronaupdates',
#  'coronavirus',
#  'tn',
#  'covid19',
#  'coronavirus',
#  'staysafe',
#  'coronavirus',
#  'covid19',
#  'covid',
#  'vaccine',
#  'corona',
#  'coronavirus',
#  'covidvaccination',
#  'covidvaccine',
#  'covid19',
#  'coronavirus',
#  'suriya',
#  'coronavirus',
#  'covid19',
#  'covid19',
#  'borrowers',
#  'msmes',
#  'india',
#  'banks',
#  'coronavirus',
#  'loans',
#  'npa',
#  'theweek',
#  'deltavariant',
#  'thirdwave',
#  'coronavirus',
#  'covid19',
#  'fauci',
#  'china',
#  'coronavirus',
#  'amygoodman',
#  'coronavirus',
#  'gratitude',
#  'respect',
#  'coronavir',
#  'coronavirus',
#  'covid19',
#  'covid_19',
#  'coronavirus',
#  'jordan',
#  'coronavirus',
#  'morocco',
#  'republicans',
#  'kansas',
#  'coronavirus',
#  'pandemic',
#  'democratic',
#  'coronavirus',
#  'covid19',
#  'mexico',
#  'speakourworld',
#  'learning',
#  'covid19nsw',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'coronavirus',
#  'covid19',
#  'suriya',
#  'corona',
#  'usa',
#  'coronavirus',
#  'covid19',
#  'covid_19',
#  'sarscov2',
#  'staysafe',
#  'telegram',
#  'nih',
#  'coronavirus',
#  'covid19',
#  'sarscov2',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'tuesdayvibe',
#  'breaking',
#  'coronavirus',
#  'coronavirus',
#  'france',
#  'inequality',
#  'poverty',
#  'pandemic',
#  'corona',
#  'covid_19',
#  'coronavirus',
#  'covid19toronto',
#  'covid19ontar',
#  'truth',
#  'trump',
#  'nojusticenopeace',
#  'covid19',
#  'coronavirus',
#  'randeepgu',
#  'sarscov2',
#  'coronavirus',
#  'pollen',
#  'airborne',
#  'suriya',
#  'philippines',
#  'coronavirus',
#  'vaccine',
#  'deltavariant',
#  'covid19',
#  'coronavirus',
#  'covidvaccination',
#  'update',
#  'wildfires',
#  'coronavirus',
#  'covid19',
#  'weather',
#  'hurricane',
#  'news',
#  'worldnews',
#  'nih',
#  'coronavirus',
#  'coronavirus',
#  'getvaccinated',
#  'tory',
#  'covid19',
#  'coronavirus',
#  'toryscum',
#  'toryincompetence',
#  'torycriminals',
#  'covid19uk',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'afrique',
#  'rwanda',
#  'mariages',
#  'covid19',
#  'coronavirus',
#  'société',
#  'society',
#  'débat',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'trump',
#  'racism',
#  'coronavirus',
#  'guncontrolnow',
#  'gunreformnow',
#  'biden',
#  'coronavirus',
#  'iran',
#  'afrique',
#  'rwanda',
#  'mariages',
#  'covid19',
#  'coronavirus',
#  'société',
#  'society',
#  'débat',
#  'débats',
#  'analyse',
#  'monde',
#  'world',
#  'news',
#  'infos',
#  'worldopinions',
#  'فضاءالآراء',
#  'freedom1',
#  'ميادين_الحرية',
#  'blog',
#  'blogs',
#  'variants',
#  'coronav',
#  'coronavirus',
#  'coronavirus',
#  'nih',
#  'coronavirus',
#  'coronavirus',
#  'nih',
#  'coronavirus',
#  'tour',
#  'trip',
#  'travel',
#  'staysafe',
#  'leisure',
#  'vacations',
#  'holiday',
#  'photography',
#  'india',
#  'travelstory',
#  'travelagain',
#  'sovereigntours',
#  'travelpackages',
#  'tourism',
#  'staysafe',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'coronavirus',
#  'covid19',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'vaccinate',
#  'deltavariant',
#  'deltaplus',
#  'wtc21',
#  'covid19',
#  'liveline',
#  'coronavirus',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'suriya',
#  'cuba',
#  'coronavirus',
#  'covid19',
#  'coronavirus',
#  'abdala',
#  'wakeupamerica',
#  'covid19',
#  'vaccinated',
#  'coronavirus',
#  'juststayhome',
#  'coronavirus',
#  'china',
#  'covid21',
#  'coronavirus',
#  'covid',
#  'coronavirus',
#  'southafrica',
#  'wakeupamerica',
#  'covid19',
#  'vaccinated',
#  'coronavirus',
#  'tcot',
#  'suriya',
#  'covid',
#  'coronavirus',
#  'coronavirus',
#  'coronavirus',
#  'philippines',
#  'coronavirus',
#  'vaccine',
#  'covid19',
#  'coronavirus',
#  'israel',
#  'largestvaccinationdrive',
#  'covid19',
#  'vaccinationupdate',
#  'covid19',
#  'vaccinationforall',
#  'india',
#  'israel',
#  'israel',
#  'covid',
#  'corona',
#  'covid19',
#  'coronavirus',
#  'bbcpm',
#  'toryincompetence',
#  'johnsonhasfailedthenation',
#  'vaccine',
#  'israel',
#  'israel',
#  'covid',
#  'coronavirus',
#  'vaccination',
#  'india',
#  'vaccineforall',
#  'largestvaccinedrive',
#  'largestfreevaccinationdrive',
#  'indiafightscorona',
#  'coronavirus',
#  'corona',
#  'iran',
#  'coronavirus',
#  'deltaplusvariant',
#  'covid19',
#  'deltavariant',
#  'coronavirus',
#  'maharashtra',
#  'deltaplus',
#  'india',
#  'madhyapradesh',
#  'thirdwave',
#  'kerala',
#  'covid',
#  'lockdown',
#  'covid19india',
#  'corona',
#  'thingstodo',
#  'coronavirus',
#  'quarantine',
#  'assam',
#  'assamcovidupdate',
#  'coronavirus',
#  'covid_vaccine',
#  'covid19',
#  'covidvaccinationdrive',
#  'dibrugarh',
#  'himantabiswasarma',
#  'kamrup',
#  'pandemic',
#  'breakingnews',
#  'dailynews',
#  'newsmove',
#  'fifawc2022',
#  'coronavirus',
#  'coronavirus',
#  'saudiarabia',
#  'covid1',
#  'tamilnadu',
#  'covid19',
#  'tncoronaupdates',
#  'coronavirus',
#  'tn',
#  'covid19',
#  'coronavirus',
#  'israel',
#  'covid19',
#  'coronavirus',
#  'israel',
#  'pfizer',
#  'coronavirus',
#  'covid19',
#  'vaccine',
#  'coronavirus',
#  'covid',
#  'who',
#  'uk',
#  'wales',
#  'britain',
#  'borisjohnson',
#  'northkorea',
#  'dearleader',
#  'torybritain',
#  'coronavirus',
#  'toxicbritain',
#  'coronavirus',
#  'israel',
#  'israel',
#  'covid19',
#  'coronavirus',
#  'coronavirus',
#  'truth',
#  'trump',
#  'nojusticenopeace',
#  'coronavirus',
#  'travel',
#  'travelrestrictions',
#  'tourism',
#  'hospitalityindustry',
#  'europe',
#  'pandemic',
#  'covid19',
#  'covid',
#  'coronavirus',
#  'coronaviruspandemic',
#  'coronavirusupdates',
#  'smartvideo',
#  'smartnews',
#  'covid19',
#  'karnataka',
#  'bangalore',
#  'coronavirus',
#  'netherlands',
#  'optimistic',
#  'coronavirus',
#  'covid19',
#  'deltavariant',
#  'coronamaatregelen',
#  'covid',
#  'coronavirus',
#  'covid19',
#  'wfh',
#  'wfh',
#  'wfh',
#  'coronavirus',
#  'coronavirus',
#  'coronavirus',
#  'aquaman',
#  'aquamanmovie',
#  'dc',
#  'dccomics',
#  'aquamanedit',
#  'rei',
#  'cosplay',
#  'aquamancosplay',
#  'mares',
#  'dcbr',
#  'coronavirus',
#  'coronavirus',
#  'coronavirus',
#  'coronavirus',
#  'coronavirusupdate',
#  'covid19',
#  'coronaviruspandemic',
#  'coronavirus',
#  'canada',
#  'airtransport',
#  'arctic',
#  'community',
#  'coronavirus',
#  'emergency',
#  'government',
#  'healthservices',
#  'indigenous',
#  'industry',
#  'investment',
#  'operation',
#  'parliament',
#  'remotecommunities',
#  'supplychain',
#  'transport',
#  ...]

# %%
hashtags_list_count = dict(zip(list(hashtags_list),[list(hashtags_list).count(i) for i in list(hashtags_list)]))
print(hashtags_list_count)
# Out:
# {'coronavirus': 647, 'gaza': 1, 'covid19': 354, 'staysafe': 8, 'covidvaccine': 7, 'deltavariant': 32, 'vaccineswork': 5, 'vaccinated': 9, 'healthcare': 6, 'immunology': 1, 'breakingne': 1, 'sandrasturm': 1, 'fu': 1, 'fun': 1, 'love': 4, 'b1010': 1, 'dvd': 1, 'v': 1, 'coronavirusupdate': 22, 'coronaviruspandemic': 22, 'sierraleone': 1, 'pandemic': 25, 'positive': 1, 'covid': 67, 'covid_19': 27, 'breaking': 11, 'jeffzients': 6, 'oxygenexpress': 6, 'train': 6, 'jamnagar': 6, 'oxygen': 6, 'rahulgandhi': 2, 'asia': 2, 'corona': 44, 'covid19nsw': 2, 'covidvaccination': 15, 'vaccine': 39, 'vaccineforall': 8, 'coronavirusupdates': 18, 'ravishkumar': 4, 'godimedia': 1, 'britain': 4, 'brexit': 4, 'borishasfailedbritain': 2, 'borisjohnson': 5, 'loc': 1, 'massachusetts': 2, 'amazon': 2, 'primeday': 2, 'numerator': 1, 'stockmarketnews': 1, 'shoppingevent': 1, 'adobe': 1, 'endthelockdown': 1, 'lockdownsmustend': 1, 'iran': 14, 'madhyapradesh': 4, '22jun2021': 1, 'mpfightscorona': 1, 'businesses': 2, 'sarscov2': 12, 'level5': 1, 'scotland': 3, 'lockdown': 5, 'covid19uk': 9, 'voteofnoconfidence': 1, 'staythefhome': 1, 'wakeup': 2, 'لعبة_الأمم': 2, 'nationesgame': 2, 'antivaccine': 2, 'antivaxx': 2, 'antivaccinepas': 1, 'endgainoffunctionfunding': 1, 'nih': 5, 'suriya': 36, 'india': 45, 'vaccines': 8, 'tmc': 1, 'saudiarabia': 6, 'philippine': 5, 'rodrigoduterte': 5, 'china': 27, 'cor': 14, 'largestvaccinationdrive': 23, 'vaccinationupdate': 23, 'vaccinationforall': 23, 'stayhome': 5, 'recoveryloanscheme': 1, 'rls': 1, 'recovery': 2, 'business': 5, 'politics': 4, 'wpro': 1, 'palestinian': 3, 'israel': 22, 'newnormal': 2, 'marketing': 2, 'abdala': 3, 'countydurham': 1, 'largestvaccinedrive': 3, 'indiafightscorona': 10, 'kbkinfographics': 1, 'cyprus': 3, 'assam': 3, 'art': 2, 'prints': 2, 'awesome': 2, 'lipreading': 2, 'lipreaders': 2, 'hardofhearing': 4, 'hearingloss': 2, 'gifts': 2, 'mask': 2, 'deaf': 6, 'diversit': 1, 'masks': 1, 'products': 1, 'rbandme': 1, 'findyourthing': 1, 'communication': 1, 'bedeafaware': 1, 'deafaware': 1, 'riverside': 1, 'beast': 1, 'beastsecondlook': 1, 'beastfl': 1, 'தன': 1, 'thalapathy66': 1, 'nicolasturgeon': 1, 'thingstodo': 5, 'quarantine': 5, 'usa': 6, 'c': 21, 'healthyaa': 1, 'cases': 1, 'testing': 1, 'pcr': 1, 'travel': 10, 'flights': 1, 'virus': 1, 'news': 7, 'health': 11, 'today': 1, 'leicester': 1, 'fourthofjuly': 1, 'uk': 12, 'wales': 5, 'nithyananda': 7, 'kailasa': 7, 'goc': 2, 'cancelexamssavestudent': 1, 'pakistan': 2, 'cancel_allboard_exams': 1, 'justiceforbalochistanstudents': 1, 'imrankhanplz': 1, 'trending': 1, 'vegan': 1, 'indiafightsback': 1, 'stayhomestaysafe': 2, 'yoga': 1, 'fitness': 2, 'nutrition': 3, 'staystrongindia': 1, 'natural': 1, 'nuts': 1, 'gevalley': 1, 'internationaldayofyoga': 1, 'naturephotography': 1, 'florida': 2, 'fail': 1, 'aiadmk': 1, 'canada': 3, 'france': 2, 'australia': 1, 'belgium': 1, 'greece': 4, 'fifawc2022': 2, 'srilanka': 10, 'lka': 9, 'covid19sl': 8, 'deltaplus': 6, 'ratnagiri': 1, 'jalgaon': 1, 'maharashtra': 4, 'kerala': 4, 'theweek': 2, 'covidvaccineworks': 1, 'getvaccinated': 4, 'namibia': 1, 'africa': 4, 'fortnite': 2, 'fortniteinvasion': 2, 'retweeet': 2, 'help': 2, 'gamedev': 3, 'gamer': 6, 'helpm': 2, 'turkey': 2, 'himachalpradesh': 1, 'lahaul': 1, 'spiti': 1, 'vaccination': 7, 'coro': 4, 'israe': 1, 'deltaplusvariant': 23, 'fauci': 3, 'wuhan': 2, 'hyderabad': 1, 'tankbund': 1, 'stayhomesta': 1, 'golf': 1, 'srinagar': 1, 'besafe': 2, 'danger': 1, 'gettheshot': 1, 'vaccinate': 3, 'mikeyeadon': 1, 'pfizer': 5, 'cowin': 1, 'covid19vaccination': 3, 'uae': 1, 'emirates': 1, 'wtc21final': 1, 'bitcoin': 2, 'hodl': 1, 'cryptocrash': 1, 'مجلس_الامه': 1, 'tamilnadu': 19, 'tncoronaupdates': 17, 'tn': 15, 'borrowers': 1, 'msmes': 1, 'banks': 1, 'loans': 1, 'npa': 1, 'thirdwave': 3, 'amygoodman': 1, 'gratitude': 1, 'respect': 1, 'coronavir': 5, 'jordan': 1, 'morocco': 1, 'republicans': 1, 'kansas': 1, 'democratic': 1, 'mexico': 1, 'speakourworld': 1, 'learning': 1, 'tele ...

# %%
c = collections.OrderedDict(sorted(hashtags_list_count.items()))

# %%
c
# Out:
# OrderedDict([('100daysofcode', 3),
#              ('100freeshares', 1),
#              ('1shotnews', 1),
#              ('2019ncov', 3),
#              ('22jun2021', 1),
#              ('77wabcradio', 1),
#              ('a', 2),
#              ('abc15', 1),
#              ('abdala', 3),
#              ('abdalavaccine', 2),
#              ('acci_india', 1),
#              ('ad', 1),
#              ('adobe', 1),
#              ('advertisng', 1),
#              ('advice', 1),
#              ('advisers', 1),
#              ('africa', 4),
#              ('afrique', 2),
#              ('ageism', 1),
#              ('ahmedabad', 1),
#              ('ai', 1),
#              ('aiadmk', 1),
#              ('airborne', 1),
#              ('airtransport', 1),
#              ('albertbourla', 1),
#              ('algeria', 1),
#              ('algerie', 1),
#              ('algorithmicbiologics', 1),
#              ('alshorts', 1),
#              ('amazon', 2),
#              ('amygoodman', 1),
#              ('analyse', 1),
#              ('anantnag', 1),
#              ('animegirl', 1),
#              ('antiafghanpeaceptm', 1),
#              ('anticovidcollectiveofindia', 1),
#              ('antivaccine', 2),
#              ('antivaccinepas', 1),
#              ('antivaccinepassport', 1),
#              ('antivaxx', 2),
#              ('aquaman', 1),
#              ('aquamancosplay', 1),
#              ('aquamanedit', 1),
#              ('aquamanmovie', 1),
#              ('arctic', 1),
#              ('argentina', 2),
#              ('arresttrump', 2),
#              ('art', 2),
#              ('asia', 2),
#              ('asians', 1),
#              ('asiaone', 1),
#              ('askdennis', 1),
#              ('askdrarwady', 2),
#              ('assam', 3),
#              ('assamcovidupdate', 1),
#              ('assistedliving', 1),
#              ('astrazenec', 1),
#              ('astrazeneca', 1),
#              ('australia', 1),
#              ('awareness', 1),
#              ('awesome', 2),
#              ('b1010', 1),
#              ('backtobusiness', 2),
#              ('bangalore', 2),
#              ('bangkok', 3),
#              ('bangkokpost', 1),
#              ('bangladesh', 1),
#              ('bankofgreece', 1),
#              ('banks', 1),
#              ('basic', 1),
#              ('batvirus', 1),
#              ('bbcpm', 1),
#              ('beast', 1),
#              ('beastfl', 1),
#              ('beastsecondlook', 1),
#              ('beauty', 1),
#              ('bedeafaware', 1),
#              ('beijing', 1),
#              ('belgium', 1),
#              ('bengaluru', 1),
#              ('besafe', 2),
#              ('bharatbiotech', 1),
#              ('biden', 6),
#              ('bigdata', 1),
#              ('billgatesbioterrorist', 1),
#              ('biology', 1),
#              ('biometrics', 1),
#              ('bitcoin', 2),
#              ('blog', 1),
#              ('blogs', 1),
#              ('blueanon', 1),
#              ('bluejays', 1),
#              ('bluemaga', 1),
#              ('bodytemp', 2),
#              ('bollywood', 2),
#              ('borishasfailedbritain', 2),
#              ('borisjohnson', 5),
#              ('borrowers', 1),
#              ('bot', 1),
#              ('boycot', 2),
#              ('boycottchina', 1),
#              ('boycottchineseproducts', 1),
#              ('boycottmadeinchina', 1),
#              ('brand', 1),
#              ('branding', 1),
#              ('breaking', 11),
#              ('breakingne', 1),
#              ('breakingnews', 5),
#              ('brexit', 4),
#              ('britain', 4),
#              ('british', 2),
#              ('brokers', 1),
#              ('broking', 1),
#              ('budgets', 1),
#              ('business', 5),
#              ('businessanalytics', 1),
#              ('businesses', 2),
#              ('buythedip', 1),
#              ('bwcdeals', 1),
#              ('c', 21),
#              ('caexampostpone', 1),
#              ('california', 4),
#              ('canada', 3),
#              ('canadacoronavirus', 1),
#              ('cancel_allboard_exams', 1),
#              ('cancelexamssavestudent', 1),
#              ('cannabis', 1),
#              ('cap', 2),
#              ('capitolriot', 1),
#              ('care', 1),
#              ('career', 2),
#              ('careeradvice', 1),
#              ('careerchange', 1),
#              ('careercoach', 1),
#              ('careercounseling', 1),
#              ('careercounselling', 1),
#              ('careerdevelopment', 1),
#              ('careergoals', 1),
#              ('careerguidance', 1),
#              ('careers', 2),
#              ('careersuccess', 1),
#              ('cases', 1),
#              ('castudent', 1),
#              ('castudents', 1),
#              ('cats', 1),
#              ('ccp', 3),
#              ('ccpvirus', 1),
#              ('cdwsocial', 1),
#              ('chennai', 1),
#              ('chi', 1),
#              ('children', 2),
#              ('china', 27),
#              ('chinamustfall', 1),
#              ('chinavirus', 2),
#              ('chinese', 2),
#              ('chinesevirus', 1),
#              ('chomumediandtv', 3),
#              ('chv', 3),
#              ('chvr', 1),
#              ('climatechange', 1),
#              ('co', 3),
#              ('code', 1),
#              ('coincidence', 1),
#              ('collateraldamage', 1),
#              ('college', 1),
#              ('commercial', 1),
#              ('communication', 1),
#              ('communism', 1),
#              ('communistchina', 1),
#              ('community', 1),
#              ('companyculture', 1),
#              ('compliance', 1),
#              ('conservative', 1),
#              ('contactlesssecurity', 1),
#              ('cor', 14),
#              ('cornwall', 2),
#              ('coro', 4),
#              ('coron', 1),
#              ('corona', 44),
#              ('coronachan', 1),
#              ('coronamaatregelen', 1),
#              ('coronaoutbreak', 1),
#              ('coronapandemic', 1),
#              ('coronaupdates', 2),
#              ('coronav', 3),
#              ('coronavaccine', 5),
#              ('coronavi', 2),
#              ('coronavir', 5),
#              ('coronaviru', 4),
#              ('coronavirus', 647),
#              ('coronavirusbrazil', 1),
#              ('coronaviruscases', 1),
#              ('coronavirusdeathtoll', 1),
#              ('coronavirusgr', 1),
#              ('coronavirusinap', 1),
#              ('coronavirusincanada', 1),
#              ('coronavirusindia', 2),
#              ('coronavirusinindia', 1),
#              ('coronavirusinmanitoba', 1),
#              ('coronavirusintelangana', 1),
#              ('coronavirusnews', 1),
#              ('coronavirusoutbreak', 1),
#              ('coronaviruspandemic', 22),
#              ('coronavirusuk', 3),
#              ('coronavirusupdate', 22),
#              ('coronavirusupdates', 18),
#              ('coronavírus', 1),
#              ('cosplay', 1),
#              ('costadelsol', 2),
#              ('countydurham', 1),
#              ('cov', 2),
#              ('covaxin', 4),
#              ('covi', 2),
#              ('covid', 67),
#              ('covid1', 3),
#              ('covid19', 354),
#              ('covid19dj', 1),
#              ('covid19gr', 4),
#              ('covid19india', 8),
#              ('covid19inindia', 1),
#              ('covid19ireland', 1),
#              ('covid19lk', 4),
#              ('covid19nl', 1),
#              ('covid19nsw', 2),
#              ('covid19ontar', 1),
#              ('covid19sa', 1),
#              ('covid19sl', 8),
#              ('covid19toll', 1),
#              ('covid19toronto', 1),
#              ('covid19uk', 9),
#              ('covid19vaccination', 3),
#              ('covid19vaccine', 5),
#              ('covid2019', 1),
#              ('covid21', 3),
#              ('covid_19', 27),
#              ('covid_19canada', 1),
#              ('covid_19news', 1),
#              ('covid_19sl', 1),
#              ('covid__19', 2),
#              ('covid_vaccine', 1),
#              ('covidcare', 1),
#              ('covidindia', 1),
#              ('covidiots', 2),
#              ('covidpass', 1),
#              ('covidsecondwave', 1),
#              ('covidtest', 1),
#              ('covidtravel', 1),
#              ('covidvac', 2),
#              ('covidvacccine', 1),
#              ('covidvaccination', 15),
#              ('covidvaccinationdrive', 1),
#              ('covidvaccine', 7),
#              ('covidvaccines', 2),
#              ('covidvaccineworks', 1),
#              ('covidー19', 3),
#              ('covishield', 3),
#              ('cowin', 1),
#              ('crime', 1),
#              ('crtoon', 1),
#              ('cryptocrash', 1),
#              ('cuba', 8),
#              ('cure', 1),
#              ('cybersecurity', 1),
#              ('cyprus', 3),
#              ('dabbooratnanicalendar', 1),
#              ('dailycovidupdate', 3),
#              ('dailynews', 2),
#              ('dakshinakannada', 1),
#              ('danger', 1),
#              ('daszak', 1),
#              ('data', 2),
#              ('datascience', 1),
#              ('davangere', 1),
#              ('dc', 1),
#              ('dcbr', 1),
#              ('dccomics', 1),
#              ('deaf', 6),
#              ('deafaware', 1),
#              ('dearleader', 1),
#              ('deathmatch', 1),
#              ('debt', 1),
#              ('delhi', 1),
#              ('delta', 1),
#              ('delta9', 1),
#              ('deltaplus', 6),
#              ('deltaplusvariant', 23),
#              ('deltavariant', 32),
#              ('democratic', 1),
#              ('devops', 1),
#              ('diabetic', 2),
#              ('dibrugarh', 1),
#              ('digitalcertificate', 1),
#              ('digitaltransformation', 1),
#              ('dirumahaja', 1),
#              ('distributionaleffects', 1),
#              ('diversit', 1),
#              ('djibouti', 2),
#              ('dna', 2),
#              ('doctor', 3),
#              ('doctors', 1),
#              ('dogs', 1),
#              ('dollarpromo', 1),
#              ('dongjingwei', 1),
#              ('drsangrampatil', 1),
#              ('ds', 1),
#              ('duterte', 1),
#              ('dvd', 1),
#              ('débat', 2),
#              ('débats', 1),
#              ('earthquake', 2),
#              ('ecchi', 1),
#              ('ecchigirls', 1),
#              ('economy', 2),
#              ('education', 1),
#              ('eldercare', 1),
#              ('emergency', 2),
#              ('emirates', 1),
#              ('end', 1),
#              ('endgainoffunctionfunding', 1),
#              ('endthelockdown', 1),
#              ('england', 1),
#              ('entrepreneurship', 1),
#              ('epidemiology', 2),
#              ('euresjobs', 1),
#              ('europe', 2),
#              ('euworkers', 1),
#              ('expat', 1),
#              ('expatnoteslux', 1),
#              ('expats', 1),
#              ('exposed', 1),
#              ('fabriziogatti', 1),
#              ('facebook', 1),
#              ('facts', 1),
#              ('faculty', 1),
#              ('fail', 1),
#              ('fake', 1),
#              ('fanservice', 1),
#              ('farmersprotest', 1),
#              ('fascism', 2),
#              ('fashion', 2),
#              ('fatalityrate', 1),
#              ('fauci', 3),
#              ('fertility', 1),
#              ('fifawc2022', 2),
#              ('fightagainstcorona', 1),
#              ('fightagainstcoronavirus', 1),
#              ('findyourthing', 1),
#              ('firesafety', 1),
#              ('fitness', 2),
#              ('flattenthecurve', 1),
#              ('flights', 1),
#              ('floods', 1),
#              ('florida', 2),
#              ('follow', 1),
#              ('followcovidp', 4),
#              ('followcovidprotocols', 1),
#              ('foodbank', 1),
#              ('fortnite', 2),
#              ('fortniteinvasion', 2),
#              ('fourthofjuly', 1),
#              ('foxnews', 1),
#              ('france', 2),
#              ('freedom1', 1),
#              ('freedomday', 1),
#              ('freedomdayuk', 1),
#              ('fu', 1),
#              ('fuel', 2),
#              ('fun', 1),
#              ('furloughing', 1),
#              ('futureoftravel', 1),
#              ('gamedev', 3),
#              ('gamer', 6),
#              ('gamers', 1),
#              ('gauteng', 2),
#              ('gaza', 1),
#              ('genocide', 1),
#              ('genome', 1),
#              ('gettheshot', 1),
#              ('getvaccinated', 4),
#              ('gevalley', 1),
#              ('gifts', 2),
#              ('gijinka', 1),
#              ('global', 1),
#              ('goc', 2),
#              ('god', 1),
#              ('godimedia', 1),
#              ('golf', 1),
#              ('google', 3),
#              ('gop', 1),
#              ('gopdomesticterrorists', 1),
#              ('gotvaccinated', 1),
#              ('government', 1),
#              ('gratitude', 1),
#              ('greece', 4),
#              ('guncontrolnow', 1),
#              ('gunreformnow', 1),
#              ('handmade', 1),
#              ('hardmarket', 1),
#              ('hardofhearing', 4),
#              ('health', 11),
#              ('healthcare', 6),
#              ('healthmatters', 2),
#              ('healthministry', 2),
#              ('healthservices', 1),
#              ('healthy', 1),
#              ('healthyaa', 1),
#              ('healthylifestyle', 2),
#              ('healthyliving', 1),
#              ('hearingloss', 2),
#              ('help', 2),
#              ('helpingothers', 1),
#              ('helpline', 1),
#              ('helpm', 2),
#              ('helptoneedy', 1),
#              ('himachalpradesh', 1),
#              ('himantabiswasarma', 1),
#              ('hiranandani', 2),
#              ('hiv', 1),
#              ('hodl', 1),
#              ('holiday', 1),
#              ('home', 1),
#              ('homeworking', 1),
#              ('hospital', 1),
#              ('hospitality', 1),
#              ('hospitalityindustry', 1),
#              ('hotline', 1),
#              ('htcvive', 1),
#              ('hurricane', 1),
#              ('hurricanes', 2),
#              ('hyderabad', 1),
#              ('hypocrisy', 1),
#              ('iceland', 1),
#              ('igdaily', 2),
#              ('immunology', 1),
#              ('imrankhanplz', 1),
#              ('imunisasi', 1),
#              ('in', 1),
#              ('incentive', 1),
#              ('income', 1),
#              ('india', 45),
#              ('indiacovidcrisis', 1),
#              ('indiafightsback', 1),
#              ('indiafightscorona', 10),
#              ('indialockdown', 1),
#              ('indianews', 1),
#              ('indianvariant', 1),
#              ('indiaunlock', 1),
#              ('indiedev', 4),
#              ('indiegamedev', 4),
#              ('indiegames', 4),
#              ('indigenous', 1),
#              ('indonesia', 1),
#              ('industry', 1),
#              ('inequality', 1),
#              ('information', 1),
#              ('informedconsent', 1),
#              ('infos', 1),
#              ('injustice', 1),
#              ('instadaily', 2),
#              ('instagood', 2),
#              ('instagram', 2),
#              ('insurance', 1),
#              ('internationaldayofyoga', 1),
#              ('internationalyogaday', 1),
#              ('investigation', 1),
#              ('investing', 2),
#              ('investment', 1),
#              ('iow', 1),
#              ('iran', 14),
#              ('ireland', 1),
#              ('isleofwight', 2),
#              ('israe', 1),
#              ('israel', 22),
#              ('italy', 2),
#              ('iwnews', 1),
#              ('jaibharat', 1),
#              ('jaihind', 1),
#              ('jalgaon', 1),
#              ('jamnagar', 6),
#              ('jeffzients', 6),
#              ('jin', 1),
#              ('job', 1),
#              ('jobs', 1),
#              ('jobsearch', 1),
#              ('joebiden', 1),
#              ('johnsonhasfailedthenation', 1),
#              ('jointsforjabs', 1),
#              ('jordan', 1),
#              ('juneteenth', 1),
#              ('jungkook', 1),
#              ('justiceforbalochistanstudents', 1),
#              ('justiceforca_students', 1),
#              ('juststayhome', 1),
#              ('kailasa', 7),
#              ('kamrup', 1),
#              ('kansas', 1),
#              ('karnataka', 2),
#              ('kashmir', 1),
#              ('kbkinfographics', 1),
#              ('kerala', 4),
#              ('keralalockdown', 1),
#              ('kernow', 1),
#              ('kids', 2),
#              ('kritisanon', 1),
#              ('kulgam', 1),
#              ('lab', 1),
#              ('labourmarkets', 1),
#              ('labourshortage', 1),
#              ('lahaul', 1),
#              ('lanavediteseo', 1),
#              ('largestfreevaccinationdrive', 1),
#              ('largestvaccinationdrive', 23),
#              ('largestvaccinedrive', 3),
#              ('latestnews', 1),
#              ('learn', 1),
#              ('learning', 1),
#              ('lebanon', 2),
#              ('leicester', 1),
#              ('leisure', 1),
#              ('lesotho', 1),
#              ('lets_get_vaccinated', 1),
#              ('level5', 1),
#              ('lifecoach', 1),
#              ('lifestyle', 1),
#              ('like', 1),
#              ('lindanimyeni', 1),
#              ('linfinitoerrore', 1),
#              ('lipreaders', 2),
#              ('lipreading', 2),
#              ('live', 1),
#              ('liveline', 1),
#              ('livingandworkingabroad', 1),
#              ('lka', 9),
#              ('loans', 1),
#              ('loc', 1),
#              ('lockdown', 5),
#              ('lockdown2021', 1),
#              ('lockdownsa', 1),
#              ('lockdownsmustend', 1),
#              ('london', 3),
#              ('longtermcare', 1),
#              ('look', 2),
#              ('lookdodia', 2),
#              ('loosewomen', 1),
#              ('lotteries', 1),
#              ('love', 4),
#              ('luchalibre', 1),
#              ('luxembourg', 1),
#              ('madhyapradesh', 4),
#              ('maga', 1),
#              ('maharashtra', 4),
#              ('mahesh', 1),
#              ('malaga', 2),
#              ('maneskin', 6),
#              ('mangonews', 1),
#              ('manila', 1),
#              ('mannkibaat', 1),
#              ('manufacturing', 1),
#              ('mares', 1),
#              ('mariages', 2),
#              ('marijuana', 1),
#              ('marketing', 2),
#              ('maruthachalamcbe', 2),
#              ('mask', 2),
#              ('masks', 1),
#              ('maskupindia', 1),
#              ('maskuppunjab', 5),
#              ('massachusetts', 2),
#              ('medical', 1),
#              ('medicaldevices', 2),
#              ('medicare', 1),
#              ('medicine', 3),
#              ('memes', 2),
#              ('mexico', 1),
#              ('michigan', 2),
#              ('microbiology', 1),
#              ('mikeyeadon', 1),
#              ('military', 1),
#              ('mkt', 1),
#              ('mlb', 1),
#              ('moda', 2),
#              ('modafeminina', 2),
#              ('moderna', 1),
#              ('modi', 3),
#              ('modicrying', 1),
#              ('modisarkar2', 1),
#              ('monde', 1),
#              ('monstergirl', 1),
#              ('morocco', 1),
#              ('moronavirus', 1),
#              ('mortality', 1),
#              ('moscow', 1),
#              ('motivation', 1),
#              ('mpfightscorona', 1),
#              ('mrna', 2),
#              ('msmes', 1),
#              ('muftiqawi', 6),
#              ('mumbai', 10),
#              ('mumbaipolice', 2),
#              ('music', 2),
#              ('mutation', 1),
#              ('mysuru', 1),
#              ('nagarajan', 2),
#              ('namibia', 1),
#              ('nashik', 2),
#              ('nationesgame', 2),
#              ('natural', 1),
#              ('naturephotography', 1),
#              ('netherlands', 1),
#              ('newcastle', 1),
#              ('newnormal', 2),
#              ('news', 7),
#              ('newsmove', 1),
#              ('newsupdate', 1),
#              ('nhs', 1),
#              ('nicolasturgeon', 1),
#              ('nifty', 1),
#              ('nih', 5),
#              ('nithyananda', 7),
#              ('nojusticen', 1),
#              ('nojusticenop', 1),
#              ('nojusticenopeace', 13),
#              ('nomoreextension', 1),
#              ('nomorelockdowns', 1),
#              ('norternireland', 1),
#              ('northkorea', 1),
#              ('noticias', 2),
#              ('nowplaying', 3),
#              ('np', 1),
#              ('npa', 1),
#              ('nsfwart', 1),
#              ('nsfwartist', 1),
#              ('nsfwartistsclub', 1),
#              ('numerator', 1),
#              ('nurse', 1),
#              ('nurses', 1),
#              ('nursing', 1),
#              ('nursinghome', 1),
#              ('nutrition', 3),
#              ('nuts', 1),
#              ('nuturemite', 1),
#              ('observations', 1),
#              ('oculus', 1),
#              ('oggi', 1),
#              ('olympics2021', 1),
#              ('onlinebusiness', 1),
#              ('onlineeducation', 1),
#              ('onlineshopping', 1),
#              ('openbo', 1),
#              ('operation', 1),
#              ('optimistic', 1),
#              ('oxygen', 6),
#              ('oxygenexpress', 6),
#              ('pakistan', 2),
#              ('palestinian', 3),
#              ('pandata', 1),
#              ('pandemic', 25),
#              ('pandemic2021', 1),
#              ('parliament', 1),
#              ('payments', 6),
#              ('pc', 1),
#              ('pcgamer', 1),
#              ('pcgaming', 1),
#              ('pcr', 1),
#              ('pentagon', 6),
#              ('personal', 1),
#              ('petro', 1),
#              ('petroldieselpricehike', 1),
#              ('pfizer', 5),
#              ('pfizervaccine', 1),
#              ('pharmacy', 1),
#              ('philippine', 5),
#              ('philippines', 7),
#              ('photography', 1),
#              ('phuket', 1),
#              ('pl490nao', 6),
#              ('plandemic', 1),
#              ('playoffs', 6),
#              ('pmmodi', 2),
#              ('pmnarendramodi', 2),
#              ('podcast', 1),
#              ('politics', 4),
#              ('pollen', 1),
#              ('positive', 1),
#              ('positivityrate', 1),
#              ('postponeneetug2021', 1),
#              ('postponeneetugtilloctober', 1),
#              ('poverty', 2),
#              ('president', 1),
#              ('pressphotography', 1),
#              ('pride', 6),
#              ('primeday', 2),
#              ('primeday2021', 1),
#              ('prints', 2),
#              ('proactpartnership', 1),
#              ('products', 1),
#              ('protectchicago', 2),
#              ('protection', 3),
#              ('public_outbursts', 1),
#              ('publichealth', 3),
#              ('pulwama', 1),
#              ('punjab', 5),
#              ('q8', 2),
#              ('qatareconomicforum', 6),
#              ('quarantine', 5),
#              ('quienmatoasantiago', 6),
#              ('quote', 1),
#              ('racism', 5),
#              ('racist', 1),
#              ('racists', 1),
#              ('rahulgandhi', 2),
#              ('randeepgu', 1),
#              ('randeepguleria', 1),
#              ('rationdistribution', 1),
#              ('ratnagiri', 1),
#              ('ravishkumar', 4),
#              ('rbandme', 1),
#              ('readers', 1),
#              ('recession', 1),
#              ('recovery', 2),
#              ('recoveryloanscheme', 1),
#              ('references', 2),
#              ('rei', 1),
#              ('relocation', 1),
#              ('remotecommunities', 1),
#              ('remotework', 2),
#              ('reopening', 1),
#              ('repost', 1),
#              ('republicans', 1),
#              ('reputation', 1),
#              ('research', 3),
#              ('respect', 1),
#              ('restaurants', 1),
#              ('restock', 1),
#              ('resume', 1),
#              ('retweeet', 2),
#              ('revenue', 1),
#              ('riansh', 1),
#              ('riskmanagement', 1),
#              ('riverside', 1),
#              ('rls', 1),
#              ('rodrigoduterte', 5),
#              ('rome', 1),
#              ('rona', 1),
#              ('royalwestmedical', 1),
#              ('rt', 3),
#              ('rules', 1),
#              ('russia', 1),
#              ('rwanda', 2),
#              ('safe', 2),
#              ('safety', 1),
#              ('saflecsystems', 1),
#              ('sales', 1),
#              ('salute', 1),
#              ('sambad', 1),
#              ('sanctionchina', 1),
#              ('sandrasturm', 1),
#              ('sars_cov_2', 1),
#              ('sarscov2', 12),
#              ('saudiarabia', 6),
#              ('savesheikhjarrah', 1),
#              ('scamdemic', 1),
#              ('scamdemic2021', 1),
#              ('schools', 2),
#              ('science', 2),
#              ('scotland', 3),
#              ('seattle', 1),
#              ('secure', 2),
#              ('security', 3),
#              ('selby', 1),
#              ('seniorliving', 1),
#              ('sha', 1),
#              ('sharing', 1),
#              ('shib', 1),
#              ('shopastik', 1),
#              ('shopian', 1),
#              ('shoplocal', 1),
#              ('shoppingevent', 1),
#              ('shopsmal', 1),
#              ('shortnewsapp', 1),
#              ('sierraleone', 1),
#              ('skillednursing', 1),
#              ('skincare', 1),
#              ('smallbusinessconsulting', 1),
#              ('smartnews', 2),
#              ('smartphone', 1),
#              ('smartvideo', 2),
#              ('socialdistanc', 1),
#              ('socialism', 1),
#              ('society', 2),
#              ('société', 2),
#              ('soldier', 1),
#              ('sonyshooter', 1),
#              ('soundcloud', 1),
#              ('southafrica', 7),
#              ('sovereigntours', 1),
#              ('speakourworld', 1),
#              ('spiti', 1),
#              ('spread', 3),
#              ('srilanka', 10),
#              ('srinagar', 1),
#              ('stayathomesavelives', 1),
#              ('stayhome', 5),
#              ('stayhomesta', 1),
#              ('stayhomestaysafe', 2),
#              ('staysafe', 8),
#              ('staystrongindia', 1),
#              ('staythefhome', 1),
#              ('steam', 1),
#              ('steaming', 1),
#              ('stives', 1),
#              ('stockmarketnews', 1),
#              ('stocks', 1),
#              ('storytelling', 1),
#              ('students', 1),
#              ('studyabroad', 1),
#              ('style', 2),
#              ('success', 1),
#              ('sunghoon', 6),
#              ('supplies', 1),
#              ('supplychain', 1),
#              ('supportsmallbusiness', 1),
#              ('surgery', 1),
#              ('suriya', 36),
#              ('t', 2),
#              ('taiw', 1),
#              ('tamilnadu', 19),
#              ('tamilnadunews', 1),
#              ('tankbund', 1),
#              ('tax', 3),
#              ('taxsaving', 1),
#              ('tcot', 1),
#              ('tea', 1),
#              ('technology', 4),
#              ('techstocks', 1),
#              ('telangana', 1),
#              ('telegram', 3),
#              ('testing', 1),
#              ('thaila', 1),
#              ('thailand', 8),
#              ('thalapathy66', 1),
#              ('thalapathybirthday', 1),
#              ('theweek', 2),
#              ('thingstodo', 5),
#              ('thirdwave', 3),
#              ('thirdwavecovid', 3),
#              ('times', 1),
#              ('tmc', 1),
#              ('tn', 15),
#              ('tncoronaupdate', 1),
#              ('tncoronaupdates', 17),
#              ('tngovt', 2),
#              ('today', 1),
#              ('tokyo2020', 2),
#              ('tokyoo', 1),
#              ('tornado', 1),
#              ('toronto', 1),
#              ('torture', 1),
#              ('tory', 1),
#              ('torybritain', 1),
#              ('torycriminals', 1),
#              ('toryincompetence', 2),
#              ('toryscum', 1),
#              ('tour', 1),
#              ('tourism', 10),
#              ('tourismnews', 1),
#              ('toxicbritain', 1),
#              ('train', 6),
#              ('traitortrump', 1),
#              ('transhumanism', 1),
#              ('transport', 1),
#              ('travel', 10),
#              ('travelagain', 1),
#              ('travelnews', 1),
#              ('travelpackages', 1),
#              ('travelrestrictions', 1),
#              ('travelstory', 1),
#              ('treason', 1),
#              ('trending', 1),
#              ('trip', 1),
#              ('tru', 1),
#              ('trump', 18),
#              ('trumpconspiredagainstus', 1),
#              ('trumpcoupattempt', 2),
#              ('trumpdeathtoll600k', 1),
#              ('trumpinsurrection', 1),
#              ('trumpisacriminal', 3),
#              ('trumpisastupididiot', 2),
#              ('trumpisguilty', 2),
#              ('trumpisnotwell', 2),
#              ('truth', 9),
#              ('ttot', 1),
#              ('tuesdayvibe', 3),
#              ('tughlakabad', 1),
#              ('turkey', 2),
#              ('turkovac', 6),
#              ('twitter', 1),
#              ('uae', 1),
#              ('ue4', 4),
#              ('uganda', 1),
#              ('uk', 12),
#              ('ukraine', 2),
#              ('unemployment', 2),
#              ('unionhealthministry', 1),
#              ('unrealengine', 4),
#              ('update', 3),
#              ('updates', 1),
#              ('us', 5),
#              ('usa', 6),
#              ('v', 1),
#              ('vacations', 1),
#              ('vaccinate', 3),
#              ('vaccinated', 9),
#              ('vaccination', 7),
#              ('vaccinationforall', 23),
#              ('vaccinations', 1),
#              ('vaccinationupdate', 23),
#              ('vaccine', 39),
#              ('vaccineforall', 8),
#              ('vaccineincentive', 1),
#              ('vaccines', 8),
#              ('vaccinescam', 1),
#              ('vaccinesideeffects', 1),
#              ('vaccinessavelives', 1),
#              ('vaccineswork', 5),
#              ('vaers', 1),
#              ('vampirevirus', 1),
#              ('variant', 1),
#              ('variantdelta', 1),
#              ('variants', 4),
#              ('vegan', 1),
#              ('venezuela', 2),
#              ('video', 3),
#              ('videocontest', 1),
#              ('videouploads', 1),
#              ('vietnam', 1),
#              ('viroligists', 1),
#              ('virtualreality', 1),
#              ('virus', 1),
#              ('virus_corona', 1),
#              ('virus_corona_china', 1),
#              ('viruscorona', 1),
#              ('voetsekanc', 1),
#              ('volunteers', 1),
#              ('voteofnoconfidence', 1),
#              ('wa', 1),
#              ('wakeup', 2),
#              ('wakeupamerica', 2),
#              ('wales', 5),
#              ('warroompandemic', 1),
#              ('warwanarat', 6),
#              ('wealth', 1),
#              ('weather', 1),
#              ('wechat', 1),
#              ('wef', 1),
#              ('wellness', 1),
#              ('wfh', 5),
#              ('whitesupremacy', 2),
#              ('who', 4),
#              ('wildfires', 1),
#              ('will', 1),
#              ('windrushday2021', 6),
#              ('womeninbusiness', 1),
#              ('workfromhome', 2),
#              ('workingabroad', 1),
#              ('workplacesafety', 1),
#              ('world', 2),
#              ('worldaftercorona', 2),
#              ('worldmusicday2021', 1),
#              ('worldnews', 1),
#              ('worldopinions', 1),
#              ('worldwide', 1),
#              ('worldyogaday', 1),
#              ('wpro', 1),
#              ('wtc21', 2),
#              ('wtc21final', 1),
#              ('wtcfinal', 7),
#              ('wuhan', 2),
#              ('wuhanlab', 8),
#              ('wuhanlableak', 3),
#              ('year', 1),
#              ('yieldfarming', 1),
#              ('yoga', 1),
#              ('yogaday', 1),
#              ('youtube', 1),
#              ('zombievirus', 1),
#              ('zonaba', 1),
#              ('الجزائر', 1),
#              ('الجزاير', 1),
#              ('الطقس', 2),
#              ('الكويت', 2),
#              ('المحاكم', 2),
#              ('حصري', 2),
#              ('حصريا', 2),
#              ('خبر', 2),
#              ('فضاءالآراء', 1),
#              ('كويت', 2),
#              ('كويتيه', 2),
#              ('لا_للتطعيم_الإجباري', 1),
#              ('لعبة_الأمم', 2),
#              ...])

# %%
collections.OrderedDict(sorted(hashtags_list_count.items(), key=lambda item: item[1]))
# Out:
# OrderedDict([('gaza', 1),
#              ('immunology', 1),
#              ('breakingne', 1),
#              ('sandrasturm', 1),
#              ('fu', 1),
#              ('fun', 1),
#              ('b1010', 1),
#              ('dvd', 1),
#              ('v', 1),
#              ('sierraleone', 1),
#              ('positive', 1),
#              ('godimedia', 1),
#              ('loc', 1),
#              ('numerator', 1),
#              ('stockmarketnews', 1),
#              ('shoppingevent', 1),
#              ('adobe', 1),
#              ('endthelockdown', 1),
#              ('lockdownsmustend', 1),
#              ('22jun2021', 1),
#              ('mpfightscorona', 1),
#              ('level5', 1),
#              ('voteofnoconfidence', 1),
#              ('staythefhome', 1),
#              ('antivaccinepas', 1),
#              ('endgainoffunctionfunding', 1),
#              ('tmc', 1),
#              ('recoveryloanscheme', 1),
#              ('rls', 1),
#              ('wpro', 1),
#              ('countydurham', 1),
#              ('kbkinfographics', 1),
#              ('diversit', 1),
#              ('masks', 1),
#              ('products', 1),
#              ('rbandme', 1),
#              ('findyourthing', 1),
#              ('communication', 1),
#              ('bedeafaware', 1),
#              ('deafaware', 1),
#              ('riverside', 1),
#              ('beast', 1),
#              ('beastsecondlook', 1),
#              ('beastfl', 1),
#              ('தன', 1),
#              ('thalapathy66', 1),
#              ('nicolasturgeon', 1),
#              ('healthyaa', 1),
#              ('cases', 1),
#              ('testing', 1),
#              ('pcr', 1),
#              ('flights', 1),
#              ('virus', 1),
#              ('today', 1),
#              ('leicester', 1),
#              ('fourthofjuly', 1),
#              ('cancelexamssavestudent', 1),
#              ('cancel_allboard_exams', 1),
#              ('justiceforbalochistanstudents', 1),
#              ('imrankhanplz', 1),
#              ('trending', 1),
#              ('vegan', 1),
#              ('indiafightsback', 1),
#              ('yoga', 1),
#              ('staystrongindia', 1),
#              ('natural', 1),
#              ('nuts', 1),
#              ('gevalley', 1),
#              ('internationaldayofyoga', 1),
#              ('naturephotography', 1),
#              ('fail', 1),
#              ('aiadmk', 1),
#              ('australia', 1),
#              ('belgium', 1),
#              ('ratnagiri', 1),
#              ('jalgaon', 1),
#              ('covidvaccineworks', 1),
#              ('namibia', 1),
#              ('himachalpradesh', 1),
#              ('lahaul', 1),
#              ('spiti', 1),
#              ('israe', 1),
#              ('hyderabad', 1),
#              ('tankbund', 1),
#              ('stayhomesta', 1),
#              ('golf', 1),
#              ('srinagar', 1),
#              ('danger', 1),
#              ('gettheshot', 1),
#              ('mikeyeadon', 1),
#              ('cowin', 1),
#              ('uae', 1),
#              ('emirates', 1),
#              ('wtc21final', 1),
#              ('hodl', 1),
#              ('cryptocrash', 1),
#              ('مجلس_الامه', 1),
#              ('borrowers', 1),
#              ('msmes', 1),
#              ('banks', 1),
#              ('loans', 1),
#              ('npa', 1),
#              ('amygoodman', 1),
#              ('gratitude', 1),
#              ('respect', 1),
#              ('jordan', 1),
#              ('morocco', 1),
#              ('republicans', 1),
#              ('kansas', 1),
#              ('democratic', 1),
#              ('mexico', 1),
#              ('speakourworld', 1),
#              ('learning', 1),
#              ('inequality', 1),
#              ('covid19toronto', 1),
#              ('covid19ontar', 1),
#              ('randeepgu', 1),
#              ('pollen', 1),
#              ('airborne', 1),
#              ('wildfires', 1),
#              ('weather', 1),
#              ('hurricane', 1),
#              ('worldnews', 1),
#              ('tory', 1),
#              ('toryscum', 1),
#              ('torycriminals', 1),
#              ('guncontrolnow', 1),
#              ('gunreformnow', 1),
#              ('débats', 1),
#              ('analyse', 1),
#              ('monde', 1),
#              ('infos', 1),
#              ('worldopinions', 1),
#              ('فضاءالآراء', 1),
#              ('freedom1', 1),
#              ('ميادين_الحرية', 1),
#              ('blog', 1),
#              ('blogs', 1),
#              ('tour', 1),
#              ('trip', 1),
#              ('leisure', 1),
#              ('vacations', 1),
#              ('holiday', 1),
#              ('photography', 1),
#              ('travelstory', 1),
#              ('travelagain', 1),
#              ('sovereigntours', 1),
#              ('travelpackages', 1),
#              ('liveline', 1),
#              ('juststayhome', 1),
#              ('tcot', 1),
#              ('bbcpm', 1),
#              ('johnsonhasfailedthenation', 1),
#              ('largestfreevaccinationdrive', 1),
#              ('assamcovidupdate', 1),
#              ('covid_vaccine', 1),
#              ('covidvaccinationdrive', 1),
#              ('dibrugarh', 1),
#              ('himantabiswasarma', 1),
#              ('kamrup', 1),
#              ('newsmove', 1),
#              ('northkorea', 1),
#              ('dearleader', 1),
#              ('torybritain', 1),
#              ('toxicbritain', 1),
#              ('travelrestrictions', 1),
#              ('hospitalityindustry', 1),
#              ('netherlands', 1),
#              ('optimistic', 1),
#              ('coronamaatregelen', 1),
#              ('aquaman', 1),
#              ('aquamanmovie', 1),
#              ('dc', 1),
#              ('dccomics', 1),
#              ('aquamanedit', 1),
#              ('rei', 1),
#              ('cosplay', 1),
#              ('aquamancosplay', 1),
#              ('mares', 1),
#              ('dcbr', 1),
#              ('airtransport', 1),
#              ('arctic', 1),
#              ('community', 1),
#              ('government', 1),
#              ('healthservices', 1),
#              ('indigenous', 1),
#              ('industry', 1),
#              ('investment', 1),
#              ('operation', 1),
#              ('parliament', 1),
#              ('remotecommunities', 1),
#              ('supplychain', 1),
#              ('transport', 1),
#              ('astrazenec', 1),
#              ('manufacturing', 1),
#              ('sharing', 1),
#              ('mortality', 1),
#              ('in', 1),
#              ('ahmedabad', 1),
#              ('crime', 1),
#              ('covid19nl', 1),
#              ('coron', 1),
#              ('chvr', 1),
#              ('virtualreality', 1),
#              ('gamers', 1),
#              ('htcvive', 1),
#              ('oculus', 1),
#              ('steam', 1),
#              ('sales', 1),
#              ('pcgaming', 1),
#              ('pc', 1),
#              ('pcgamer', 1),
#              ('follow', 1),
#              ('like', 1),
#              ('covid2019', 1),
#              ('coronaoutbreak', 1),
#              ('global', 1),
#              ('rationdistribution', 1),
#              ('foodbank', 1),
#              ('helptoneedy', 1),
#              ('medical', 1),
#              ('nurse', 1),
#              ('hospital', 1),
#              ('doctors', 1),
#              ('wellness', 1),
#              ('healthy', 1),
#              ('healthyliving', 1),
#              ('nurses', 1),
#              ('surgery', 1),
#              ('pharmacy', 1),
#              ('skincare', 1),
#              ('nursing', 1),
#              ('bharatbiotech', 1),
#              ('president', 1),
#              ('public_outbursts', 1),
#              ('sars_cov_2', 1),
#              ('quote', 1),
#              ('god', 1),
#              ('riansh', 1),
#              ('thalapathybirthday', 1),
#              ('yieldfarming', 1),
#              ('openbo', 1),
#              ('primeday2021', 1),
#              ('savesheikhjarrah', 1),
#              ('shib', 1),
#              ('farmersprotest', 1),
#              ('jungkook', 1),
#              ('jin', 1),
#              ('zonaba', 1),
#              ('buythedip', 1),
#              ('nifty', 1),
#              ('lifestyle', 1),
#              ('mlb', 1),
#              ('bluejays', 1),
#              ('np', 1),
#              ('soundcloud', 1),
#              ('coronapandemic', 1),
#              ('viroligists', 1),
#              ('covidindia', 1),
#              ('shopastik', 1),
#              ('canadacoronavirus', 1),
#              ('coronaviruscases', 1),
#              ('coronavirusincanada', 1),
#              ('coronavirusnews', 1),
#              ('covid_19canada', 1),
#              ('covid_19news', 1),
#              ('informedconsent', 1),
#              ('newcastle', 1),
#              ('nhs', 1),
#              ('pressphotography', 1),
#              ('pfizervaccine', 1),
#              ('sonyshooter', 1),
#              ('cannabis', 1),
#              ('coronavirusinmanitoba', 1),
#              ('delta9', 1),
#              ('jointsforjabs', 1),
#              ('vaccineincentive', 1),
#              ('tncoronaupdate', 1),
#              ('1shotnews', 1),
#              ('tamilnadunews', 1),
#              ('storytelling', 1),
#              ('end', 1),
#              ('torture', 1),
#              ('cats', 1),
#              ('dogs', 1),
#              ('care', 1),
#              ('algeria', 1),
#              ('الجزائر', 1),
#              ('الجزاير', 1),
#              ('algerie', 1),
#              ('learn', 1),
#              ('personal', 1),
#              ('observations', 1),
#              ('exposed', 1),
#              ('thaila', 1),
#              ('hotline', 1),
#              ('helpline', 1),
#              ('livingandworkingabroad', 1),
#              ('expat', 1),
#              ('expats', 1),
#              ('will', 1),
#              ('workingabroad', 1),
#              ('relocation', 1),
#              ('advice', 1),
#              ('taxsaving', 1),
#              ('year', 1),
#              ('proactpartnership', 1),
#              ('covid19inindia', 1),
#              ('bot', 1),
#              ('pandemic2021', 1),
#              ('alshorts', 1),
#              ('shortnewsapp', 1),
#              ('coronachan', 1),
#              ('gijinka', 1),
#              ('monstergirl', 1),
#              ('animegirl', 1),
#              ('ecchi', 1),
#              ('ecchigirls', 1),
#              ('nsfwart', 1),
#              ('nsfwartist', 1),
#              ('nsfwartistsclub', 1),
#              ('fanservice', 1),
#              ('insurance', 1),
#              ('broking', 1),
#              ('homeworking', 1),
#              ('hardmarket', 1),
#              ('reputation', 1),
#              ('brokers', 1),
#              ('brand', 1),
#              ('modisarkar2', 1),
#              ('mannkibaat', 1),
#              ('bangkokpost', 1),
#              ('caexampostpone', 1),
#              ('justiceforca_students', 1),
#              ('castudent', 1),
#              ('castudents', 1),
#              ('students', 1),
#              ('faculty', 1),
#              ('worldyogaday', 1),
#              ('assistedliving', 1),
#              ('nursinghome', 1),
#              ('seniorliving', 1),
#              ('eldercare', 1),
#              ('longtermcare', 1),
#              ('skillednursing', 1),
#              ('labourmarkets', 1),
#              ('furloughing', 1),
#              ('labourshortage', 1),
#              ('euworkers', 1),
#              ('hospitality', 1),
#              ('distributionaleffects', 1),
#              ('phuket', 1),
#              ('indonesia', 1),
#              ('asians', 1),
#              ('income', 1),
#              ('asiaone', 1),
#              ('wealth', 1),
#              ('budgets', 1),
#              ('debt', 1),
#              ('mkt', 1),
#              ('selby', 1),
#              ('bengaluru', 1),
#              ('covidsecondwave', 1),
#              ('positivityrate', 1),
#              ('fatalityrate', 1),
#              ('dakshinakannada', 1),
#              ('mysuru', 1),
#              ('davangere', 1),
#              ('dollarpromo', 1),
#              ('videouploads', 1),
#              ('videocontest', 1),
#              ('100freeshares', 1),
#              ('jaibharat', 1),
#              ('jaihind', 1),
#              ('vietnam', 1),
#              ('genocide', 1),
#              ('gop', 1),
#              ('scamdemic2021', 1),
#              ('digitalcertificate', 1),
#              ('covidpass', 1),
#              ('transhumanism', 1),
#              ('billgatesbioterrorist', 1),
#              ('wef', 1),
#              ('rona', 1),
#              ('marijuana', 1),
#              ('treason', 1),
#              ('gopdomesticterrorists', 1),
#              ('nojusticen', 1),
#              ('variantdelta', 1),
#              ('petro', 1),
#              ('petroldieselpricehike', 1),
#              ('kritisanon', 1),
#              ('dabbooratnanicalendar', 1),
#              ('olympics2021', 1),
#              ('randeepguleria', 1),
#              ('keralalockdown', 1),
#              ('lockdown2021', 1),
#              ('fake', 1),
#              ('vaccinescam', 1),
#              ('rules', 1),
#              ('home', 1),
#              ('covid19dj', 1),
#              ('77wabcradio', 1),
#              ('medicare', 1),
#              ('conservative', 1),
#              ('algorithmicbiologics', 1),
#              ('covidtest', 1),
#              ('lotteries', 1),
#              ('hiv', 1),
#              ('lesotho', 1),
#              ('incentive', 1),
#              ('tornado', 1),
#              ('floods', 1),
#              ('unionhealthministry', 1),
#              ('indiaunlock', 1),
#              ('indialockdown', 1),
#              ('coronavirusdeathtoll', 1),
#              ('coronavirusintelangana', 1),
#              ('coronavirusinap', 1),
#              ('coronavirusinindia', 1),
#              ('mangonews', 1),
#              ('stives', 1),
#              ('kernow', 1),
#              ('wa', 1),
#              ('times', 1),
#              ('oggi', 1),
#              ('linfinitoerrore', 1),
#              ('lab', 1),
#              ('military', 1),
#              ('advisers', 1),
#              ('rome', 1),
#              ('beijing', 1),
#              ('fabriziogatti', 1),
#              ('lanavediteseo', 1),
#              ('salute', 1),
#              ('basic', 1),
#              ('worldmusicday2021', 1),
#              ('england', 1),
#              ('norternireland', 1),
#              ('reopening', 1),
#              ('ireland', 1),
#              ('covid19ireland', 1),
#              ('indianvariant', 1),
#              ('tughlakabad', 1),
#              ('delhi', 1),
#              ('fightagainstcoronavirus', 1),
#              ('chennai', 1),
#              ('mahesh', 1),
#              ('careercounselling', 1),
#              ('careerguidance', 1),
#              ('careercoach', 1),
#              ('education', 1),
#              ('careeradvice', 1),
#              ('careergoals', 1),
#              ('careerdevelopment', 1),
#              ('studyabroad', 1),
#              ('careersuccess', 1),
#              ('success', 1),
#              ('college', 1),
#              ('careercounseling', 1),
#              ('lifecoach', 1),
#              ('dirumahaja', 1),
#              ('kashmir', 1),
#              ('anantnag', 1),
#              ('kulgam', 1),
#              ('pulwama', 1),
#              ('shopian', 1),
#              ('covidcare', 1),
#              ('acci_india', 1),
#              ('anticovidcollectiveofindia', 1),
#              ('helpingothers', 1),
#              ('flattenthecurve', 1),
#              ('volunteers', 1),
#              ('fightagainstcorona', 1),
#              ('newsupdate', 1),
#              ('indianews', 1),
#              ('latestnews', 1),
#              ('fertility', 1),
#              ('lets_get_vaccinated', 1),
#              ('vaccinessavelives', 1),
#              ('repost', 1),
#              ('imunisasi', 1),
#              ('vaccinations', 1),
#              ('toronto', 1),
#              ('royalwestmedical', 1),
#              ('iceland', 1),
#              ('uganda', 1),
#              ('traitortrump', 1),
#              ('followcovidprotocols', 1),
#              ('gotvaccinated', 1),
#              ('indiacovidcrisis', 1),
#              ('bangladesh', 1),
#              ('covid19toll', 1),
#              ('loosewomen', 1),
#              ('taiw', 1),
#              ('abc15', 1),
#              ('internationalyogaday', 1),
#              ('yogaday', 1),
#              ('restaurants', 1),
#              ('moronavirus', 1),
#              ('modicrying', 1),
#              ('revenue', 1),
#              ('coronavirusgr', 1),
#              ('bankofgreece', 1),
#              ('ttot', 1),
#              ('bigdata', 1),
#              ('businessanalytics', 1),
#              ('compliance', 1),
#              ('cybersecurity', 1),
#              ('datascience', 1),
#              ('ds', 1),
#              ('digitaltransformation', 1),
#              ('riskmanagement', 1),
#              ('plandemic', 1),
#              ('scamdemic', 1),
#              ('socialism', 1),
#              ('communism', 1),
#              ('chinesevirus', 1),
#              ('covid19sa', 1),
#              ('vaccinesideeffects', 1),
#              ('mutation', 1),
#              ('coincidence', 1),
#              ('awareness', 1),
#              ('stocks', 1),
#              ('techstocks', 1),
#              ('entrepreneurship', 1),
#              ('womeninbusiness', 1),
#              ('beauty', 1),
#              ('motivation', 1),
#              ('branding', 1),
#              ('smallbusinessconsulting', 1),
#              ('onlinebusiness', 1),
#              ('coronavírus', 1),
#              ('viruscorona', 1),
#              ('coronavirusbrazil', 1),
#              ('virus_corona', 1),
#              ('virus_corona_china', 1),
#              ('onlineshopping', 1),
#              ('supportsmallbusiness', 1),
#              ('handmade', 1),
#              ('shoplocal', 1),
#              ('shopsmal', 1),
#              ('worldwide', 1),
#              ('advertisng', 1),
#              ('commercial', 1),
#              ('ad', 1),
#              ('safety', 1),
#              ('workplacesafety', 1),
#              ('firesafety', 1),
#              ('nuturemite', 1),
#              ('dongjingwei', 1),
#              ('chi', 1),
#              ('racists', 1),
#              ('racist', 1),
#              ('hypocrisy', 1),
#              ('injustice', 1),
#              ('nojusticenop', 1),
#              ('delta', 1),
#              ('variant', 1),
#              ('nomoreextension', 1),
#              ('nomorelockdowns', 1),
#              ('freedomdayuk', 1),
#              ('freedomday', 1),
#              ('tru', 1),
#              ('boycottchina', 1),
#              ('boycottchineseproducts', 1),
#              ('boycottmadeinchina', 1),
#              ('sanctionchina', 1),
#              ('chinamustfall', 1),
#              ('foxnews', 1),
#              ('information', 1),
#              ('postponeneetugtilloctober', 1),
#              ('postponeneetug2021', 1),
#              ('deathmatch', 1),
#              ('luchalibre', 1),
#              ('socialdistanc', 1),
#              ('albertbourla', 1),
#              ('resume', 1),
#              ('job', 1),
#              ('jobs', 1),
#              ('jobsearch', 1),
#              ('ageism', 1),
#              ('careerchange', 1),
#              ('recession', 1),
#              ('collateraldamage', 1),
#              ('genome', 1),
#              ('cure', 1),
#              ('stayathomesavelives', 1),
#              ('companyculture', 1),
#              ('investigation', 1),
#              ('wechat', 1),
#              ('biology', 1),
#              ('microbiology', 1),
#              ('updates', 1),
#              ('daszak', 1),
#              ('warroompandemic', 1),
#              ('communistchina', 1),
#              ('iwnews', 1),
#              ('iow', 1),
#              ('coronavirusoutbreak', 1),
#              ('seattle', 1),
#              ('youtube', 1),
#              ('twitter', 1),
#              ('devops', 1),
#              ('code', 1),
#              ('live', 1),
#              ('facebook', 1),
#              ('cdwsocial', 1),
#              ('steaming', 1),
#              ('sambad', 1),
#              ('crtoon', 1),
#              ('onlineeducation', 1),
#              ('smartphone', 1),
#              ('maskupindia', 1),
#              ('futureoftravel', 1),
#              ('travelnews', 1),
#              ('covidtravel', 1),
#              ('tourismnews', 1),
#              ('supplies', 1),
#              ('restock', 1),
#              ('bwcdeals', 1),
#              ('askdennis', 1),
#              ('پردہ_شریعت_پردہ_تحفظ', 1),
#              ('antiafghanpeaceptm', 1),
#              ('sha', 1),
#              ('ccpvirus', 1),
#              ('drsangrampatil', 1),
#              ('trumpinsurrection', 1),
#              ('trumpconspiredagainstus', 1),
#              ('trumpdeathtoll600k', 1),
#              ('capitolriot', 1),
#              ('joebiden', 1),
#              ('facts', 1),
#              ('tokyoo', 1),
#              ('vaers', 1),
#              ('moderna', 1),
#              ('astrazeneca', 1),
#              ('expatnoteslux', 1),
#              ('luxembourg', 1),
#              ('contactlesssecurity', 1),
#              ('biometrics', 1),
#              ('readers', 1),
#              ('saflecsystems', 1),
#              ('maga', 1),
#              ('bluemaga', 1),
#              ('blueanon', 1),
#              ('soldier', 1),
#              ('vampirevirus', 1),
#              ('batvirus', 1),
#              ('zombievirus', 1),
#              ('tea', 1),
#              ('antivaccinepassport', 1),
#              ('لا_للتطعيم_الإجباري', 1),
#              ('telangana', 1),
#              ('covidvacccine', 1),
#              ('lockdownsa', 1),
#              ('voetsekanc', 1),
#              ('lindanimyeni', 1),
#              ('juneteenth', 1),
#              ('pandata', 1),
#              ('euresjobs', 1),
#              ('podcast', 1),
#              ('ai', 1),
#              ('covid_19sl', 1),
#              ('manila', 1),
#              ('duterte', 1),
#              ('climatechange', 1),
#              ('moscow', 1),
#              ('russia', 1),
#              ('rahulgandhi', 2),
#              ('asia', 2),
#              ('covid19nsw', 2),
#              ('borishasfailedbritain', 2),
#              ('massachusetts', 2),
#              ('amazon', 2),
#              ('primeday', 2),
#              ('businesses', 2),
#              ('wakeup', 2),
#              ('لعبة_الأمم', 2),
#              ('nationesgame', 2),
#              ('antivaccine', 2),
#              ('antivaxx', 2),
#              ('recovery', 2),
#              ('newnormal', 2),
#              ('marketing', 2),
#              ('art', 2),
#              ('prints', 2),
#              ('awesome', 2),
#              ('lipreading', 2),
#              ('lipreaders', 2),
#              ('hearingloss', 2),
#              ('gifts', 2),
#              ('mask', 2),
#              ('goc', 2),
#              ('pakistan', 2),
#              ('stayhomestaysafe', 2),
#              ('fitness', 2),
#              ('florida', 2),
#              ('france', 2),
#              ('fifawc2022', 2),
#              ('theweek', 2),
#              ('fortnite', 2),
#              ('fortniteinvasion', 2),
#              ('retweeet', 2),
#              ('help', 2),
#              ('helpm', 2),
#              ('turkey', 2),
#              ('wuhan', 2),
#              ('besafe', 2),
#              ('bitcoin', 2),
#              ('poverty', 2),
#              ('toryincompetence', 2),
#              ('afrique', 2),
#              ('rwanda', 2),
#              ('mariages', 2),
#              ('société', 2),
#              ('society', 2),
#              ('débat', 2),
#              ('world', 2),
#              ('wtc21', 2),
#              ('wakeupamerica', 2),
#              ('dailynews', 2),
#              ('europe', 2),
#              ('smartvideo', 2),
#              ('smartnews', 2),
#              ('karnataka', 2),
#              ('bangalore', 2),
#              ('emergency', 2),
#              ('mrna', 2),
#              ('healthmatters', 2),
#              ('kids', 2),
#              ('children', 2),
#              ('schools', 2),
#              ('lebanon', 2),
#              ('covid__19', 2),
#              ('italy', 2),
#              ('healthylifestyle', 2),
#              ('covi', 2),
#              ('investing', 2),
#              ('abdalavaccine', 2),
#              ('diabetic', 2),
#              ('medicaldevices', 2),
#              ('moda', 2),
#              ('fashion', 2),
#              ('الكويت', 2),
#              ('modafeminina', 2),
#              ('style', 2),
#              ('خبر', 2),
#              ('حصري', 2),
#              ('كويت', 2),
#              ('noticias', 2),
#              ('lookdodia', 2),
#              ('q8', 2),
#              ('instagood', 2),
#              ('look', 2),
#              ('الطقس', 2),
#              ('كويتيه', 2),
#              ('حصريا', 2),
#              ('المحاكم', 2),
#              ('instagram', 2),
#              ('venezuela', 2),
#              ('instadaily', 2),
#              ('igdaily', 2),
#              ('askdrarwady', 2),
#              ('protectchicago', 2),
#              ('ukraine', 2),
#              ('music', 2),
#              ('bodytemp', 2),
#              ('backtobusiness', 2),
#              ('safe', 2),
#              ('secure', 2),
#              ('coronavi', 2),
#              ('cornwall', 2),
#              ('covidvac', 2),
#              ('bollywood', 2),
#              ('unemployment', 2),
#              ('economy', 2),
#              ('க', 2),
#              ('coronavirusindia', 2),
#              ('tngovt', 2),
#              ('maruthachalamcbe', 2),
#              ('nagarajan', 2),
#              ('dna', 2),
#              ('pmnarendramodi', 2),
#              ('fuel', 2),
#              ('tokyo2020', 2),
#              ('references', 2),
#              ('gauteng', 2),
#              ('hiranandani', 2),
#              ('mumbaipolice', 2),
#              ('trumpisnotwell', 2),
#              ('trumpisastupididiot', 2),
#              ('trumpisguilty', 2),
#              ('cap', 2),
#              ('hurricanes', 2),
#              ('earthquake', 2),
#              ('djibouti', 2),
#              ('pmmodi', 2),
#              ('chinese', 2),
#              ('boycot', 2),
#              ('healthministry', 2),
#              ('career', 2),
#              ('careers', 2),
#              ('cov', 2),
#              ('covidvaccines', 2),
#              ('arresttrump', 2),
#              ('trumpcoupattempt', 2),
#              ('t', 2),
#              ('fascism', 2),
#              ('michigan', 2),
#              ('covidiots', 2),
#              ('data', 2),
#              ('british', 2),
#              ('malaga', 2),
#              ('costadelsol', 2),
#              ('chinavirus', 2),
#              ('epidemiology', 2),
#              ('worldaftercorona', 2),
#              ('nashik', 2),
#              ('coronaupdates', 2),
#              ('whitesupremacy', 2),
#              ('memes', 2),
#              ('science', 2),
#              ('isleofwight', 2),
#              ('a', 2),
#              ('argentina', 2),
#              ('workfromhome', 2),
#              ('remotework', 2),
#              ('scotland', 3),
#              ('palestinian', 3),
#              ('abdala', 3),
#              ('largestvaccinedrive', 3),
#              ('cyprus', 3),
#              ('assam', 3),
#              ('nutrition', 3),
#              ('canada', 3),
#              ('gamedev', 3),
#              ('fauci', 3),
#              ('vaccinate', 3),
#              ('covid19vaccination', 3),
#              ('thirdwave', 3),
#              ('telegram', 3),
#              ('tuesdayvibe', 3),
#              ('update', 3),
#              ('coronav', 3),
#              ('covid21', 3),
#              ('covid1', 3),
#              ('chv', 3),
#              ('medicine', 3),
#              ('doctor', 3),
#              ('rt', 3),
#              ('wuhanlableak', 3),
#              ('security', 3),
#              ('protection', 3),
#              ('spread', 3),
#              ('tax', 3),
#              ('2019ncov', 3),
#              ('modi', 3),
#              ('co', 3),
#              ('bangkok', 3),
#              ('research', 3),
#              ('trumpisacriminal', 3),
#              ('publichealth', 3),
#              ('chomumediandtv', 3),
#              ('covidー19', 3),
#              ('ccp', 3),
#              ('thirdwavecovid', 3),
#              ('covishield', 3),
#              ('coronavirusuk', 3),
#              ('london', 3),
#              ('dailycovidupdate', 3),
#              ('100daysofcode', 3),
#              ('nowplaying', 3),
#              ('google', 3),
#              ('video', 3),
#              ('love', 4),
#              ('ravishkumar', 4),
#              ('britain', 4),
#              ('brexit', 4),
#              ('madhyapradesh', 4),
#              ('politics', 4),
#              ('hardofhearing', 4),
#              ('greece', 4),
#              ('maharashtra', 4),
#              ('kerala', 4),
#              ('getvaccinated', 4),
#              ('africa', 4),
#              ('coro', 4),
#              ('variants', 4),
#              ('who', 4),
#              ('technology', 4),
#              ('ue4', 4),
#              ('unrealengine', 4),
#              ('indiedev', 4),
#              ('indiegamedev', 4),
#              ('indiegames', 4),
#              ('covaxin', 4),
#              ('coronaviru', 4),
#              ('covid19lk', 4),
#              ('california', 4),
#              ('followcovidp', 4),
#              ('covid19gr', 4),
#              ('vaccineswork', 5),
#              ('borisjohnson', 5),
#              ('lockdown', 5),
#              ('nih', 5),
#              ('philippine', 5),
#              ('rodrigoduterte', 5),
#              ('stayhome', 5),
#              ('business', 5),
#              ('thingstodo', 5),
#              ('quarantine', 5),
#              ('wales', 5),
#              ('pfizer', 5),
#              ('coronavir', 5),
#              ('racism', 5),
#              ('breakingnews', 5),
#              ('wfh', 5),
#              ('coronavaccine', 5),
#              ('covid19vaccine', 5),
#              ('punjab', 5),
#              ('maskuppunjab', 5),
#              ('us', 5),
#              ('healthcare', 6),
#              ('jeffzients', 6),
#              ('oxygenexpress', 6),
#              ('train', 6),
#              ('jamnagar', 6),
#              ('oxygen', 6),
#              ('saudiarabia', 6),
#              ('deaf', 6),
#              ('usa', 6),
#              ('deltaplus', 6),
#              ('gamer', 6),
#              ('biden', 6),
#              ('qatareconomicforum', 6),
#              ('quienmatoasantiago', 6),
#              ('warwanarat', 6),
#              ('windrushday2021', 6),
#              ('sunghoon', 6),
#              ('pride', 6),
#              ('pentagon', 6),
#              ('playoffs', 6),
#              ('pl490nao', 6),
#              ('turkovac', 6),
#              ('maneskin', 6),
#              ('muftiqawi', 6),
#              ('payments', 6),
#              ('covidvaccine', 7),
#              ('news', 7),
#              ('nithyananda', 7),
#              ('kailasa', 7),
#              ('vaccination', 7),
#              ('philippines', 7),
#              ('southafrica', 7),
#              ('wtcfinal', 7),
#              ('staysafe', 8),
#              ('vaccineforall', 8),
#              ('vaccines', 8),
#              ('covid19sl', 8),
#              ('cuba', 8),
#              ('covid19india', 8),
#              ('wuhanlab', 8),
#              ('thailand', 8),
#              ('vaccinated', 9),
#              ('covid19uk', 9),
#              ('lka', 9),
#              ('truth', 9),
#              ('indiafightscorona', 10),
#              ('travel', 10),
#              ('srilanka', 10),
#              ('tourism', 10),
#              ('mumbai', 10),
#              ('breaking', 11),
#              ('health', 11),
#              ('sarscov2', 12),
#              ('uk', 12),
#              ('nojusticenopeace', 13),
#              ('iran', 14),
#              ('cor', 14),
#              ('covidvaccination', 15),
#              ('tn', 15),
#              ('tncoronaupdates', 17),
#              ('coronavirusupdates', 18),
#              ('trump', 18),
#              ('tamilnadu', 19),
#              ('c', 21),
#              ('coronavirusupdate', 22),
#              ('coronaviruspandemic', 22),
#              ('israel', 22),
#              ('largestvaccinationdrive', 23),
#              ('vaccinationupdate', 23),
#              ('vaccinationforall', 23),
#              ('deltaplusvariant', 23),
#              ('pandemic', 25),
#              ('covid_19', 27),
#              ('china', 27),
#              ('deltavariant', 32),
#              ('suriya', 36),
#              ('vaccine', 39),
#              ...])

# %%
coronavirus_hashtags_list = ['borishasfailedbritain', 'boristheliar', 'bitcoin', 'bill', 'cancer', 'capitolriots', 'china', 'chinaliedpeopledied', 'chinesevirus', 'chinesevirus', 'communism', 'crimesagainsthumanity', 'crypto', 'cryptocurrency', 'doomsdaytwt', 'fakenews', 'federalgovernment', 'fda', 'firefauci', 'firefaucilegislation', 'fauci', 'fungalinfections', 'futureindanger', 'g7', 'g72021leaders', 'g7summit2021', 'government', 'grenfell', 'hackingduringthecoronaviruspandemic', 'hiv', 'lableaktheory','lableak', 'magneticpower', 'moronavirus', 'trumpvirus', 'tyranny', 'notocoronavirusvaccines', 'robots', 'russia', 'trumpisguilty', 'tyranny', 'whitesupremacy', 'wuhan', 'wuhanlab', 'xijinping']

# %%
#count of words in tweets
words = tweet_coronavirus.stack().str.split("[^\w+]").explode().tolist()

# %%
count_words = dict(zip(list(words),[list(words).count(i) for i in list(words)]))
print(count_words)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-e8602c26e421> in <module>()
# ----> 1 count_words = dict(zip(list(words),[list(words).count(i) for i in list(words)]))
#       2 print(count_words)
#
# <ipython-input-59-e8602c26e421> in <listcomp>(.0)
# ----> 1 count_words = dict(zip(list(words),[list(words).count(i) for i in list(words)]))
#       2 print(count_words)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hashtag EDA Covid

# %%
def get_hashtags_list(df):
    h_list = hashtags(df.hashtag)
    h_list_lower = lowercase(h_list)
    h_list_count = dict(zip(list(h_list_lower),[list(h_list_lower).count(i) for i in list(h_list_lower)]))
    h = h_list_count
    return h

# %%
covid_hashtags = get_hashtags_list(tweet_covid)

# %%
covid_hashtags
# Out:
# {'1a': 1,
#  '2a': 1,
#  '3x3annual': 1,
#  '50swomen': 1,
#  'a24': 1,
#  'a24news': 1,
#  'absolutejoke': 1,
#  'ad': 1,
#  'afirstwave': 34,
#  'africafirst': 1,
#  'africanews': 1,
#  'agility': 1,
#  'ahrq': 1,
#  'ai': 2,
#  'aircare02': 1,
#  'airevolution': 1,
#  'airport': 1,
#  'america': 1,
#  'american': 1,
#  'americanjournal': 1,
#  'amethi': 1,
#  'analytics': 1,
#  'andhra': 1,
#  'antibodies': 1,
#  'antiviral': 1,
#  'art': 1,
#  'artificialintelligence': 1,
#  'arunachalcovidupdate': 2,
#  'asakhe': 1,
#  'asia': 1,
#  'asmicrobe': 1,
#  'assnchat': 1,
#  'associationlife': 1,
#  'astrazeneca': 2,
#  'astrazenica': 7,
#  'asymptomatic': 1,
#  'atlanta': 1,
#  'august': 1,
#  'australia': 1,
#  'awesome': 1,
#  'backstabber': 1,
#  'basemetals': 1,
#  'bbcr4today': 1,
#  'beatcovid': 1,
#  'behibagh': 1,
#  'belairviv': 1,
#  'bengal': 1,
#  'biden': 3,
#  'bidenbordercrisis': 1,
#  'bidensamerica': 1,
#  'bigpharma': 5,
#  'bigtech': 1,
#  'billgates': 2,
#  'billionaireboom': 4,
#  'billionaires': 1,
#  'billy': 1,
#  'bitcoin': 1,
#  'bitechnology': 1,
#  'blockchain': 2,
#  'bombayhighcourt': 1,
#  'boobs': 1,
#  'borishasfailedbritain': 2,
#  'borisjohnson': 3,
#  'brain': 2,
#  'bravotv': 1,
#  'breaking': 3,
#  'breakingnews': 1,
#  'brexit': 4,
#  'britain': 2,
#  'btsthebest': 1,
#  'buildbackbetter': 1,
#  'buildingdevelopments': 1,
#  'bullshit': 1,
#  'business': 4,
#  'businesscontinuity': 1,
#  'businessnews': 1,
#  'c': 5,
#  'cafe': 1,
#  'cancelallexams': 1,
#  'cancer': 1,
#  'caregiver': 2,
#  'carehomes': 1,
#  'cartoons': 2,
#  'cases': 1,
#  'cdhwebinar': 1,
#  'cdnpoli': 1,
#  'censorship': 1,
#  'centrallondon': 1,
#  'cgfsummit': 1,
#  'cgnews': 1,
#  'chandigarh': 1,
#  'chandigarhupdate': 1,
#  'charity': 3,
#  'chemistry': 1,
#  'chenn': 2,
#  'children': 1,
#  'chilwell': 1,
#  'china': 2,
#  'chronicillness': 1,
#  'clean': 1,
#  'cleanair': 1,
#  'climatecrisis': 2,
#  'climatejustice': 1,
#  'clinicalresearch': 1,
#  'clinicaltrials': 1,
#  'cnn': 1,
#  'co': 2,
#  'coffee': 1,
#  'college': 1,
#  'colombia': 1,
#  'comedian': 1,
#  'comics': 1,
#  'commentarypodcast': 1,
#  'computational': 1,
#  'conducive': 1,
#  'confused': 1,
#  'conspiracytheories': 2,
#  'conspirator': 1,
#  'consumerhealth': 1,
#  'cor': 2,
#  'coro': 1,
#  'corona': 7,
#  'coronafacts': 1,
#  'coronaupdate': 29,
#  'coronavirus': 31,
#  'coronaviruspandemic': 1,
#  'coronavirusupdates': 1,
#  'county': 1,
#  'cov': 10,
#  'covaxin': 1,
#  'covi': 5,
#  'covid': 785,
#  'covid19': 88,
#  'covid19india': 2,
#  'covid19sa': 1,
#  'covid19uk': 2,
#  'covid19vaccine': 3,
#  'covid19vaccines': 1,
#  'covid_': 1,
#  'covid_19': 9,
#  'covidaid': 2,
#  'covidappropriatebehaviour': 3,
#  'covidbook': 1,
#  'covidcash': 4,
#  'covidemergency': 1,
#  'covidhelp': 2,
#  'covidindia': 2,
#  'covidiots': 2,
#  'covidisairborne': 2,
#  'covidthermometer': 1,
#  'covidupdates': 1,
#  'covidvacccine': 1,
#  'covidvaccination': 6,
#  'covidvaccine': 2,
#  'covidvariant': 1,
#  'covidvax': 1,
#  'covishield': 1,
#  'crimebranch': 2,
#  'crisismanagement': 1,
#  'cruinsight': 1,
#  'crypto': 1,
#  'cryptocrash': 2,
#  'cryptocurrencies': 1,
#  'csjmu': 1,
#  'cuba': 1,
#  'cybersecurity': 1,
#  'czeeng': 1,
#  'daddysgirls': 10,
#  'dadlife': 1,
#  'dapp': 2,
#  'dascteam': 1,
#  'daszak': 1,
#  'data': 1,
#  'datascience': 1,
#  'dctoday': 1,
#  'dcts': 1,
#  'ddugky': 2,
#  'deathsantis': 1,
#  'decentralizedclinicaltrials': 1,
#  'decentralizedidentity': 1,
#  'decolonize': 1,
#  'deeplearning': 1,
#  'delhi': 1,
#  'delhimetro': 1,
#  'delhipolice': 2,
#  'delhiunlock': 1,
#  'delicious': 1,
#  'delivery': 1,
#  'deltaplus': 3,
#  'deltaplusalarm': 2,
#  'deltaplusvariant': 15,
#  'deltavariant': 6,
#  'deltavariante': 1,
#  'development': 3,
#  'devolutionary': 1,
#  'diagnostics': 1,
#  'digitallearni': 1,
#  'digitallearning': 1,
#  'digitalmarketing': 1,
#  'digitaltechnology': 1,
#  'digitaltransformation': 1,
#  'dinner': 1,
#  'disasterrecovery': 1,
#  'disinfection': 1,
#  'disinfectionservice': 1,
#  'disinformation': 1,
#  'disneycruiseline': 1,
#  'disneyworld': 1,
#  'distancelearning': 1,
#  'dmjaunpur': 1,
#  'dmrc': 1,
#  'doctor': 1,
#  'doha': 1,
#  'donaldtrump': 1,
#  'donate': 1,
#  'drone': 1,
#  'drugs': 1,
#  'dynamic': 1,
#  'ebv': 1,
#  'economy': 1,
#  'edtech': 1,
#  'education': 5,
#  'egypt': 1,
#  'elearning': 1,
#  'election': 1,
#  'electionday': 1,
#  'elitecare': 1,
#  'embarassing': 1,
#  'emory': 1,
#  'emoryuniversity': 1,
#  'employer': 1,
#  'employmentlaw': 2,
#  'encino': 1,
#  'endthelockdown': 3,
#  'england': 1,
#  'enoughisenough': 2,
#  'epsteinisland': 1,
#  'error': 1,
#  'etribun': 1,
#  'euro2020': 8,
#  'europe': 1,
#  'eventplanning': 1,
#  'evs': 1,
#  'exponential': 1,
#  'fabricator': 1,
#  'facebook': 1,
#  'facemask': 2,
#  'facemasks': 1,
#  'fatherhood': 1,
#  'fauci': 3,
#  'fauciemails': 2,
#  'fightfamine': 1,
#  'finestadodealarma': 1,
#  'firstdose': 1,
#  'flights': 2,
#  'florida': 7,
#  'floridaman': 1,
#  'flu': 1,
#  'fluid': 1,
#  'followthesilence': 15,
#  'food': 2,
#  'foodie': 1,
#  'foodlover': 1,
#  'foodphotography': 1,
#  'foodporn': 1,
#  'foodstagram': 1,
#  'foodtraceability': 1,
#  'forthepeople': 1,
#  'fraudulent': 1,
#  'free': 2,
#  'freedom': 2,
#  'freeonlyfans': 1,
#  'freight': 1,
#  'fullyvaccinated': 1,
#  'fundingopportunity': 1,
#  'fyi': 1,
#  'gainoffunction': 1,
#  'genomics': 1,
#  'georgefloyd': 1,
#  'georgia': 1,
#  'getfucked': 1,
#  'gettheshot': 1,
#  'getvaccinated': 2,
#  'getvaccinatedasap': 2,
#  'gifts': 1,
#  'globalism': 1,
#  'goacm': 1,
#  'google': 2,
#  'gop': 3,
#  'gopbetrayedamerica': 1,
#  'gophypocrisy': 1,
#  'goptraitors': 1,
#  'govaxmaryland': 1,
#  'govaxmontgomery': 1,
#  'gqp': 1,
#  'gratitude': 1,
#  'guantanamo': 1,
#  'guillainbarré': 1,
#  'gymjordan': 1,
#  'hand': 1,
#  'hardofhearing': 1,
#  'harrisonsmith': 1,
#  'hbcus': 1,
#  'hcldr': 1,
#  'health': 2,
#  'healthandwellness': 1,
#  'healthcare': 1,
#  'healthtips': 1,
#  'healthyaa': 1,
#  'healthyfood': 1,
#  'hearingaids': 1,
#  'hearingloss': 2,
#  'help': 10,
#  'helping': 1,
#  'highschool': 1,
#  'himachal': 1,
#  'himachalpradesh': 1,
#  'holiday': 1,
#  'home': 1,
#  'homedelivery': 1,
#  'honest': 1,
#  'hospital': 1,
#  'hospitalityindustry': 1,
#  'hospitalizations': 1,
#  'hr': 2,
#  'hsis': 1,
#  'humans': 2,
#  'humor': 1,
#  'hustling101': 1,
#  'ibd': 1,
#  'ibmi': 1,
#  'icai': 1,
#  'icupatients': 1,
#  'icymi': 1,
#  'iglive': 1,
#  'igotmyshot': 1,
#  'illustration': 1,
#  'imdone': 1,
#  'immunization': 1,
#  'inclusive': 1,
#  'india': 25,
#  'indiafightscorona': 4,
#  'indian': 1,
#  'indianarmy': 2,
#  'indianvariant': 1,
#  'inequality': 1,
#  'inhousecounsel': 1,
#  'injection': 1,
#  'innovation': 2,
#  'innovativelearning': 1,
#  'instafood': 1,
#  'interopdoneright': 1,
#  'intersectionality': 1,
#  'investing': 1,
#  'iowaswineday': 1,
#  'irish': 1,
#  'israel': 5,
#  'israelis': 1,
#  'jaipur': 28,
#  'jammu': 1,
#  'jio': 1,
#  'jk': 1,
#  'jobs': 1,
#  'joebiden': 1,
#  'just': 2,
#  'kailasa': 7,
#  'kanpuruniversity': 1,
#  'karnataka': 1,
#  'kashmir': 1,
#  'kazofmupdates': 1,
#  'kellydodd': 1,
#  'kenya': 1,
#  'kerala': 1,
#  'khi': 1,
#  'kishtwar': 1,
#  'kumbh': 1,
#  'laborlaws': 1,
#  'labs': 2,
#  'lahaul': 1,
#  'lakebalboa': 1,
#  'largestvaccinationdrive': 15,
#  'latam': 1,
#  'latest_news': 1,
#  'latinamerica': 1,
#  'leadership': 1,
#  'leaguecity': 1,
#  'learning': 2,
#  'leicester': 2,
#  'leicestershire': 1,
#  'leisa': 1,
#  'lej': 1,
#  'lessons': 1,
#  'lhr': 1,
#  'liar': 1,
#  'lies': 1,
#  'life': 1,
#  'lifestyle': 1,
#  'lipreaders': 1,
#  'lipreading': 1,
#  'lisamariemeadows': 34,
#  'live': 2,
#  'liven': 1,
#  'livestream': 1,
#  'loc': 6,
#  'localseo': 1,
#  'lockdown': 22,
#  'lockdowns': 2,
#  'lockdownsmustend': 3,
#  'london': 4,
#  'longcovid': 1,
#  'losangeles': 1,
#  'love': 1,
#  'lsuhsc': 1,
#  'lunch': 1,
#  'lyme': 1,
#  'machinelearning': 2,
#  'madhyapradesh': 1,
#  'maga': 2,
#  'maharashtra': 2,
#  'manateecounty': 1,
#  'mandatoryvaccination': 1,
#  'manufacturing': 1,
#  'marketing': 1,
#  'mask': 3,
#  'maskmandates': 1,
#  'masks': 1,
#  'masonmount': 1,
#  'matthancock': 1,
#  'mcgm': 1,
#  'meatpacking': 1,
#  'mediascum': 1,
#  'medicine': 1,
#  'meditation': 1,
#  'medtwitter': 1,
#  'memeproject': 2,
#  'memethefamilyman': 1,
#  'metoo': 1,
#  'michigan': 1,
#  'missouri': 1,
#  'mobiletesting': 1,
#  'model': 1,
#  'moderna': 9,
#  'modi': 1,
#  'modiresign': 1,
#  'moldova': 2,
#  'montreal': 1,
#  'mrna': 1,
#  'msis': 1,
#  'mucormycosis': 1,
#  'multifamily': 1,
#  'mumbai': 2,
#  'music': 1,
#  'nantwich': 1,
#  'narendramodi': 1,
#  'nashville': 1,
#  'natgas': 2,
#  'nature': 1,
#  'ndtvexclusive': 1,
#  'nepal': 1,
#  'neurology': 1,
#  'new': 1,
#  'news': 2,
#  'newscentraltv': 1,
#  'nfid': 1,
#  'ngo': 1,
#  'nhs': 4,
#  'nihcm': 2,
#  'nithyananda': 7,
#  'njlaw': 1,
#  'nonprofit': 1,
#  'northcarolina': 1,
#  'northeast': 1,
#  'notover': 1,
#  'nyc': 1,
#  'odaat': 1,
#  'offi': 1,
#  'officereentry': 7,
#  'olympics': 5,
#  'onlinelearning': 1,
#  'onlyfansadult': 1,
#  'onlyfansbabies': 1,
#  'onlyfanscolombia': 1,
#  'onlyfansgoth': 1,
#  'onlyfansgratuito': 1,
#  'onlyfanssa': 1,
#  'onlyfansspain': 1,
#  'onlyfanthailand': 1,
#  'ontario': 1,
#  'open': 1,
#  'organizing': 2,
#  'otaus2021': 1,
#  'ourvoice': 1,
#  'oxygen': 2,
#  'p': 2,
#  'pakistan': 1,
#  'palestine': 2,
#  'pandas': 1,
#  'pandemic': 16,
#  'pandemictransformations': 1,
#  'pans': 1,
#  'parenting': 1,
#  'patients': 1,
#  'pcr': 1,
#  'pedazitosdevuelta': 1,
#  'pedestrianmodelling': 1,
#  'permanentsterilization': 1,
#  'petadoptions': 1,
#  'peterdaszak': 1,
#  'pethealth': 1,
#  'pfizer': 13,
#  'phd': 1,
#  'piercedboobs': 1,
#  'piercing': 1,
#  'pizza': 1,
#  'platforms': 1,
#  'plumber': 1,
#  'plumbers': 1,
#  'plumbing': 1,
#  'plutocracy': 1,
#  'pmcaresfund': 1,
#  'pmoindia': 1,
#  'podcast': 1,
#  'podesta': 1,
#  'podestaart': 1,
#  'politics': 1,
#  'pork': 1,
#  'portfolio': 1,
#  'positive': 1,
#  'power9': 1,
#  'prayerwarrior': 1,
#  'prayfortheworld': 1,
#  'praytogether': 1,
#  'presidents': 1,
#  'pridemonth': 1,
#  'prints': 1,
#  'prohibitoryorder': 1,
#  'propaganda': 1,
#  'prosurvival': 1,
#  'pubs': 1,
#  'quarantine': 1,
#  'rajasthan': 28,
#  'ranchi': 1,
#  'raquelespuelas': 1,
#  'realestate': 1,
#  'recovered': 28,
#  'recovery': 2,
#  'recoveryloanscheme': 1,
#  'recoveryposse': 1,
#  'rehab': 1,
#  'remdesivir': 1,
#  'remotework': 1,
#  'rentassistance': 1,
#  'reopen': 1,
#  'repairs': 1,
#  'research': 2,
#  'researcher': 1,
#  'reseda': 1,
#  'resilience': 2,
#  'restaurant': 1,
#  'retailstrends': 1,
#  'retirement': 1,
#  'returntooffice': 8,
#  'rhoc': 1,
#  'riots': 1,
#  'riseup': 1,
#  'riskmanagement': 1,
#  'rls': 1,
#  'robots': 1,
#  'rotary': 1,
#  'rules': 1,
#  'rwot': 1,
#  'sales': 1,
#  'sanfernandovalley': 1,
#  'sanitization': 1,
#  'sanitizer': 1,
#  'sarscov2': 3,
#  'satire': 1,
#  'saudiarabia': 1,
#  'school': 1,
#  'schoolofmedicine': 1,
#  'scoliosis': 1,
#  'scotland': 1,
#  'scottishcommunities': 1,
#  'scotus': 1,
#  'searchengineoptimization': 1,
#  'seconddose': 1,
#  'secondwave': 1,
#  'sellingcontent': 1,
#  'seniorcitizen': 1,
#  'seostrategy': 1,
#  'service': 1,
#  'services': 1,
#  'sesamestreet': 1,
#  'shahsofsunset': 1,
#  'shg': 1,
#  'shibacharity': 2,
#  'shicha': 2,
#  'sicklecell': 1,
#  'sicklecellwarrior': 1,
#  'sicknotweak': 1,
#  'sierraleone': 1,
#  'smartbusiness': 1,
#  'smartnews': 1,
#  'smartvideo': 1,
#  'so': 2,
#  'soberaf': 1,
#  'socialdistance': 1,
#  'socialdistancing': 3,
#  'southkorean': 1,
#  'sph': 1,
#  'spirituality': 1,
#  'spiti': 1,
#  'splco': 2,
#  'sportsday': 1,
#  'ssi': 1,
#  'stayhome': 1,
#  'stayhomestaysafe': 1,
#  'staysafestayhome': 1,
#  'staythefhome': 1,
#  'sterilization': 1,
#  'stewardmeme': 1,
#  'strep': 1,
#  'student': 1,
#  'students': 1,
#  'successful': 1,
#  'sugardaddy': 1,
#  'suggarmommy': 1,
#  'superbugsuperhero': 1,
#  'supplychain': 1,
#  'support': 1,
#  'supportlocal': 1,
#  'supremecourt': 1,
#  'surgeon': 1,
#  'sushi': 1,
#  'sustainability': 2,
#  'sustainable': 1,
#  'takeaway': 1,
#  'takeawayfood': 1,
#  'takeout': 1,
#  'takeover': 1,
#  'takepoliticsoutofcovid': 1,
#  'tameside': 3,
#  'tarzana': 1,
#  'teachingtips': 1,
#  'techforgood': 1,
#  'technicals': 1,
#  'technology': 2,
#  'telangana': 1,
#  'temples': 1,
#  'testing': 2,
#  'texas': 2,
#  'thailand': 2,
#  'thermometer': 1,
#  'thirdwave': 7,
#  'tikaria': 1,
#  'timecover': 1,
#  'tiredofwaiting': 1,
#  'today': 1,
#  'tokyo2020': 1,
#  'toquedequeda': 1,
#  'torybrexit': 8,
#  'toughgame': 1,
#  'tourism': 5,
#  'trans': 1,
#  'transformationtuesday': 1,
#  'translation': 1,
#  'transparency': 1,
#  'transparencyiskey': 1,
#  'travel': 2,
#  'travelinsurance': 1,
#  'travelrestrictions': 1,
#  'trendingtonight': 7,
#  'trendlines': 1,
#  'trucking': 1,
#  'trump': 1,
#  'trumpcrimefamily': 1,
#  'trumpterroism': 1,
#  'truth': 1,
#  'truthbrigade': 1,
#  'tuesdayvibe': 1,
#  'turkey': 1,
#  'twitch': 1,
#  'udhr': 1,
#  'udupi': 1,
#  'udupicovidupdate': 1,
#  'uk': 3,
#  'ukgovernment': 1,
#  'ulcerativecolitis': 1,
#  'uniform': 1,
#  'unitedagainstcorona': 1,
#  'unitedstates': 1,
#  'university': 4,
#  'up': 1,
#  'update': 1,
#  'updated': 2,
#  'usa': 3,
#  'uttarpradesh': 1,
#  'utv': 1,
#  'vacation': 1,
#  'vaccina': 1,
#  'vaccinate': 1,
#  'vaccinated': 6,
#  'vaccination': 12,
#  'vaccination2021': 1,
#  'vaccinationdone': 1,
#  'vaccinationdrive': 1,
#  'vaccinationforall': 15,
#  'vaccinations': 2,
#  'vaccinationupdate': 15,
#  'vaccinationupdates': 1,
#  'vaccine': 52,
#  'vaccineconfident': 1,
#  'vaccineforall': 3,
#  'vaccines': 2,
#  'vaccinessavelives': 1,
#  'vaccineswork': 3,
#  'vannuys': 1,
#  'variant': 1,
#  'verified': 2,
#  'video': 1,
#  'vietnam': 1,
#  'virtuallearning': 2,
#  'virtualtrials': 1,
#  'virus': 2,
#  'visiting': 1,
#  'viva': 1,
#  'volunteer': 1,
#  'volunteering': 1,
#  'vote': 1,
#  'voteofnoconfidence': 1,
#  'wakedafuckup': 1,
#  'waspi': 1,
#  'webinar': 1,
#  'welfare': 1,
#  'wembley': 1,
#  'weshield': 6,
#  'westbengal': 2,
#  'westend': 1,
#  'westernprivilege': 1,
#  'westminster': 1,
#  'wfh': 4,
#  'whataboutweddings': 1,
#  'wherearethechildren': 1,
#  'who': 1,
#  'whodeemswhatnonessential': 1,
#  'wholetoadnewsservice': 1,
#  'whyisnooneready': 1,
#  'willtolive': 1,
#  'wipolitics': 2,
#  'wisconsin': 2,
#  'wiunion': 2,
#  'women': 1,
#  'workfromhome': 1,
#  'workingparent': 1,
#  'wuhan': 1,
#  'wuhanlab': 4,
#  'wuhanlableak': 1,
#  'yogiadityanath': 1,
#  'youtube': 2,
#  'yummy': 1,
#  '방탄소년단진': 1}

# %%
covid_hashtags
# Out:
# {'1a': 1,
#  '2a': 1,
#  '3x3annual': 1,
#  '50swomen': 1,
#  'a24': 1,
#  'a24news': 1,
#  'absolutejoke': 1,
#  'ad': 1,
#  'afirstwave': 34,
#  'africafirst': 1,
#  'africanews': 1,
#  'agility': 1,
#  'ahrq': 1,
#  'ai': 2,
#  'aircare02': 1,
#  'airevolution': 1,
#  'airport': 1,
#  'america': 1,
#  'american': 1,
#  'americanjournal': 1,
#  'amethi': 1,
#  'analytics': 1,
#  'andhra': 1,
#  'antibodies': 1,
#  'antiviral': 1,
#  'art': 1,
#  'artificialintelligence': 1,
#  'arunachalcovidupdate': 2,
#  'asakhe': 1,
#  'asia': 1,
#  'asmicrobe': 1,
#  'assnchat': 1,
#  'associationlife': 1,
#  'astrazeneca': 2,
#  'astrazenica': 7,
#  'asymptomatic': 1,
#  'atlanta': 1,
#  'august': 1,
#  'australia': 1,
#  'awesome': 1,
#  'backstabber': 1,
#  'basemetals': 1,
#  'bbcr4today': 1,
#  'beatcovid': 1,
#  'behibagh': 1,
#  'belairviv': 1,
#  'bengal': 1,
#  'biden': 3,
#  'bidenbordercrisis': 1,
#  'bidensamerica': 1,
#  'bigpharma': 5,
#  'bigtech': 1,
#  'billgates': 2,
#  'billionaireboom': 4,
#  'billionaires': 1,
#  'billy': 1,
#  'bitcoin': 1,
#  'bitechnology': 1,
#  'blockchain': 2,
#  'bombayhighcourt': 1,
#  'boobs': 1,
#  'borishasfailedbritain': 2,
#  'borisjohnson': 3,
#  'brain': 2,
#  'bravotv': 1,
#  'breaking': 3,
#  'breakingnews': 1,
#  'brexit': 4,
#  'britain': 2,
#  'btsthebest': 1,
#  'buildbackbetter': 1,
#  'buildingdevelopments': 1,
#  'bullshit': 1,
#  'business': 4,
#  'businesscontinuity': 1,
#  'businessnews': 1,
#  'c': 5,
#  'cafe': 1,
#  'cancelallexams': 1,
#  'cancer': 1,
#  'caregiver': 2,
#  'carehomes': 1,
#  'cartoons': 2,
#  'cases': 1,
#  'cdhwebinar': 1,
#  'cdnpoli': 1,
#  'censorship': 1,
#  'centrallondon': 1,
#  'cgfsummit': 1,
#  'cgnews': 1,
#  'chandigarh': 1,
#  'chandigarhupdate': 1,
#  'charity': 3,
#  'chemistry': 1,
#  'chenn': 2,
#  'children': 1,
#  'chilwell': 1,
#  'china': 2,
#  'chronicillness': 1,
#  'clean': 1,
#  'cleanair': 1,
#  'climatecrisis': 2,
#  'climatejustice': 1,
#  'clinicalresearch': 1,
#  'clinicaltrials': 1,
#  'cnn': 1,
#  'co': 2,
#  'coffee': 1,
#  'college': 1,
#  'colombia': 1,
#  'comedian': 1,
#  'comics': 1,
#  'commentarypodcast': 1,
#  'computational': 1,
#  'conducive': 1,
#  'confused': 1,
#  'conspiracytheories': 2,
#  'conspirator': 1,
#  'consumerhealth': 1,
#  'cor': 2,
#  'coro': 1,
#  'corona': 7,
#  'coronafacts': 1,
#  'coronaupdate': 29,
#  'coronavirus': 31,
#  'coronaviruspandemic': 1,
#  'coronavirusupdates': 1,
#  'county': 1,
#  'cov': 10,
#  'covaxin': 1,
#  'covi': 5,
#  'covid': 785,
#  'covid19': 88,
#  'covid19india': 2,
#  'covid19sa': 1,
#  'covid19uk': 2,
#  'covid19vaccine': 3,
#  'covid19vaccines': 1,
#  'covid_': 1,
#  'covid_19': 9,
#  'covidaid': 2,
#  'covidappropriatebehaviour': 3,
#  'covidbook': 1,
#  'covidcash': 4,
#  'covidemergency': 1,
#  'covidhelp': 2,
#  'covidindia': 2,
#  'covidiots': 2,
#  'covidisairborne': 2,
#  'covidthermometer': 1,
#  'covidupdates': 1,
#  'covidvacccine': 1,
#  'covidvaccination': 6,
#  'covidvaccine': 2,
#  'covidvariant': 1,
#  'covidvax': 1,
#  'covishield': 1,
#  'crimebranch': 2,
#  'crisismanagement': 1,
#  'cruinsight': 1,
#  'crypto': 1,
#  'cryptocrash': 2,
#  'cryptocurrencies': 1,
#  'csjmu': 1,
#  'cuba': 1,
#  'cybersecurity': 1,
#  'czeeng': 1,
#  'daddysgirls': 10,
#  'dadlife': 1,
#  'dapp': 2,
#  'dascteam': 1,
#  'daszak': 1,
#  'data': 1,
#  'datascience': 1,
#  'dctoday': 1,
#  'dcts': 1,
#  'ddugky': 2,
#  'deathsantis': 1,
#  'decentralizedclinicaltrials': 1,
#  'decentralizedidentity': 1,
#  'decolonize': 1,
#  'deeplearning': 1,
#  'delhi': 1,
#  'delhimetro': 1,
#  'delhipolice': 2,
#  'delhiunlock': 1,
#  'delicious': 1,
#  'delivery': 1,
#  'deltaplus': 3,
#  'deltaplusalarm': 2,
#  'deltaplusvariant': 15,
#  'deltavariant': 6,
#  'deltavariante': 1,
#  'development': 3,
#  'devolutionary': 1,
#  'diagnostics': 1,
#  'digitallearni': 1,
#  'digitallearning': 1,
#  'digitalmarketing': 1,
#  'digitaltechnology': 1,
#  'digitaltransformation': 1,
#  'dinner': 1,
#  'disasterrecovery': 1,
#  'disinfection': 1,
#  'disinfectionservice': 1,
#  'disinformation': 1,
#  'disneycruiseline': 1,
#  'disneyworld': 1,
#  'distancelearning': 1,
#  'dmjaunpur': 1,
#  'dmrc': 1,
#  'doctor': 1,
#  'doha': 1,
#  'donaldtrump': 1,
#  'donate': 1,
#  'drone': 1,
#  'drugs': 1,
#  'dynamic': 1,
#  'ebv': 1,
#  'economy': 1,
#  'edtech': 1,
#  'education': 5,
#  'egypt': 1,
#  'elearning': 1,
#  'election': 1,
#  'electionday': 1,
#  'elitecare': 1,
#  'embarassing': 1,
#  'emory': 1,
#  'emoryuniversity': 1,
#  'employer': 1,
#  'employmentlaw': 2,
#  'encino': 1,
#  'endthelockdown': 3,
#  'england': 1,
#  'enoughisenough': 2,
#  'epsteinisland': 1,
#  'error': 1,
#  'etribun': 1,
#  'euro2020': 8,
#  'europe': 1,
#  'eventplanning': 1,
#  'evs': 1,
#  'exponential': 1,
#  'fabricator': 1,
#  'facebook': 1,
#  'facemask': 2,
#  'facemasks': 1,
#  'fatherhood': 1,
#  'fauci': 3,
#  'fauciemails': 2,
#  'fightfamine': 1,
#  'finestadodealarma': 1,
#  'firstdose': 1,
#  'flights': 2,
#  'florida': 7,
#  'floridaman': 1,
#  'flu': 1,
#  'fluid': 1,
#  'followthesilence': 15,
#  'food': 2,
#  'foodie': 1,
#  'foodlover': 1,
#  'foodphotography': 1,
#  'foodporn': 1,
#  'foodstagram': 1,
#  'foodtraceability': 1,
#  'forthepeople': 1,
#  'fraudulent': 1,
#  'free': 2,
#  'freedom': 2,
#  'freeonlyfans': 1,
#  'freight': 1,
#  'fullyvaccinated': 1,
#  'fundingopportunity': 1,
#  'fyi': 1,
#  'gainoffunction': 1,
#  'genomics': 1,
#  'georgefloyd': 1,
#  'georgia': 1,
#  'getfucked': 1,
#  'gettheshot': 1,
#  'getvaccinated': 2,
#  'getvaccinatedasap': 2,
#  'gifts': 1,
#  'globalism': 1,
#  'goacm': 1,
#  'google': 2,
#  'gop': 3,
#  'gopbetrayedamerica': 1,
#  'gophypocrisy': 1,
#  'goptraitors': 1,
#  'govaxmaryland': 1,
#  'govaxmontgomery': 1,
#  'gqp': 1,
#  'gratitude': 1,
#  'guantanamo': 1,
#  'guillainbarré': 1,
#  'gymjordan': 1,
#  'hand': 1,
#  'hardofhearing': 1,
#  'harrisonsmith': 1,
#  'hbcus': 1,
#  'hcldr': 1,
#  'health': 2,
#  'healthandwellness': 1,
#  'healthcare': 1,
#  'healthtips': 1,
#  'healthyaa': 1,
#  'healthyfood': 1,
#  'hearingaids': 1,
#  'hearingloss': 2,
#  'help': 10,
#  'helping': 1,
#  'highschool': 1,
#  'himachal': 1,
#  'himachalpradesh': 1,
#  'holiday': 1,
#  'home': 1,
#  'homedelivery': 1,
#  'honest': 1,
#  'hospital': 1,
#  'hospitalityindustry': 1,
#  'hospitalizations': 1,
#  'hr': 2,
#  'hsis': 1,
#  'humans': 2,
#  'humor': 1,
#  'hustling101': 1,
#  'ibd': 1,
#  'ibmi': 1,
#  'icai': 1,
#  'icupatients': 1,
#  'icymi': 1,
#  'iglive': 1,
#  'igotmyshot': 1,
#  'illustration': 1,
#  'imdone': 1,
#  'immunization': 1,
#  'inclusive': 1,
#  'india': 25,
#  'indiafightscorona': 4,
#  'indian': 1,
#  'indianarmy': 2,
#  'indianvariant': 1,
#  'inequality': 1,
#  'inhousecounsel': 1,
#  'injection': 1,
#  'innovation': 2,
#  'innovativelearning': 1,
#  'instafood': 1,
#  'interopdoneright': 1,
#  'intersectionality': 1,
#  'investing': 1,
#  'iowaswineday': 1,
#  'irish': 1,
#  'israel': 5,
#  'israelis': 1,
#  'jaipur': 28,
#  'jammu': 1,
#  'jio': 1,
#  'jk': 1,
#  'jobs': 1,
#  'joebiden': 1,
#  'just': 2,
#  'kailasa': 7,
#  'kanpuruniversity': 1,
#  'karnataka': 1,
#  'kashmir': 1,
#  'kazofmupdates': 1,
#  'kellydodd': 1,
#  'kenya': 1,
#  'kerala': 1,
#  'khi': 1,
#  'kishtwar': 1,
#  'kumbh': 1,
#  'laborlaws': 1,
#  'labs': 2,
#  'lahaul': 1,
#  'lakebalboa': 1,
#  'largestvaccinationdrive': 15,
#  'latam': 1,
#  'latest_news': 1,
#  'latinamerica': 1,
#  'leadership': 1,
#  'leaguecity': 1,
#  'learning': 2,
#  'leicester': 2,
#  'leicestershire': 1,
#  'leisa': 1,
#  'lej': 1,
#  'lessons': 1,
#  'lhr': 1,
#  'liar': 1,
#  'lies': 1,
#  'life': 1,
#  'lifestyle': 1,
#  'lipreaders': 1,
#  'lipreading': 1,
#  'lisamariemeadows': 34,
#  'live': 2,
#  'liven': 1,
#  'livestream': 1,
#  'loc': 6,
#  'localseo': 1,
#  'lockdown': 22,
#  'lockdowns': 2,
#  'lockdownsmustend': 3,
#  'london': 4,
#  'longcovid': 1,
#  'losangeles': 1,
#  'love': 1,
#  'lsuhsc': 1,
#  'lunch': 1,
#  'lyme': 1,
#  'machinelearning': 2,
#  'madhyapradesh': 1,
#  'maga': 2,
#  'maharashtra': 2,
#  'manateecounty': 1,
#  'mandatoryvaccination': 1,
#  'manufacturing': 1,
#  'marketing': 1,
#  'mask': 3,
#  'maskmandates': 1,
#  'masks': 1,
#  'masonmount': 1,
#  'matthancock': 1,
#  'mcgm': 1,
#  'meatpacking': 1,
#  'mediascum': 1,
#  'medicine': 1,
#  'meditation': 1,
#  'medtwitter': 1,
#  'memeproject': 2,
#  'memethefamilyman': 1,
#  'metoo': 1,
#  'michigan': 1,
#  'missouri': 1,
#  'mobiletesting': 1,
#  'model': 1,
#  'moderna': 9,
#  'modi': 1,
#  'modiresign': 1,
#  'moldova': 2,
#  'montreal': 1,
#  'mrna': 1,
#  'msis': 1,
#  'mucormycosis': 1,
#  'multifamily': 1,
#  'mumbai': 2,
#  'music': 1,
#  'nantwich': 1,
#  'narendramodi': 1,
#  'nashville': 1,
#  'natgas': 2,
#  'nature': 1,
#  'ndtvexclusive': 1,
#  'nepal': 1,
#  'neurology': 1,
#  'new': 1,
#  'news': 2,
#  'newscentraltv': 1,
#  'nfid': 1,
#  'ngo': 1,
#  'nhs': 4,
#  'nihcm': 2,
#  'nithyananda': 7,
#  'njlaw': 1,
#  'nonprofit': 1,
#  'northcarolina': 1,
#  'northeast': 1,
#  'notover': 1,
#  'nyc': 1,
#  'odaat': 1,
#  'offi': 1,
#  'officereentry': 7,
#  'olympics': 5,
#  'onlinelearning': 1,
#  'onlyfansadult': 1,
#  'onlyfansbabies': 1,
#  'onlyfanscolombia': 1,
#  'onlyfansgoth': 1,
#  'onlyfansgratuito': 1,
#  'onlyfanssa': 1,
#  'onlyfansspain': 1,
#  'onlyfanthailand': 1,
#  'ontario': 1,
#  'open': 1,
#  'organizing': 2,
#  'otaus2021': 1,
#  'ourvoice': 1,
#  'oxygen': 2,
#  'p': 2,
#  'pakistan': 1,
#  'palestine': 2,
#  'pandas': 1,
#  'pandemic': 16,
#  'pandemictransformations': 1,
#  'pans': 1,
#  'parenting': 1,
#  'patients': 1,
#  'pcr': 1,
#  'pedazitosdevuelta': 1,
#  'pedestrianmodelling': 1,
#  'permanentsterilization': 1,
#  'petadoptions': 1,
#  'peterdaszak': 1,
#  'pethealth': 1,
#  'pfizer': 13,
#  'phd': 1,
#  'piercedboobs': 1,
#  'piercing': 1,
#  'pizza': 1,
#  'platforms': 1,
#  'plumber': 1,
#  'plumbers': 1,
#  'plumbing': 1,
#  'plutocracy': 1,
#  'pmcaresfund': 1,
#  'pmoindia': 1,
#  'podcast': 1,
#  'podesta': 1,
#  'podestaart': 1,
#  'politics': 1,
#  'pork': 1,
#  'portfolio': 1,
#  'positive': 1,
#  'power9': 1,
#  'prayerwarrior': 1,
#  'prayfortheworld': 1,
#  'praytogether': 1,
#  'presidents': 1,
#  'pridemonth': 1,
#  'prints': 1,
#  'prohibitoryorder': 1,
#  'propaganda': 1,
#  'prosurvival': 1,
#  'pubs': 1,
#  'quarantine': 1,
#  'rajasthan': 28,
#  'ranchi': 1,
#  'raquelespuelas': 1,
#  'realestate': 1,
#  'recovered': 28,
#  'recovery': 2,
#  'recoveryloanscheme': 1,
#  'recoveryposse': 1,
#  'rehab': 1,
#  'remdesivir': 1,
#  'remotework': 1,
#  'rentassistance': 1,
#  'reopen': 1,
#  'repairs': 1,
#  'research': 2,
#  'researcher': 1,
#  'reseda': 1,
#  'resilience': 2,
#  'restaurant': 1,
#  'retailstrends': 1,
#  'retirement': 1,
#  'returntooffice': 8,
#  'rhoc': 1,
#  'riots': 1,
#  'riseup': 1,
#  'riskmanagement': 1,
#  'rls': 1,
#  'robots': 1,
#  'rotary': 1,
#  'rules': 1,
#  'rwot': 1,
#  'sales': 1,
#  'sanfernandovalley': 1,
#  'sanitization': 1,
#  'sanitizer': 1,
#  'sarscov2': 3,
#  'satire': 1,
#  'saudiarabia': 1,
#  'school': 1,
#  'schoolofmedicine': 1,
#  'scoliosis': 1,
#  'scotland': 1,
#  'scottishcommunities': 1,
#  'scotus': 1,
#  'searchengineoptimization': 1,
#  'seconddose': 1,
#  'secondwave': 1,
#  'sellingcontent': 1,
#  'seniorcitizen': 1,
#  'seostrategy': 1,
#  'service': 1,
#  'services': 1,
#  'sesamestreet': 1,
#  'shahsofsunset': 1,
#  'shg': 1,
#  'shibacharity': 2,
#  'shicha': 2,
#  'sicklecell': 1,
#  'sicklecellwarrior': 1,
#  'sicknotweak': 1,
#  'sierraleone': 1,
#  'smartbusiness': 1,
#  'smartnews': 1,
#  'smartvideo': 1,
#  'so': 2,
#  'soberaf': 1,
#  'socialdistance': 1,
#  'socialdistancing': 3,
#  'southkorean': 1,
#  'sph': 1,
#  'spirituality': 1,
#  'spiti': 1,
#  'splco': 2,
#  'sportsday': 1,
#  'ssi': 1,
#  'stayhome': 1,
#  'stayhomestaysafe': 1,
#  'staysafestayhome': 1,
#  'staythefhome': 1,
#  'sterilization': 1,
#  'stewardmeme': 1,
#  'strep': 1,
#  'student': 1,
#  'students': 1,
#  'successful': 1,
#  'sugardaddy': 1,
#  'suggarmommy': 1,
#  'superbugsuperhero': 1,
#  'supplychain': 1,
#  'support': 1,
#  'supportlocal': 1,
#  'supremecourt': 1,
#  'surgeon': 1,
#  'sushi': 1,
#  'sustainability': 2,
#  'sustainable': 1,
#  'takeaway': 1,
#  'takeawayfood': 1,
#  'takeout': 1,
#  'takeover': 1,
#  'takepoliticsoutofcovid': 1,
#  'tameside': 3,
#  'tarzana': 1,
#  'teachingtips': 1,
#  'techforgood': 1,
#  'technicals': 1,
#  'technology': 2,
#  'telangana': 1,
#  'temples': 1,
#  'testing': 2,
#  'texas': 2,
#  'thailand': 2,
#  'thermometer': 1,
#  'thirdwave': 7,
#  'tikaria': 1,
#  'timecover': 1,
#  'tiredofwaiting': 1,
#  'today': 1,
#  'tokyo2020': 1,
#  'toquedequeda': 1,
#  'torybrexit': 8,
#  'toughgame': 1,
#  'tourism': 5,
#  'trans': 1,
#  'transformationtuesday': 1,
#  'translation': 1,
#  'transparency': 1,
#  'transparencyiskey': 1,
#  'travel': 2,
#  'travelinsurance': 1,
#  'travelrestrictions': 1,
#  'trendingtonight': 7,
#  'trendlines': 1,
#  'trucking': 1,
#  'trump': 1,
#  'trumpcrimefamily': 1,
#  'trumpterroism': 1,
#  'truth': 1,
#  'truthbrigade': 1,
#  'tuesdayvibe': 1,
#  'turkey': 1,
#  'twitch': 1,
#  'udhr': 1,
#  'udupi': 1,
#  'udupicovidupdate': 1,
#  'uk': 3,
#  'ukgovernment': 1,
#  'ulcerativecolitis': 1,
#  'uniform': 1,
#  'unitedagainstcorona': 1,
#  'unitedstates': 1,
#  'university': 4,
#  'up': 1,
#  'update': 1,
#  'updated': 2,
#  'usa': 3,
#  'uttarpradesh': 1,
#  'utv': 1,
#  'vacation': 1,
#  'vaccina': 1,
#  'vaccinate': 1,
#  'vaccinated': 6,
#  'vaccination': 12,
#  'vaccination2021': 1,
#  'vaccinationdone': 1,
#  'vaccinationdrive': 1,
#  'vaccinationforall': 15,
#  'vaccinations': 2,
#  'vaccinationupdate': 15,
#  'vaccinationupdates': 1,
#  'vaccine': 52,
#  'vaccineconfident': 1,
#  'vaccineforall': 3,
#  'vaccines': 2,
#  'vaccinessavelives': 1,
#  'vaccineswork': 3,
#  'vannuys': 1,
#  'variant': 1,
#  'verified': 2,
#  'video': 1,
#  'vietnam': 1,
#  'virtuallearning': 2,
#  'virtualtrials': 1,
#  'virus': 2,
#  'visiting': 1,
#  'viva': 1,
#  'volunteer': 1,
#  'volunteering': 1,
#  'vote': 1,
#  'voteofnoconfidence': 1,
#  'wakedafuckup': 1,
#  'waspi': 1,
#  'webinar': 1,
#  'welfare': 1,
#  'wembley': 1,
#  'weshield': 6,
#  'westbengal': 2,
#  'westend': 1,
#  'westernprivilege': 1,
#  'westminster': 1,
#  'wfh': 4,
#  'whataboutweddings': 1,
#  'wherearethechildren': 1,
#  'who': 1,
#  'whodeemswhatnonessential': 1,
#  'wholetoadnewsservice': 1,
#  'whyisnooneready': 1,
#  'willtolive': 1,
#  'wipolitics': 2,
#  'wisconsin': 2,
#  'wiunion': 2,
#  'women': 1,
#  'workfromhome': 1,
#  'workingparent': 1,
#  'wuhan': 1,
#  'wuhanlab': 4,
#  'wuhanlableak': 1,
#  'yogiadityanath': 1,
#  'youtube': 2,
#  'yummy': 1,
#  '방탄소년단진': 1}

# %% [markdown]
# ## Hashtag EDA Covid19

# %%
covid19_hashtags = get_hashtags_list(tweet_covid19)
covid19_hashtags
# Out:
# {'30seconds': 1,
#  '3rdwave': 1,
#  '7dayavg': 2,
#  '7yearsofseva': 1,
#  'ab_healthandwellnesscentres': 1,
#  'abpoli': 1,
#  'accountabilityand': 2,
#  'actforequal': 1,
#  'afghan': 1,
#  'africa': 2,
#  'africancsossurvey': 1,
#  'africaunconstrained': 1,
#  'ai': 1,
#  'aif2021': 2,
#  'albertaforall': 1,
#  'allah': 1,
#  'amarnathyatra': 4,
#  'amazingproduct': 2,
#  'amazon': 1,
#  'america': 1,
#  'americans': 1,
#  'amerix': 1,
#  'amtz': 2,
#  'antimask': 1,
#  'anxious': 1,
#  'apocalypse': 1,
#  'armys': 1,
#  'artist': 1,
#  'arunachalpradesh': 1,
#  'asmano': 1,
#  'assam': 2,
#  'asıoldum': 1,
#  'auspol': 2,
#  'auspol2021': 1,
#  'autophagy': 1,
#  'awam': 1,
#  'awareness': 1,
#  'ayurvedic': 1,
#  'baby': 1,
#  'backtoschool': 1,
#  'bakerylife': 1,
#  'bakeryproducts': 1,
#  'bame': 1,
#  'banff': 1,
#  'bangkok': 1,
#  'bangladesh': 1,
#  'bbc': 1,
#  'bbcbreakfast': 2,
#  'bbmp': 1,
#  'bct': 1,
#  'beautiful': 1,
#  'before3rdwave': 21,
#  'beita': 1,
#  'bengalassemblyelections': 1,
#  'bengaluru': 2,
#  'berlin': 1,
#  'biden': 1,
#  'bihar': 2,
#  'biontech': 1,
#  'bioweapon': 1,
#  'bjpliesindiacries': 1,
#  'blackfungus': 1,
#  'blacklivesmatter': 1,
#  'blackowned': 2,
#  'blob2323': 3,
#  'book': 1,
#  'booster': 1,
#  'border': 1,
#  'borisjohnson': 1,
#  'boristheliar': 1,
#  'breadlover': 1,
#  'breaking': 2,
#  'breakingnews': 4,
#  'brexitshambles': 1,
#  'budget2021': 1,
#  'burnout': 1,
#  'bushcraft': 1,
#  'c': 4,
#  'c37pango': 1,
#  'cadila': 1,
#  'caexams': 1,
#  'canada': 1,
#  'cancelboardexam2021': 1,
#  'canceluniversityexam2021': 1,
#  'canonphotography': 1,
#  'carialox': 1,
#  'catherinekasavuli': 1,
#  'cba': 1,
#  'ccpvirus': 1,
#  'centralgovt': 1,
#  'chandrotomar': 1,
#  'charity': 1,
#  'chennaicorporation': 1,
#  'childmarriage': 2,
#  'china': 6,
#  'choosetovaccinate': 1,
#  'christianity': 1,
#  'climateactio': 1,
#  'climatechange': 1,
#  'closeapp': 6,
#  'cm': 1,
#  'co': 7,
#  'coffee': 1,
#  'cognitive': 1,
#  'commentary': 1,
#  'concerns': 1,
#  'congo': 4,
#  'congrats': 1,
#  'congress': 1,
#  'copaamerica': 1,
#  'corona': 2,
#  'coronavaccine': 2,
#  'coronavirus': 22,
#  'coronavirusoutbreak': 1,
#  'coronavirusupdates': 2,
#  'coronawarriors': 1,
#  'corruption': 2,
#  'cov': 1,
#  'covax': 2,
#  'covaxin': 1,
#  'covi': 4,
#  'covid': 12,
#  'covid19': 600,
#  'covid19ab': 1,
#  'covid19ind': 1,
#  'covid19india': 6,
#  'covid19indiahelp': 1,
#  'covid19outbreak': 1,
#  'covid19vaccinati': 1,
#  'covid19vaccination': 3,
#  'covid19vaccine': 5,
#  'covid19vaccines': 1,
#  'covid19vic': 2,
#  'covid3rdwave': 1,
#  'covid_19': 4,
#  'covid_patients': 1,
#  'covidappropriatebehaviour': 1,
#  'covidcarehospital': 1,
#  'covidemergency': 1,
#  'covidhelp': 1,
#  'covidhoax': 1,
#  'covidreliefforindia': 1,
#  'covidshield': 1,
#  'covidupdate': 1,
#  'covidvac': 1,
#  'covidvacccine2021': 1,
#  'covidvaccination': 11,
#  'covidvaccine': 5,
#  'covidー19': 1,
#  'covigyaan': 1,
#  'covishieldvaccine': 1,
#  'cowin': 53,
#  'cowinapp': 1,
#  'cowinregistration': 1,
#  'creamcake': 1,
#  'crime': 2,
#  'crisesmanager': 1,
#  'crisis': 1,
#  'crowdfunding': 1,
#  'csjmu': 1,
#  'currentnews': 1,
#  'customizedwork': 1,
#  'cvc': 1,
#  'dailynews': 1,
#  'dailyupdate': 2,
#  'deaths': 2,
#  'debt': 4,
#  'delicious': 1,
#  'delta': 1,
#  'deltaplusvariant': 3,
#  'deltavariant': 68,
#  'demand': 1,
#  'dengue': 1,
#  'departmentofmedicalservices': 1,
#  'deputy': 1,
#  'died': 1,
#  'diesel': 1,
#  'digitallending': 1,
#  'discovery': 1,
#  'disinformation': 1,
#  'distribution': 1,
#  'dms': 1,
#  'doctors': 2,
#  'dontcensorme': 1,
#  'dontsufferalone': 1,
#  'dushyantchautala': 1,
#  'ecf': 1,
#  'ecommerce': 1,
#  'egypt': 1,
#  'elderly': 1,
#  'emergency': 1,
#  'endfearmongering': 1,
#  'enough': 1,
#  'enoughisenough': 1,
#  'entrepreneur': 1,
#  'equitycrowdfund': 1,
#  'eu': 1,
#  'euco': 2,
#  'euro2020': 1,
#  'expertspeak': 1,
#  'eyemitra': 1,
#  'facemask': 2,
#  'facemasks': 2,
#  'facemasktime': 1,
#  'faith': 1,
#  'false': 1,
#  'fauciliedpeopledied': 1,
#  'faucipandemic': 1,
#  'fda': 1,
#  'fearmongering': 1,
#  'fijinews': 1,
#  'filmcitymumbai': 2,
#  'finance': 1,
#  'fintech': 1,
#  'fintechnews': 1,
#  'fintechstartup': 1,
#  'fintechsurvey': 1,
#  'firstnations': 2,
#  'follow': 1,
#  'food': 1,
#  'foodstagram': 1,
#  'free': 2,
#  'freelancer': 1,
#  'freepalestine': 1,
#  'funding': 1,
#  'fundraiser': 1,
#  'g7': 3,
#  'gac': 1,
#  'generationequality': 1,
#  'getvaccinated': 1,
#  'getvaccinatedasap': 1,
#  'ghanaiantimes': 1,
#  'gifts': 1,
#  'gitplus': 1,
#  'globalgoals': 1,
#  'gmb': 1,
#  'god': 1,
#  'graduation2021': 1,
#  'greendeal': 3,
#  'gtnews': 1,
#  'gtnewstoday': 1,
#  'gucci': 1,
#  'guwahati': 1,
#  'handbag': 1,
#  'happy': 1,
#  'happybirthdaythalapathy': 3,
#  'haryana': 2,
#  'health': 3,
#  'healthandwellness': 1,
#  'healthcare': 1,
#  'healthiswealth': 1,
#  'healthminister': 2,
#  'healthyeating': 1,
#  'healthyfood': 1,
#  'healthylifestyle': 1,
#  'heaven': 1,
#  'hell': 1,
#  'help': 1,
#  'helppeople': 1,
#  'hiring': 1,
#  'historic': 1,
#  'hope': 1,
#  'hospital': 1,
#  'htcoviddispatch': 1,
#  'humanity': 1,
#  'hungary': 2,
#  'icai': 1,
#  'iiitd': 1,
#  'iitd': 1,
#  'illegal': 1,
#  'immigration': 1,
#  'immunology': 1,
#  'imrankhanonhbo': 1,
#  'india': 15,
#  'indiafightsc': 1,
#  'indiafightscorona': 22,
#  'indiafightscovid19': 1,
#  'indian': 2,
#  'indianarmy': 9,
#  'indonesia': 1,
#  'indore': 2,
#  'infodemic': 1,
#  'information': 1,
#  'inspiration': 1,
#  'instagram': 1,
#  'internationaldayofyoga': 2,
#  'internationalyogaday2021': 1,
#  'inthistogether': 2,
#  'islam': 2,
#  'islamic': 1,
#  'israel': 1,
#  'itanagar': 1,
#  'itv': 1,
#  'jammuandkashmir': 1,
#  'jk': 1,
#  'jkia': 1,
#  'johnsonvariant': 1,
#  'joy': 2,
#  'joynews': 1,
#  'joytrain': 2,
#  'judaism': 1,
#  'justice': 1,
#  'kannada': 1,
#  'karnataka': 1,
#  'kashmir': 1,
#  'kayburley': 2,
#  'kigali': 1,
#  'kindness': 2,
#  'knowledge': 1,
#  'kritagyata': 1,
#  'kupwara': 1,
#  'kupwaraterriers': 1,
#  'lambdavariant': 1,
#  'largestvaccinationdrive': 4,
#  'largestvaccinedrive': 2,
#  'learn': 1,
#  'light': 2,
#  'like': 1,
#  'live': 3,
#  'liverpool': 5,
#  'lockdown': 3,
#  'longcovid': 1,
#  'love': 5,
#  'lungs': 1,
#  'madhyapradesh': 2,
#  'mankind': 1,
#  'mask': 1,
#  'masker': 1,
#  'maskless': 1,
#  'masks': 1,
#  'maskup': 2,
#  'me': 1,
#  'media': 18,
#  'medical': 1,
#  'medicine': 1,
#  'medtechzone': 1,
#  'medtwitter': 1,
#  'men': 1,
#  'menangbersama': 2,
#  'mentalhealth': 3,
#  'mentalhealthmatters': 1,
#  'ministryofpublichealth': 2,
#  'moderna': 1,
#  'modi': 18,
#  'modivirus': 1,
#  'monitorupdates': 1,
#  'motivation': 1,
#  'movid': 1,
#  'mucormycosis': 1,
#  'mumb': 1,
#  'muslim': 1,
#  'mwc21': 1,
#  'nadra': 1,
#  'nationalselfieday': 1,
#  'nature': 1,
#  'nbsliveat9': 1,
#  'ncoc': 2,
#  'neuroimaging': 1,
#  'newcases': 4,
#  'newcastle': 2,
#  'newdelhi': 1,
#  'news': 6,
#  'newsmove': 1,
#  'newsonline': 2,
#  'newstoday': 1,
#  'newworldorder': 1,
#  'ngo': 1,
#  'nhs': 3,
#  'nhsheros': 1,
#  'ninaandnana': 1,
#  'no': 1,
#  'noble': 1,
#  'nogreatreset': 1,
#  'nonprofits': 1,
#  'norfolkfoodbloggers': 1,
#  'norwich': 1,
#  'norwichfood': 1,
#  'norwichlife': 1,
#  'notfaironkids': 1,
#  'nursing': 1,
#  'nytimes': 1,
#  'o': 6,
#  'odisha': 2,
#  'opinion': 1,
#  'orphanages': 1,
#  'oxygen': 9,
#  'oxygeninfrastructure': 1,
#  'p': 3,
#  'pakholdsafghanpeace': 1,
#  'pakistan': 1,
#  'palestine': 1,
#  'pandemic': 7,
#  'pandemicpanda': 1,
#  'pangoc37': 1,
#  'panty': 1,
#  'parenting': 1,
#  'patient': 1,
#  'peace': 1,
#  'penang': 1,
#  'people': 2,
#  'petrol': 1,
#  'pfizer': 1,
#  'pharmafundas': 1,
#  'photograghy': 1,
#  'photography': 1,
#  'photooftheday': 2,
#  'phys': 1,
#  'pib': 1,
#  'picoftheday': 1,
#  'plagueisland': 1,
#  'pm': 2,
#  'pmm': 2,
#  'poland': 2,
#  'policy': 1,
#  'polio': 1,
#  'ponzi': 2,
#  'poovachalkhader': 1,
#  'positivenews': 3,
#  'postdoc': 1,
#  'precaution': 1,
#  'prevention': 1,
#  'privatelaboratories': 1,
#  'profession': 1,
#  'psl6': 1,
#  'public': 1,
#  'publichealth': 1,
#  'puducherry': 1,
#  'pulangahalli': 1,
#  'pune': 52,
#  'punishment': 1,
#  'pupils': 2,
#  'purse': 1,
#  'qatar': 1,
#  'quran': 1,
#  'rahulexposesmodigovt': 1,
#  'rahulgandhi': 28,
#  'rakeshjhunjhunwala': 1,
#  'rankin': 1,
#  'rankinarchive': 1,
#  'rapeapolo': 1,
#  'rapeapologistselectedpm': 1,
#  'rathajatra': 1,
#  'rbi': 1,
#  'recall': 1,
#  'recovery': 1,
#  'recruitmentprocess': 1,
#  'refugee': 1,
#  'religion': 1,
#  'reopening': 1,
#  'rescueme': 1,
#  'restrictions': 1,
#  'rip': 1,
#  'rippoovachalkhader': 1,
#  'roadsafety': 1,
#  'rta': 1,
#  'rules': 1,
#  'rwot': 1,
#  's': 2,
#  'sabcnews': 1,
#  'salsa': 1,
#  'sandrasturm': 1,
#  'sanitizer': 1,
#  'sars': 1,
#  'sarscov2': 1,
#  'saudiarabia': 1,
#  'savebeita': 1,
#  'savenaslatower': 1,
#  'savepalestine': 1,
#  'secondwave': 14,
#  'seenonsharktank': 2,
#  'selangor': 4,
#  'shafqatmehmood': 2,
#  'shameonpta': 1,
#  'share': 1,
#  'shibpur': 1,
#  'showusthevirus': 1,
#  'sinovac': 1,
#  'slovenia': 2,
#  'sluggate': 2,
#  'smile': 1,
#  'socialdistancing': 1,
#  'socialprotection': 1,
#  'sold': 1,
#  'southafrica': 2,
#  'srilanka': 2,
#  'srinagar': 1,
#  'startup': 1,
#  'startups': 3,
#  'stayhome': 3,
#  'staysafe': 5,
#  'stopthespread': 1,
#  'studentloan': 1,
#  'supportlocal': 1,
#  'survey': 1,
#  'survival': 2,
#  'survive': 1,
#  'taiwan': 4,
#  'taiwancanhelp': 1,
#  'tamil': 1,
#  'tanzania': 1,
#  'taridalu': 1,
#  'tbt': 1,
#  'teammanoj': 1,
#  'teenagepregnancy': 2,
#  'telangana': 2,
#  'telegrap': 5,
#  'testing': 1,
#  'testresult': 1,
#  'thailand': 5,
#  'thailandnews': 1,
#  'thankyou': 1,
#  'themail': 1,
#  'thenationthailand': 1,
#  'theoneshow': 1,
#  'thirdwave': 3,
#  'thirdwavecovid': 1,
#  'thisiskbc': 1,
#  'tikamahaabhiyan': 1,
#  'tinsukia': 1,
#  'today': 1,
#  'torycorruption': 1,
#  'toys': 1,
#  'toystory': 1,
#  'toystory4': 1,
#  'transformingurbanlandscape': 1,
#  'travel': 2,
#  'treatment': 1,
#  'trumpvirus': 1,
#  'truthdecay': 1,
#  'tsai': 1,
#  'tsaivirus': 1,
#  'tuesdayfeeling': 1,
#  'tuesdaymotivations': 1,
#  'tuesdayvibe': 1,
#  'uae': 1,
#  'uber': 1,
#  'uganda': 2,
#  'uk': 1,
#  'understand': 1,
#  'unite2fightcorona': 5,
#  'unitedstates': 1,
#  'unlock': 1,
#  'unputdownable': 5,
#  'unv_india': 2,
#  'unvaccinated': 1,
#  'up': 3,
#  'update': 2,
#  'usa': 1,
#  'usians': 1,
#  'usm': 1,
#  'uttarpradesh': 1,
#  'vaccinate': 1,
#  'vaccinated': 3,
#  'vaccination': 5,
#  'vaccinationdrive': 4,
#  'vaccinations': 2,
#  'vaccine': 67,
#  'vaccinechor': 1,
#  'vaccineforall': 1,
#  'vaccinepune': 52,
#  'vaccines': 5,
#  'vaccinetrial': 1,
#  'vaccinewastage': 1,
#  'vaksinasicovid19': 1,
#  'variants': 1,
#  'vaxaware': 1,
#  'vforce': 1,
#  'virologists': 1,
#  'virus': 1,
#  'voice': 1,
#  'volunteers': 2,
#  'we4vaccine': 4,
#  'wearamask': 2,
#  'wearamasksavealife': 1,
#  'webinar': 1,
#  'westernnavalcommand': 1,
#  'whitecollarcrime': 2,
#  'whitepaper': 22,
#  'wholesale': 1,
#  'world': 1,
#  'wsjtechlive': 1,
#  'wuhan': 2,
#  'xenophobia': 1,
#  'yeg': 1,
#  'yoga': 9,
#  'youlead20': 1,
#  'youth': 1,
#  'yyc': 1,
#  'zambia': 2,
#  'ا': 1,
#  'انقذوا_بيتا': 1,
#  'انقذوا_حي_الشيخ_جراح': 1,
#  'فلسطين': 1,
#  'مقاطعه_المنتجات_الفرنسيه238': 1,
#  'กรมการแพทย': 1,
#  'ข': 3,
#  'พบผ': 2,
#  'โคว': 5,
#  '𝑪𝑶𝑽𝑰𝑫19': 3}

# %% [markdown]
# ## Hashtag EDA Virus

# %%
virus_hashtags = get_hashtags_list(tweet_virus)
virus_hashtags
# Out:
# {'covid19': 231,
#  'worldhealthorganization': 2,
#  'virus': 724,
#  'euro2021': 2,
#  'mosquitoes': 1,
#  'israel': 1,
#  'vquiz': 1,
#  'magnetism': 1,
#  'nanotech': 1,
#  'spikeprotein': 3,
#  'germtheory': 1,
#  'virology': 4,
#  'pcr': 2,
#  'postapocalyptic': 6,
#  'corona': 41,
#  'covid2019': 5,
#  'coronavirus': 110,
#  'canada': 4,
#  'covid19canada': 6,
#  'coronaviruscanada': 4,
#  'coronavirusfinland': 4,
#  'covid19fi': 4,
#  'canadacoronavirus': 5,
#  'covidー19': 5,
#  'covid19finland': 5,
#  'epidemic': 10,
#  'covid__19': 4,
#  'finland': 4,
#  'covid2019finland': 3,
#  'finlandcoronavirus': 3,
#  'koronafi': 3,
#  'wuhan': 67,
#  'meateatersvirus': 2,
#  'pandemics': 3,
#  'force': 2,
#  'health': 29,
#  'pentagon': 2,
#  'conflict': 1,
#  'disease': 11,
#  'emergency': 1,
#  'employees': 1,
#  'military': 1,
#  'pandemic': 63,
#  'personalprotectiveequipment': 1,
#  'publichealth': 9,
#  'secretary': 1,
#  'vaccination': 23,
#  'vegan': 1,
#  'phage': 2,
#  'bioinformatics': 1,
#  'microbiology': 2,
#  'uv': 3,
#  'bacteria': 5,
#  'vir': 1,
#  'india': 71,
#  'deltavariant': 49,
#  'coronavirusupdates': 3,
#  'tracking': 1,
#  'tracing': 1,
#  'dgi': 5,
#  'government': 13,
#  'information': 5,
#  'department': 5,
#  'srilanka': 5,
#  'staysafe': 12,
#  'socialdistan': 1,
#  'birmingham': 11,
#  'smallbusi': 6,
#  'covid': 84,
#  'gbd': 1,
#  'suspense': 5,
#  'occult': 3,
#  'supernatural': 3,
#  'scifi': 4,
#  'vaccine': 69,
#  'thementors': 1,
#  'socialdistancing': 10,
#  'gates': 1,
#  'who': 7,
#  'smallbusiness': 5,
#  'brumhour': 5,
#  'malware': 25,
#  'ransomware': 15,
#  'phishing': 7,
#  'cryptomining': 3,
#  'trojan': 4,
#  'security': 8,
#  'identitytheft': 3,
#  'privacy': 8,
#  'smallbizbritain2021': 3,
#  'largestvaccinedrive': 2,
#  'fakesnews': 2,
#  'google': 34,
#  'daszak': 22,
#  'vaccins': 22,
#  'vaccines': 56,
#  'nft': 2,
#  'nfts': 2,
#  'cryptoart': 2,
#  'nftart': 3,
#  'nftartist': 3,
#  'nftcollecto': 1,
#  'euopean': 1,
#  'airborne': 3,
#  'europe': 1,
#  'world': 8,
#  'nftcollector': 1,
#  'nftcommunity': 1,
#  'digitalart': 1,
#  'artist': 1,
#  'animation': 3,
#  'c4d': 1,
#  '3d': 1,
#  'loop': 1,
#  'quarantine': 18,
#  'art': 3,
#  'satisfying': 1,
#  'nftbmarket': 1,
#  'bnb': 1,
#  'binance': 1,
#  'binancenft': 1,
#  'render': 1,
#  'waltdisneyworld': 1,
#  'dresscode': 1,
#  'giftcard': 1,
#  'disneysanimalkingdom': 1,
#  'thewaltdisneycompany': 1,
#  'dailynewsandanalysis': 1,
#  'ist': 1,
#  'flu': 6,
#  'shot': 1,
#  'covid_19': 12,
#  'astrazeneca': 2,
#  'endgame': 1,
#  'lightattheendofthetunnel': 1,
#  'endpandemic': 1,
#  'scienceismagicthatworks': 1,
#  'homeoffice': 1,
#  'insidezalando': 1,
#  'zalando': 1,
#  'dortmund': 1,
#  'wewillhugagain': 1,
#  'stayhealthy': 1,
#  'activistsofoptimism': 1,
#  'lies': 1,
#  'rt': 2,
#  'viruswaanzin': 2,
#  'coronavirusuk': 2,
#  'home': 5,
#  'china': 61,
#  'think': 5,
#  'flatcurvechallenge': 5,
#  'gainoffunction': 1,
#  'genetics': 2,
#  'biotech': 1,
#  'treatments': 1,
#  'university_of_illinois': 1,
#  'chicago': 1,
#  'graphene': 1,
#  'sars_cov_2': 1,
#  'statnano': 1,
#  'nanotechnology': 1,
#  'nbic': 1,
#  'nagaland': 3,
#  'bat': 3,
#  'thaisacbrood': 1,
#  'honeybee': 1,
#  'bees': 1,
#  'apiary': 1,
#  'dis': 1,
#  'immunity': 3,
#  'makeithappen': 1,
#  'worldnewsguest': 2,
#  'virologist': 2,
#  'delta': 5,
#  'transmissibility': 1,
#  'protection': 3,
#  'poland': 1,
#  'worldin': 1,
#  'gasoline': 1,
#  'coronavirusindia': 1,
#  'fuel': 1,
#  'coron': 1,
#  'lockdowns': 5,
#  'milesguo': 4,
#  'gettr': 4,
#  'dr_sellin': 3,
#  'ccp': 76,
#  'release': 3,
#  'cbs': 1,
#  'microbiome': 1,
#  'facemasks': 3,
#  'reusable': 2,
#  'washable': 2,
#  'lnp': 3,
#  'fuellmich': 1,
#  'vi': 2,
#  'pneumonia': 2,
#  'sarscov2': 10,
#  'dissertation': 1,
#  'phd': 1,
#  'survey': 2,
#  'surveycircle': 1,
#  'meded': 1,
#  'cmv': 4,
#  'pregnancy': 4,
#  'pediatri': 3,
#  'jabbed': 2,
#  'brits': 2,
#  'isolate': 2,
#  'infection': 5,
#  'mutation': 2,
#  'variant': 5,
#  'tb': 1,
#  'italy': 6,
#  'gesù': 3,
#  'italian': 3,
#  'eu': 3,
#  'dio': 3,
#  'italycoronavirus': 3,
#  'fear': 4,
#  'cristo': 4,
#  'coronavirusitalia': 4,
#  'italiancov': 1,
#  'wmf2021': 3,
#  'indianarmy': 2,
#  'training': 2,
#  'fight': 2,
#  'lottiefiles': 4,
#  'lottie': 4,
#  'lottieanimation': 4,
#  'lottieanimatio': 1,
#  'lockdown': 24,
#  'influenza': 4,
#  'doctor': 18,
#  'stayhome': 7,
#  'healthcare': 13,
#  'immunization': 1,
#  'lottieanimations': 3,
#  'animations': 2,
#  'prevention': 2,
#  'temprature': 2,
#  'motiongraphics': 2,
#  'animate': 2,
#  'aftereffects': 2,
#  'diarrhea': 2,
#  'breathe': 2,
#  'nswpol': 2,
#  'economic': 1,
#  'trump': 7,
#  'communist': 1,
#  'biowarfare': 1,
#  'freeworld': 1,
#  'auspol': 3,
#  'washyourhan': 1,
#  'italiancovid': 3,
#  'italycovid': 3,
#  'vangelo': 3,
#  'paura': 3,
#  'chiesa': 2,
#  'cristianesimo': 2,
#  'washyourhands': 4,
#  'handwash': 4,
#  'staysafestayhome': 4,
#  'chholabhatura': 1,
#  'chhola': 1,
#  'dosa': 1,
#  'paneerdosa': 1,
#  'bhatura': 1,
#  'gajak': 1,
#  'happy': 1,
#  'enjoy': 1,
#  'party': 1,
#  'food': 2,
#  'delicious': 1,
#  'yummy': 1,
#  'thesecretwar': 3,
#  'unite2fightcorona': 1,
#  'birthday': 1,
#  'wedding': 1,
#  'burger': 1,
#  'milk': 1,
#  'milkcake': 1,
#  'covinconspiracy': 1,
#  'shanghai': 1,
#  'shaitansubzimandi': 1,
#  'mask': 2,
#  'nipahvirus': 2,
#  'maharashtra': 4,
#  'nationalinstituteofvirology': 1,
#  'pune': 1,
#  'mahabaleshwar': 1,
#  'transmission': 2,
#  'outbreak': 6,
#  'wearamask': 2,
#  'kingfappe': 1,
#  'kingfaindia': 1,
#  'kingfamasks': 1,
#  'respiratoryprotection': 1,
#  'breathecleanair': 1,
#  'pollution': 1,
#  'pullutants': 1,
#  'harmfulparticles': 1,
#  'masks': 4,
#  'adverrisements': 1,
#  'chdxkin': 1,
#  'qrcode': 1,
#  'superspreaders': 1,
#  'followtheleader': 1,
#  'wednesdaythought': 1,
#  'jk': 1,
#  'covid19nsw': 1,
#  'covidiots': 11,
#  'vaccinated': 10,
#  'indianexpress': 1,
#  'socialdistance': 1,
#  'c': 7,
#  'animals': 4,
#  'comedy': 2,
#  'coronaviruslockdown': 1,
#  'film': 3,
#  'fun': 1,
#  'funnyvideo': 3,
#  'indie': 3,
#  'parody': 1,
#  'shortfilm': 3,
#  'webseries': 3,
#  'uppcare': 1,
#  'africa': 6,
#  'fauci': 10,
#  'billgates': 5,
#  'reward': 1,
#  'unemployment': 1,
#  'stupidtweets': 1,
#  'silverstream': 1,
#  'aeroduct': 1,
#  'safety': 3,
#  'indicanews': 1,
#  'siliconvalley': 1,
#  'ceo': 1,
#  'gopimattel': 1,
#  'variants': 6,
#  'cdc': 2,
#  'alexander': 1,
#  'covid19vaccine': 1,
#  'viral': 2,
#  'covid19death': 1,
#  'adelaide': 1,
#  'auckland': 1,
#  'chamberofcommerce': 1,
#  'commerce': 1,
#  'community': 1,
#  'industry': 1,
#  'northernterritory': 1,
#  'queensland': 1,
#  'tasmania': 1,
#  'tassie': 1,
#  'victoria': 1,
#  'prc': 1,
#  'fortdetrick': 1,
#  'wuhanlab': 4,
#  'etb': 1,
#  'president': 3,
#  'whitehouse': 3,
#  'encryption': 1,
#  'decryption': 1,
#  '100daysofcode': 1,
#  'malwa': 1,
#  'pediatric': 1,
#  'hearingloss': 1,
#  'cmvawarenessmonth': 1,
#  'stopcmv': 1,
#  'screen4cmv': 1,
#  'wordpress': 3,
#  'woocommerce': 2,
#  'malicious': 5,
#  'fiverr': 2,
#  'freelancers': 1,
#  'indian': 2,
#  'assholes': 1,
#  'poshmark': 1,
#  'fashion': 2,
#  'style': 1,
#  'shopmycloset': 1,
#  'pinkvictoriassecret': 1,
#  'lulus': 1,
#  'covidorigin': 1,
#  'canberra': 1,
#  'echozulu': 1,
#  'webinar': 1,
#  'immunology': 1,
#  'registernow': 1,
#  'worldvaccinemeet2021': 1,
#  'immunesystem': 2,
#  'antibodies': 1,
#  'biotechnology': 2,
#  'deltaplusvariant': 2,
#  'mutationofcovid': 1,
#  'indiafightscorona': 3,
#  'kolkata': 2,
#  'westbengal': 2,
#  'news': 9,
#  'breakingnews': 4,
#  'dailynewskol': 2,
#  'dnk': 1,
#  'trending': 16,
#  'jokervirus': 3,
#  '64bittech': 1,
#  'polio': 1,
#  'free': 4,
#  'pandemia': 2,
#  'wecanbeheroes': 1,
#  'economycrisis': 2,
#  'hunger': 2,
#  'australia': 4,
#  'stayathome': 4,
#  'nipah': 1,
#  'nipahoutbreak': 1,
#  'nipahscare': 1,
#  'mahableshwar': 1,
#  'bats': 3,
#  'atal': 1,
#  'wave': 2,
#  'pollen': 11,
#  'isrgrajan': 3,
#  'wednesdaymotivation': 3,
#  'avianin': 2,
#  'avianinfluenza': 1,
#  'birdflu': 2,
#  'hpa1': 1,
#  'lpai': 1,
#  'atadistancespringisgreen': 1,
#  'covidvaccine': 2,
#  'funny': 4,
#  'wuhanlableak': 1,
#  'netspeed': 9,
#  'vpnapp': 10,
#  'cybercrime': 9,
#  'hacke': 3,
#  'hackers': 13,
#  'databreachs': 2,
#  'infosec': 4,
#  'netsec': 2,
#  'ios': 1,
#  'android': 4,
#  'hacker': 1,
#  'cybersecurity': 9,
#  'nordvpn': 2,
#  'cookies': 2,
#  'website': 4,
#  'socialmediatips': 2,
#  'online': 2,
#  'internet': 3,
#  'vpn': 3,
#  'bangladesh': 3,
#  'stocks': 4,
#  'investment': 4,
#  'pharmaceuticals': 1,
#  'bio': 1,
#  'media': 4,
#  'contagion': 2,
#  'blackmen': 1,
#  'public': 2,
#  'model': 1,
#  'rightwinmedias': 3,
#  'h10n3': 1,
#  '𝒟𝒾𝑒𝒷𝒪37': 2,
#  'birds': 3,
#  'signature': 1,
#  'wuhanflu': 1,
#  'uvfresh': 1,
#  'uvfreshergerm': 1,
#  'germ': 1,
#  'mold': 1,
#  'innovations': 1,
#  'ba': 1,
#  'updates': 2,
#  'coronavirusupdatetoday': 2,
#  'coronavirusupdatesindia': 2,
#  'coronavirusupdate': 2,
#  'indiacoronavirusupdate': 2,
#  'uttarpradesh': 2,
#  'lucknow': 2,
#  'zombeavers': 1,
#  'zombie': 3,
#  'mutants': 1,
#  'cabininthewoods': 1,
#  'chaos': 3,
#  'religion': 6,
#  'politics': 5,
#  'fiction': 5,
#  'korean': 2,
#  'pharmaceutica': 2,
#  'pcmr': 1,
#  'asean': 1,
#  'dengue': 9,
#  'indonesia': 2,
#  'idx': 1,
#  'hospitals': 1,
#  'med': 1,
#  'usb': 1,
#  'leradio': 2,
#  'trendy': 2,
#  'sp': 3,
#  'onmessage': 1,
#  'imdone': 1,
#  'enoughisenough': 1,
#  'fuckcovid': 1,
#  'sage': 1,
#  'businesstrip': 1,
#  'dubai': 1,
#  'deltavariante': 3,
#  'mentalhealth': 1,
#  'toolkit': 1,
#  'indianvariant': 1,
#  'chinese': 25,
#  'taiw': 22,
#  'psyop': 1,
#  'funded': 2,
#  'research': 2,
#  'scientist': 3,
#  'peterdaszak': 4,
#  'ecohealthalliance': 1,
#  'ccpvirus': 2,
#  'usa': 5,
#  'bigtech': 1,
#  'newsgang': 1,
#  'love': 3,
#  'bhfyp': 1,
#  'instagood': 1,
#  'instagram': 4,
#  'like': 1,
#  'follow': 1,
#  'photography': 2,
#  'dirumahaja': 1,
#  'd': 4,
#  'covidinindia': 4,
#  'vampire': 2,
#  'viru': 3,
#  'rich': 2,
#  'corporate': 1,
#  'hungers': 1,
#  'lockdown2021': 1,
#  'business': 1,
#  'wages': 1,
#  'covid19india': 4,
#  'stoplockdown': 1,
#  'pyramidschemes': 3,
#  'outreach': 3,
#  'freshrecruitment': 3,
#  'australian': 2,
#  'genome': 1,
#  'genomesequencing': 1,
#  'ministryofhealth': 2,
#  'newzealand': 1,
#  'nz': 1,
#  'sydney': 1,
#  'visit': 1,
#  'wellington': 1,
#  'vesicles': 3,
#  'political': 3,
#  'religious': 3,
#  'luggage': 1,
#  'airtravel': 1,
#  'airports': 1,
#  'deathsantis': 2,
#  'failure': 1,
#  'florida': 4,
#  'alabama': 1,
#  'covaxin': 1,
#  'jagamethanthiram': 1,
#  'dhanush': 1,
#  'clubhouse': 1,
#  'vijaytv': 1,
#  'foodie': 1,
#  'friends': 1,
#  'simbu': 1,
#  'vijaysethupath': 1,
#  'asia': 4,
#  'herpes': 3,
#  'simplex': 2,
#  'cancer': 3,
#  'silicon': 2,
#  'obama': 2,
#  'travel': 6,
#  'vacinate': 1,
#  'spam': 1,
#  'threathunting': 1,
#  'messagingsecurity': 1,
#  'sars': 1,
#  'willow': 1,
#  'didyouknow': 1,
#  'funfact': 1,
#  'cleaning': 1,
#  '1': 3,
#  'postapoc': 1,
#  'desantis': 1,
#  'doctors': 5,
#  'fungus': 1,
#  'blinded': 1,
#  'dead': 1,
#  'avtsm': 1,
#  'deaths': 2,
#  'mkt': 1,
#  'spread': 1,
#  'human': 2,
#  'desease': 1,
#  'money': 3,
#  'fakenews': 1,
#  'poor': 1,
#  'blind': 1,
#  'thermometer': 1,
#  'covidthermometer': 1,
#  'infodprtsl': 2,
#  'ebola': 4,
#  'persecution': 3,
#  'virusattenuation': 1,
#  'boycottchina': 1,
#  'chinaliedpeopledied': 13,
#  'chinavirus': 2,
#  'gadgets': 1,
#  'variety': 1,
#  'amazon': 5,
#  'ebook': 1,
#  'healthyaa': 1,
#  'cases': 1,
#  'testing': 1,
#  'flights': 1,
#  'today': 1,
#  'leicester': 1,
#  'study': 2,
#  'alliance': 1,
#  '2020election': 2,
#  'lableak': 3,
#  'capitalist': 3,
#  'unvacci': 2,
#  'usaid': 1,
#  'experiments': 1,
#  'georgecarlin': 1,
#  'control': 1,
#  'liberty': 1,
#  'truth': 2,
#  'thetr': 1,
#  'africanews': 1,
#  'coronavi': 1,
#  'science': 4,
#  'drama': 2,
#  'programming': 3,
#  'pentestin': 1,
#  'pentesting': 1,
#  'cyberattack': 1,
#  'bug': 2,
#  'worms': 1,
#  'hacking': 2,
#  'cyber': 1,
#  'threat': 1,
#  'kill': 10,
#  'medical': 10,
#  'made': 9,
#  'gujaratmail': 1,
#  'newsmail': 1,
#  'newspaper': 1,
#  '10thstd': 1,
#  'students': 1,
#  '12thstd': 1,
#  'educationboard': 1,
#  'highcout': 1,
#  'h1n1': 1,
#  '1977flu': 1,
#  'swineflu': 1,
#  'hepatitis': 1,
#  'kidney': 1,
#  'respiratory': 4,
#  'viruses': 1,
#  'aphids': 1,
#  'grasses': 1,
#  'pathogen': 2,
#  'grass': 1,
#  'vector': 1,
#  'diseaseecology': 1,
#  'ucl': 1,
#  'cartoon': 1,
#  'country': 2,
#  'balls': 1,
#  'countryballs': 1,
#  'countryballs2021': 1,
#  'country2021': 1,
#  'balls2021': 1,
#  'covidmountain': 1,
#  'finallyavaccine': 1,
#  'mountain': 1,
#  'shelterinplace': 1,
#  'wanking': 1,
#  'masturbation': 1,
#  'masturbating': 1,
#  'greetings': 1,
#  'trumpsamerica': 1,
#  'wrightcounty': 1,
#  'missouri': 1,
#  'white': 1,
#  'trumpier': 1,
#  'unvaccinated': 2,
#  'sick': 1,
#  'vaccineswork': 1,
#  'fewer_covid_cases': 3,
#  'haryana': 2,
#  'mucormycosis': 1,
#  'bioweapon': 1,
#  'expert': 3,
#  'probiotic': 1,
#  'gut': 1,
#  'invasion': 1,
#  'healthsaarthi': 2,
#  'covid19outbreak': 2,
#  'patients': 2,
#  'organically': 1,
#  'vaxed': 1,
#  'computervirus': 4,
#  'history': 2,
#  'computers': 2,
#  'worldwideweb': 1,
#  'cloud': 1,
#  'dental': 1,
#  'dentis': 1,
#  'covid_vaccines': 1,
#  'o': 1,
#  'cuarentena': 1,
#  'pcrtests': 1,
#  'olympics': 1,
#  'isolation': 2,
#  'tokyo2020': 1,
#  'painting': 3,
#  'excursionsjournal': 3,
#  'stepbystep': 3,
#  'abstractexpressionism': 3,
#  'abs': 1,
#  'educatiecibernetica': 1,
#  'romania': 1,
#  'plots': 26,
#  'taiwan': 29,
#  'abstractexpressionist': 1,
#  'stepbysteppainting': 1,
#  '6fish': 1,
#  'exsjournalexhibition': 1,
#  'achinkoflight': 1,
#  'humanity': 1,
#  'daybyday': 2,
#  'officials': 2,
#  'gop': 3,
#  'sycophants': 2,
#  'trumpvirus': 1,
#  'rondesantis': 1,
#  'botched': 1,
#  'malwareremoval': 1,
#  'wordpresssecurity': 2,
#  'clean': 1,
#  'hackedwebsite': 1,
#  'jockermalware': 1,
#  'apps': 2,
#  'googleplaystore': 1,
#  'guinea': 1,
#  'respiratorytherapy': 1,
#  'copd': 1,
#  'respiratorytherap': 1,
#  'longhauler': 1,
#  'n95': 1,
#  'filter': 1,
#  'twitter': 1,
#  'tech': 2,
#  'zoonosis': 1,
#  'zoonotic': 1,
#  'bacterium': 1,
#  'parasite': 1,
#  'prion': 1,
#  'gcc': 1,
#  'obfs': 1,
#  'obfuscation': 2,
#  'developer': 1,
#  'ethicalhacking': 1,
#  'polymorphic': 1,
#  'fingerprint': 1,
#  'ramsoware': 1,
#  'pakistani': 1,
#  'digital': 1,
#  'futuregrace': 1,
#  'faith': 1,
#  'hope': 9,
#  'christ': 1,
#  'jesus': 1,
#  'hungary': 1,
#  'tomato': 1,
#  'farm': 1,
#  'agriculture': 1,
#  'memes': 1,
#  'vtuber': 1,
#  'vtube': 1,
#  'thriller': 2,
#  'murder': 2,
#  'crime': 2,
#  'mysuru': 1,
#  'karnataka': 1,
#  'children': 2,
#  'social': 1,
#  'herdimmunity': 5,
#  'socialcare': 5,
#  'guangzhou': 1,
#  'delivery': 1,
#  'guangdong': 1,
#  'conspiracytheories': 2,
#  'mac': 1,
#  'apple': 1,
#  'dat': 4,
#  'transmissible': 1,
#  'jabdone': 1,
#  'reasonstogetvaccine': 1,
#  'androidapps': 1,
#  'playstore': 1,
#  'technology': 2,
#  'technews': 1,
#  'infectiousdiseases': 3,
#  'remapcapfamily': 1,
#  'zika': 1,
#  'geimpfte': 4,
#  'mutationen': 4,
#  'ungeimpfte': 4,
#  'covid19de': 2,
#  'wearafuckingmask': 2,
#  'wealth': 1,
#  'finance': 1,
#  'scomo': 1,
#  'ausgov': 1,
#  'worldhealth': 1,
#  'wfh': 1,
#  'restrictions': 1,
#  'covidvaccination': 5,
#  'healthforall': 1,
#  'jibjab': 1,
#  'russia': 2,
#  'origin': 3,
#  'modi': 2,
#  'covidcases': 1,
#  'pakistan': 5,
#  'fifthdeck': 1,
#  'publicpolicy': 1,
#  'animalsandwildlife': 1,
#  'wwf': 1,
#  'risks': 1,
#  'buddhist': 1,
#  'second': 1,
#  'sweep': 1,
#  'monasteries': 1,
#  'hailmary': 1,
#  'avemaria': 1,
#  'coronavirusvariants': 1,
#  'medicine': 5,
#  'exclusive': 1,
#  'clothes': 1,
#  'sitapur': 2,
#  'sitapurmarket': 1,
#  'unique': 1,
#  'kids': 1,
#  'kidswear': 1,
#  'winter': 1,
#  'football': 2,
#  'nhs': 2,
#  'question': 2,
#  'mazerunner': 2,
#  'ninaandnana': 8,
#  'covid19vaccination': 2,
#  'sold': 2,
#  'madewithunity': 1,
#  'videogame': 1,
#  'biology': 1,
#  'gamersunite': 1,
#  'indiedev': 1,
#  'gamedev': 1,
#  'letsplay': 1,
#  'unity3d': 1,
#  'retrogamer': 1,
#  'indiegame': 1,
#  'win': 1,
#  'gamergirl': 1,
#  'supportsmallstreamers': 1,
#  'pcgamer': 1,
#  'atagi': 1,
#  'blood': 1,
#  'commonwealth': 1,
#  'death': 1,
#  'departmentofhealth': 1,
#  'headache': 1,
#  'olderpeople': 1,
#  'outcomes': 2,
#  'pfizer': 2,
#  'fitnortheast': 1,
#  'healthy': 2,
#  'wellness': 1,
#  'fitness': 1,
#  'northeast': 1,
#  'hpylori': 1,
#  'northeastindia': 1,
#  'shycocan': 1,
#  'advertisement': 1,
#  'southasia': 1,
#  'times': 1,
#  'caused': 1,
#  'timesofindia': 1,
#  'management': 1,
#  'biologicalwarfare': 1,
#  'braininjury': 1,
#  'inflammation': 2,
#  'supplements': 2,
#  'lyprinol': 1,
#  'curcumin': 1,
#  'decreased': 1,
#  'casualties': 1,
#  'indiafightscovid19': 1,
#  'kolkatacovid': 1,
#  'evolution': 3,
#  'alpha': 1,
#  'typesofcovidtests': 1,
#  'coronatest': 1,
#  'covidtest': 1,
#  'pcrtest': 1,
#  'covidtesting': 1,
#  'beaware': 1,
#  'covid2020': 2,
#  'maps': 1,
#  'onlinemap': 1,
#  'mapping': 1,
#  'googlemaps': 1,
#  'mapmaker': 1,
#  'covidpatients': 1,
#  'vacantbedsforcovidpatients': 1,
#  'askmentor': 1,
#  'mystartuptv': 1,
#  'majorsunilshetty': 1,
#  'startupnews': 1,
#  'suggest': 1,
#  'springwatch': 2,
#  'wildlife': 2,
#  'nature': 2,
#  'mystery': 2,
#  'organism': 1,
#  'pathogens': 1,
#  'diseases': 1,
#  'pathology': 1,
#  'windows11': 2,
#  'wind': 1,
#  'windows': 1,
#  'linux': 1,
#  'server': 1,
#  'kindleunlimited': 1,
#  'gladbags': 1,
#  'thankyoumodiji': 1,
#  'largestvaccinationdrive': 1,
#  'atheist': 1,
#  'men': 1,
#  'laugh': 1,
#  'savemoney': 1,
#  'gift': 2,
#  'gifts': 2,
#  'giftideas': 1,
#  'humor': 2,
#  'accessories': 1,
#  'skyline': 2,
#  'profit': 1,
#  'vacation': 2,
#  'package': 1,
#  'price': 2,
#  'low': 2,
#  'cheap': 2,
#  'safari': 2,
#  'bitvpn': 7,
#  'blockchain': 7,
#  'netsp': 6,
#  'cough': 2,
#  'congestion': 1,
#  'lungs': 1,
#  'breath': 1,
#  'asthma': 1,
#  'lol': 2,
#  'video': 2,
#  'covidemergency': 2,
#  'vaccinessavelives': 2,
#  'vaccineforall': 2,
#  'retweet': 1,
#  'iartg': 1,
#  'fbr': 1,
#  'dems': 1,
#  'democrats': 2,
#  'dem': 1,
#  'biden': 1,
#  'covid19bc': 1,
#  'bidenharris': 1,
#  'misinformation': 2,
#  'virustransmission': 1,
#  'airgap': 1,
#  'sharedfacts': 1,
#  'healthscience': 1,
#  'invisiblebutreal': 1,
#  ...}

# %% [markdown]
# ## Hashtag EDA Vaccine

# %%
vaccine_hashtags = get_hashtags_list(tweet_vaccine)
vaccine_hashtags
# Out:
# {'100daysofcode': 1,
#  '324': 1,
#  '5g': 11,
#  'abdala': 2,
#  'abhousingrealtypvtltd': 1,
#  'abroad': 1,
#  'actress': 1,
#  'adjuvants': 1,
#  'advertising': 1,
#  'africa': 4,
#  'africaresistance': 1,
#  'ai': 1,
#  'alberta': 1,
#  'amrishpuri': 1,
#  'antivaxxer': 1,
#  'antivirals': 1,
#  'apple': 1,
#  'ardhinternational': 1,
#  'army': 1,
#  'arunachalpradesh': 1,
#  'ashecon2021': 1,
#  'asheville': 6,
#  'asiapacific': 2,
#  'assam': 1,
#  'astrazeneca': 24,
#  'astrazenecavaccine': 2,
#  'aussies': 1,
#  'australia': 2,
#  'australians': 1,
#  'baani': 1,
#  'baanigirlsethnicwear': 1,
#  'bangalore': 1,
#  'bbc': 1,
#  'beast': 3,
#  'bharatbiotec': 3,
#  'bharatbiotech': 5,
#  'biden': 1,
#  'bigpharma': 1,
#  'billgates': 1,
#  'biomarkers': 1,
#  'bioreagents': 1,
#  'biotech': 7,
#  'biotechnology': 1,
#  'bjp': 2,
#  'blockchain': 1,
#  'blog': 1,
#  'blogging': 1,
#  'blooddonorday': 1,
#  'bolsonaro': 1,
#  'bonds': 1,
#  'brazil': 1,
#  'breaking': 3,
#  'breakingnews': 2,
#  'bringsomefun': 1,
#  'buffer': 1,
#  'canada': 2,
#  'cancer': 1,
#  'cantwait': 1,
#  'cdc': 1,
#  'cg': 1,
#  'chennai': 1,
#  'china': 4,
#  'chinavirus': 3,
#  'chinesevirus': 1,
#  'christ': 1,
#  'cloud': 1,
#  'coding': 1,
#  'commodities': 1,
#  'conspiracytheories': 1,
#  'copaamerica': 1,
#  'corona': 6,
#  'coronavac': 2,
#  'coronavaccine': 3,
#  'coronavi': 2,
#  'coronavirus': 31,
#  'coronaviruspandemic': 18,
#  'coronavirusupdate': 1,
#  'coronvirus': 1,
#  'covax': 6,
#  'covaxin': 64,
#  'covi': 1,
#  'covid': 59,
#  'covid1': 1,
#  'covid19': 343,
#  'covid19lk': 1,
#  'covid19pandemic': 1,
#  'covid19vaccination': 1,
#  'covid19vaccine': 1,
#  'covid_19': 3,
#  'covidab': 1,
#  'covidappropriatebehaviour': 1,
#  'covidjab': 1,
#  'covidpandemic': 2,
#  'covidtests': 1,
#  'covidvacccine': 1,
#  'covidvaccination': 8,
#  'covidvaccine': 1,
#  'covidvaccinevictims': 8,
#  'covisheild': 1,
#  'covishield': 6,
#  'cowin': 150,
#  'cowinapp': 2,
#  'crimesagainsthumanity': 1,
#  'crypto': 1,
#  'cryptocurrencies': 1,
#  'csl': 1,
#  'cuban': 3,
#  'cuckold': 1,
#  'cummingoutofcovid': 1,
#  'data': 1,
#  'dataprotection': 1,
#  'datascience': 1,
#  'daventry': 1,
#  'deadlyvirus': 1,
#  'deaths': 1,
#  'delhi': 3,
#  'deltaplus': 2,
#  'deltaplusvariant': 4,
#  'deltavariant': 2,
#  'digitalmarketing': 2,
#  'digitaltransformation': 1,
#  'distance': 1,
#  'doctor': 7,
#  'doomatyourserviceep13': 2,
#  'dose': 1,
#  'economy': 2,
#  'econtwitter': 1,
#  'edge': 1,
#  'education': 2,
#  'elections2021': 1,
#  'electronic': 1,
#  'employmentmatters': 1,
#  'england': 1,
#  'esymposia': 1,
#  'etribune': 1,
#  'eu': 7,
#  'europe': 2,
#  'evds': 1,
#  'f': 1,
#  'faith': 1,
#  'fakenews': 18,
#  'fastestvaccinationdrive': 1,
#  'fauci': 2,
#  'fertility': 1,
#  'fightcorona': 1,
#  'finance': 1,
#  'fiverr': 1,
#  'fmrevolution': 7,
#  'fmtnews': 2,
#  'forex': 1,
#  'free': 1,
#  'freevaccineforall': 2,
#  'futuregrace': 1,
#  'gates': 1,
#  'gb': 1,
#  'germany': 1,
#  'getvaccinated': 1,
#  'getyour': 1,
#  'global': 2,
#  'google': 2,
#  'government': 1,
#  'greatbritain': 1,
#  'hadenough': 1,
#  'healiing': 1,
#  'healing': 2,
#  'health': 15,
#  'healthandsafety': 2,
#  'healthcare': 15,
#  'healthministry': 1,
#  'healthsecretary': 1,
#  'hepes': 1,
#  'herdimmunity': 1,
#  'hero': 1,
#  'hlaligands': 1,
#  'hll': 1,
#  'homelessness': 2,
#  'hongkong': 2,
#  'hope': 2,
#  'hotwife': 1,
#  'hub': 2,
#  'hubballi': 1,
#  'hubby': 1,
#  'hydroxychloroquine': 1,
#  'hypocrisy': 1,
#  'idea': 1,
#  'immunise': 1,
#  'immunology': 2,
#  'impact': 1,
#  'inaninstant': 1,
#  'inclusion': 1,
#  'incubation': 1,
#  'india': 26,
#  'indiafightscorona': 7,
#  'indian': 49,
#  'indianarmy': 1,
#  'indochina': 2,
#  'infographic': 1,
#  'infographics': 1,
#  'inoculation': 1,
#  'insurance': 7,
#  'internationaldayofyoga': 1,
#  'investigation': 1,
#  'iot': 1,
#  'itrustramjanambhuminayas': 1,
#  'itw': 1,
#  'itwreagents': 1,
#  'ivermectin': 1,
#  'ivermectinworks': 1,
#  'jab': 1,
#  'japan': 2,
#  'jesus': 1,
#  'johnsonandjohnsonvaccine': 1,
#  'justsayno': 1,
#  'katrinakaif': 2,
#  'kejriwalexposedonvaccine': 6,
#  'kids': 1,
#  'kolkata': 1,
#  'kremlin': 1,
#  'kunalkhemu': 1,
#  'largestvaccinationdrive': 7,
#  'largestvaccinedrive': 3,
#  'lawandamanning': 1,
#  'leadership': 1,
#  'life': 1,
#  'lithuania': 124,
#  'live': 6,
#  'lnp': 1,
#  'lockdown': 1,
#  'love': 1,
#  'ma': 1,
#  'magufuli': 2,
#  'mahesh': 1,
#  'malaysia': 1,
#  'mamatabanerjee': 1,
#  'mandates': 1,
#  'manmohansingh': 4,
#  'manufacturing': 2,
#  'mask': 1,
#  'masks': 3,
#  'maskup': 2,
#  'maskupindia': 1,
#  'massspec': 1,
#  'matthancock': 1,
#  'measles': 2,
#  'media': 1,
#  'medic': 1,
#  'medicalfreedom': 1,
#  'medicine': 9,
#  'medtech': 7,
#  'metals': 1,
#  'middleeast': 1,
#  'ml': 1,
#  'moderna': 3,
#  'modernavaccine': 1,
#  'modihaitohmumkinhai': 3,
#  'modiresign': 1,
#  'molecularbiology': 1,
#  'mondaymotivation': 1,
#  'mondaythoughts': 1,
#  'mpvaccinationmahaabhiyan': 1,
#  'mrna': 4,
#  'mssny': 1,
#  'mumbai': 1,
#  'mustersowoozoo': 1,
#  'mybodyismyown': 1,
#  'mybodymychoice': 1,
#  'mzansi': 1,
#  'narendramodi': 1,
#  'naripragatisocialfoundation': 3,
#  'naturalimmunity': 1,
#  'nature': 1,
#  'news': 3,
#  'newsalert': 2,
#  'nhs': 8,
#  'nigeria': 1,
#  'njcri': 1,
#  'noida': 1,
#  'nonvaccinated': 1,
#  'normality': 1,
#  'northamptonshire': 2,
#  'novaccinepassportsanywhere': 1,
#  'novakdjokovic': 1,
#  'novavax': 2,
#  'nss': 1,
#  'nssindia': 1,
#  'nstnation': 1,
#  'ntagi': 1,
#  'nxttakeoverinyourhouse': 1,
#  'nys': 21,
#  'oneruleforone': 1,
#  'ontario': 14,
#  'othernews': 1,
#  'pandemic': 10,
#  'panreacapplichem': 1,
#  'pataudi': 1,
#  'patients': 7,
#  'pcmc': 1,
#  'people': 1,
#  'peoplesvaccine': 1,
#  'pfizer': 30,
#  'pfizervaccine': 1,
#  'ph': 1,
#  'pharmaceutical': 7,
#  'pibfactcheck': 18,
#  'pibkochi': 2,
#  'platelets': 2,
#  'pmmodi': 3,
#  'pmoindia': 2,
#  'policy': 8,
#  'polio': 1,
#  'poll': 1,
#  'postvaccination': 3,
#  'ppe': 1,
#  'precautions': 2,
#  'pridemonth2021': 1,
#  'propaganda': 1,
#  'protect': 1,
#  'protectioninfection': 1,
#  'pune': 148,
#  'punjab': 1,
#  'python': 1,
#  'quarant': 1,
#  'quarantine': 2,
#  'quienmatoasantiago': 1,
#  'quotes': 2,
#  'rahulexposesmodigovt': 9,
#  'rajasthan': 1,
#  'rajeshbhushan': 1,
#  'rammandir': 1,
#  'rammandirscam': 1,
#  'ravishkumar': 29,
#  'refugees': 1,
#  'registration': 1,
#  'reinvent': 1,
#  'relief': 1,
#  'reopening': 14,
#  'reopenontario': 1,
#  'researc': 1,
#  'research': 2,
#  'researcher': 3,
#  'resilience': 1,
#  'reuters': 1,
#  'rsmuk': 1,
#  'rubbishkumar': 1,
#  'russia': 1,
#  'rwanda': 1,
#  's': 13,
#  'safetyfirst': 1,
#  'safewithapollo': 1,
#  'samsungm32': 3,
#  'sarkaruvaaripaata': 1,
#  'sarv': 1,
#  'savebuxwahaforest': 1,
#  'savechildren': 1,
#  'science': 1,
#  'seconddose': 2,
#  'selfservice': 1,
#  'senegal': 1,
#  'seruminstitute': 3,
#  'servicenow': 1,
#  'sharing': 1,
#  'sinovac': 2,
#  'skiptostage3': 1,
#  'socialcare': 2,
#  'socialdistancing': 1,
#  'socialmedia': 2,
#  'sohaalikhan': 1,
#  'southafrica': 5,
#  'southamer': 1,
#  'southamerica': 1,
#  'sputnik': 1,
#  'sputnikv': 3,
#  'stayhome': 1,
#  'staysafe': 1,
#  'stockmarket': 1,
#  'stopcensorship': 1,
#  'students': 1,
#  'subscribe': 1,
#  'summer': 1,
#  'sushantsinghrajput_forever': 1,
#  'taiwan': 125,
#  'tamilnadu': 1,
#  'technology': 12,
#  'tenreasons': 1,
#  'testing': 1,
#  'thirdwave': 1,
#  'tiktok': 1,
#  'today': 7,
#  'todaysmedicalupdate': 9,
#  'together': 1,
#  'tokyo': 1,
#  'tpindia': 1,
#  'travel': 8,
#  'travelban': 1,
#  'travelrestrictions': 1,
#  'treatments': 1,
#  'trending': 2,
#  'tripswaiver': 5,
#  'tris': 1,
#  'trustscience': 1,
#  'tuesdaymotivations': 1,
#  'tuesdayvibe': 2,
#  'turkey': 6,
#  'tv9news': 1,
#  'twitter': 2,
#  'uitvnews': 1,
#  'uk': 4,
#  'unite2fightcorona': 4,
#  'unitedkingdom': 1,
#  'unitedstates': 1,
#  'untested': 1,
#  'up': 1,
#  'update': 8,
#  'uppcares': 1,
#  'us': 1,
#  'usa': 2,
#  'uspoli': 1,
#  'uttarpradesh': 1,
#  'v': 1,
#  'vacc': 1,
#  'vacci': 2,
#  'vaccin': 1,
#  'vaccinate': 1,
#  'vaccinated': 22,
#  'vaccinateindia': 1,
#  'vaccinatetosavesouthafrica': 1,
#  'vaccination': 26,
#  'vaccinationdone': 1,
#  'vaccinationdrive': 31,
#  'vaccinationguidelines': 1,
#  'vaccinations': 3,
#  'vaccinationupdate': 1,
#  'vaccine': 805,
#  'vaccineforall': 30,
#  'vaccinehesitancy': 1,
#  'vaccinemaitri': 1,
#  'vaccinenews': 1,
#  'vaccinepune': 145,
#  'vaccineresearch': 1,
#  'vaccinerolloutsa': 2,
#  'vaccines': 8,
#  'vaccinesideeffects': 3,
#  'vaccinessavelives': 1,
#  'vaccineswork': 2,
#  'vaccineupdates': 1,
#  'vaccineupdatesindia': 1,
#  'variants': 2,
#  'vijay': 1,
#  'vikrantrona': 1,
#  'virus': 1,
#  'vitt': 2,
#  'vksinnovax21': 1,
#  'vladimirputin': 1,
#  'volunteer': 1,
#  'vr': 1,
#  'washing': 1,
#  'washinghands': 1,
#  'washyourhands': 1,
#  'westbengal': 1,
#  'wfh': 1,
#  'who': 7,
#  'withrefugees': 1,
#  'world': 11,
#  'worldrefugeeday': 1,
#  'wow': 1,
#  'wtcfinal': 3,
#  'yasministry': 1,
#  'yorkregion': 1,
#  'yuvabharat': 1,
#  'εμβολιασμος': 1,
#  'εμβολιο': 1,
#  'प': 11,
#  'คนละคร': 1}

# %% [markdown]
# ## Hashtag EDA Pandemic

# %%
pandemic_hashtags = get_hashtags_list(tweet_pandemic)
pandemic_hashtags
# Out:
# {'traveldayofaction': 1,
#  'speakupfortravel': 1,
#  'pandemic': 653,
#  'covid19': 234,
#  'g20': 1,
#  'digital': 3,
#  'climateaction': 1,
#  'afirstwave': 4,
#  'lisamariemeadows': 4,
#  'anxiety': 5,
#  'depression': 3,
#  'charity': 2,
#  'help': 1,
#  'crisis': 4,
#  'smallbusiness': 5,
#  'health': 21,
#  'wellbeing': 1,
#  'cdp4recovery': 1,
#  'ivychamp': 1,
#  'suriya': 1,
#  'jyothika': 1,
#  'covidvaccination': 9,
#  'vaccine': 16,
#  'tuesdayvibes': 1,
#  'tuesdaythoughts': 1,
#  'career': 3,
#  'jobs': 4,
#  'work': 2,
#  'workingfromhome': 4,
#  'workout': 1,
#  'business': 5,
#  'humanresources': 1,
#  'coronavirus': 70,
#  'corona': 11,
#  'pandemia': 3,
#  'diversity': 1,
#  'khou11': 6,
#  'fauciemails': 1,
#  'fauci': 2,
#  'wuhanlableak': 1,
#  'usa': 6,
#  'wuhan': 2,
#  'nstnation': 13,
#  'recoveryplan': 1,
#  'muhyiddin': 1,
#  'labor': 1,
#  'household': 1,
#  'italy': 1,
#  'lableaktheory': 1,
#  'coronavirusorigin': 1,
#  'coronaviruslableak': 1,
#  'china': 19,
#  'covid': 55,
#  'fortune500': 1,
#  'remoteworklife': 1,
#  'remotework': 1,
#  'diverceety': 1,
#  'climate': 2,
#  'resilient': 2,
#  'cities': 3,
#  'tuneinnow': 1,
#  'joinus': 1,
#  'covid19uk': 2,
#  'neurology': 1,
#  'neurological': 1,
#  'neurologist': 1,
#  'neurologicaldisease': 1,
#  'couples': 1,
#  'rahulvaidya': 4,
#  'dishaparmar': 4,
#  'biggboss': 4,
#  'presidenttrump': 1,
#  'immigrants': 1,
#  'minorities': 1,
#  'syria': 1,
#  'yemen': 1,
#  'iraq': 1,
#  'afghanistan': 1,
#  'africa': 5,
#  'security': 6,
#  'sahel': 1,
#  'libya': 1,
#  'smes': 1,
#  'circulareconomy': 1,
#  'greenrecovery': 1,
#  'buildbackbetter': 3,
#  'lockdowns': 3,
#  'youngpeople': 2,
#  'wales': 1,
#  'evensurvey': 1,
#  'vital': 1,
#  'margin': 1,
#  'debt': 1,
#  'businessconsultant': 1,
#  'companies': 1,
#  'consulting': 1,
#  'recovery': 14,
#  'sme': 5,
#  'warehouseindustry': 2,
#  'retail': 2,
#  'ecommerce': 13,
#  'highstreet': 2,
#  'logisticsindustry': 2,
#  'supplychainmanagement': 2,
#  'levis': 1,
#  'hr': 1,
#  'leadership': 2,
#  'futureofwork': 6,
#  'lockdown': 25,
#  'india': 22,
#  'inspiring': 1,
#  'cybersecurity': 6,
#  'data': 9,
#  'iot': 6,
#  'supplychain': 4,
#  'attacksolutions': 2,
#  'champions': 1,
#  'cmcvalumni': 1,
#  'onlineeducation': 1,
#  'onlineeducationplatform': 1,
#  'covid19effect': 1,
#  'uk': 10,
#  'yulin': 9,
#  'pets': 1,
#  'dogs': 1,
#  'cats': 1,
#  'coronavirusupdates': 2,
#  'healthsaarthi': 1,
#  'covid19outbreak': 1,
#  'patients': 1,
#  'european': 2,
#  'dfs': 8,
#  'economy': 15,
#  'digitalpayments': 2,
#  'fcommerce': 2,
#  'bangladesh': 4,
#  'ecmo': 3,
#  'ecls': 3,
#  'author': 14,
#  'bolp': 14,
#  'bookofliespodcast': 14,
#  'chandnichowk': 4,
#  'groundreality': 4,
#  'realitycheck': 4,
#  'repair': 1,
#  'reuse': 1,
#  'diy': 1,
#  'ewaste': 1,
#  'wastemanagement': 1,
#  'consumer': 3,
#  'attitude': 1,
#  'covid__19': 3,
#  'sustainability': 4,
#  'ward126': 2,
#  'crypto': 3,
#  'cryptocrash': 1,
#  'investing': 1,
#  'bullmarket': 1,
#  'falsereports': 1,
#  'fakenews': 2,
#  'blockchain': 2,
#  'thetruthinternational': 2,
#  'ttimagazine': 2,
#  'tti': 2,
#  'news': 15,
#  'altafhussain': 1,
#  'antiencroachmentoperations': 1,
#  'bilawalbhuttozardari': 1,
#  'legislation': 1,
#  'london': 3,
#  'mqm': 1,
#  'pmimrankhan': 1,
#  'politics': 2,
#  'ppp': 1,
#  'sindhgovernment': 2,
#  'terrorism': 9,
#  'unemployment': 2,
#  'technology': 17,
#  'pan': 3,
#  'water': 1,
#  'university': 3,
#  'paris': 1,
#  'greencities': 1,
#  'france': 1,
#  'trees': 1,
#  'urbangardens': 1,
#  'environment': 2,
#  'nature': 1,
#  'newideas': 1,
#  'planttrees': 1,
#  'town': 2,
#  'chicago': 1,
#  'smarthomes': 1,
#  'homeautomation': 1,
#  'smarthome': 1,
#  'smartliving': 1,
#  'appcontrol': 1,
#  'voicecontrol': 1,
#  'smartdevices': 1,
#  'mapping': 1,
#  'connectedeurope': 1,
#  'resilienteurope': 1,
#  'cps': 1,
#  'internationalyogaday2021': 2,
#  'yoga': 7,
#  'wellness': 1,
#  'meditation': 1,
#  'physicalwellness': 1,
#  '7thinternationalyogaday': 1,
#  'cpsgroup': 1,
#  'onlinelearning': 1,
#  'stayhome': 4,
#  'staysafe': 2,
#  'admission': 1,
#  'vitamind': 2,
#  'supplements': 2,
#  'hospitality': 9,
#  'businesses': 6,
#  'lakedistrict': 5,
#  'borders': 5,
#  'bekind': 5,
#  'abuse': 5,
#  'startupstreet': 1,
#  'buildbackbetterslt': 2,
#  'jcf': 2,
#  'gartner': 6,
#  'services': 7,
#  'mentalhealth': 10,
#  'gwdocs': 1,
#  'insurance': 3,
#  'healthcare': 15,
#  'cgfsummit': 2,
#  'cyberfraud': 1,
#  'cyberattacks': 1,
#  'income': 1,
#  'forex': 1,
#  'mt5broker': 1,
#  'repayment': 1,
#  'tax': 1,
#  'ketto': 3,
#  'contribute': 3,
#  'covidrelief': 4,
#  'migrant': 4,
#  'women': 5,
#  'delhi': 1,
#  'mumbai': 4,
#  'meal': 1,
#  'ration': 1,
#  'food': 1,
#  'humanityatstake': 1,
#  'humanhealth': 1,
#  'pride': 18,
#  'narendramodi': 2,
#  'ganga': 1,
#  'cataclysm': 1,
#  'stalbans': 1,
#  'lowtrafficneighbourhoods': 1,
#  'ltns': 1,
#  'laliga': 1,
#  'publicserviceday': 1,
#  'welfarereform': 1,
#  'oxygen': 1,
#  'essentials': 1,
#  'yulu': 1,
#  '2017taxscam': 1,
#  'tfg': 1,
#  'gaslighting': 1,
#  'amber': 2,
#  'redlist': 2,
#  'quarantine': 3,
#  'travel': 19,
#  'travelban': 5,
#  'travelnews': 2,
#  'thetablet': 1,
#  'heatpump': 2,
#  'strategy': 3,
#  'greenindustrialrevolution': 2,
#  'virus': 6,
#  'vaccines': 11,
#  'covid_vaccines': 1,
#  'shortages': 1,
#  'market': 2,
#  'economicrecovery': 1,
#  'netzero': 1,
#  'hvac': 1,
#  'love': 2,
#  'socialdistancing': 4,
#  'o': 1,
#  'stayathome': 1,
#  'instagram': 2,
#  'cuarentena': 1,
#  'assistance': 3,
#  'times': 9,
#  'newsreviews': 9,
#  'fbi': 9,
#  'intel': 9,
#  'biowarfare': 9,
#  'russia': 8,
#  'putin': 8,
#  'trumpinvestigations': 8,
#  'capitolriot': 8,
#  'kanganaranaut': 1,
#  'income_tax': 1,
#  'association': 1,
#  'balance': 1,
#  'eventprofs': 1,
#  'futuresa': 1,
#  'staffingsolutions': 1,
#  'challenge': 1,
#  'youth': 2,
#  'mediaxpose': 1,
#  'statssa': 1,
#  'gis': 3,
#  'geo': 2,
#  'who': 8,
#  'infections': 4,
#  'greatreset': 2,
#  'jobgrowth': 3,
#  'digitaleconomy': 3,
#  'usgrowth': 3,
#  'itresources': 3,
#  'emergingtech': 7,
#  'masks': 8,
#  'coruzant': 7,
#  'thedigitalexecutive': 2,
#  'cxo': 1,
#  'cochranepodcast': 3,
#  'plasma': 3,
#  'poetry': 3,
#  'digitalisation': 3,
#  'globalisation': 2,
#  'arts': 2,
#  'humanities': 2,
#  'caspiandebt': 1,
#  'employeehealth': 1,
#  'safety': 4,
#  'workfromhome': 4,
#  'adminstaff': 1,
#  'impact': 3,
#  'trombone': 1,
#  'staff': 1,
#  'bekindtohospitality': 1,
#  'bigtech': 2,
#  'zoom': 2,
#  'childhood': 1,
#  'homeschooling': 1,
#  'care': 2,
#  'web': 1,
#  'preschool': 2,
#  'socialhypnosis': 1,
#  'humanity': 1,
#  'europe': 6,
#  'america': 1,
#  'americans': 2,
#  'trtworldforum2021': 1,
#  'spidey': 2,
#  'spiderman': 2,
#  'peterparker': 2,
#  'marvel': 2,
#  'avengers': 2,
#  'superhero': 2,
#  'cosplay': 2,
#  'covid_19': 8,
#  'shopping': 1,
#  'habits': 1,
#  'latestblog': 1,
#  'changing': 1,
#  'treatment': 4,
#  'guidelines': 1,
#  'matchmaking': 1,
#  'treatments': 1,
#  'covid19treatment': 1,
#  'clinicalresearch': 1,
#  'ards': 1,
#  'asia': 2,
#  'us': 4,
#  'wfh': 8,
#  'geospatial': 1,
#  'analytics': 1,
#  'bigdata': 2,
#  'innovation': 5,
#  'deeplearning': 3,
#  'cto': 3,
#  'cio': 1,
#  'techunting': 2,
#  'smallbusinesses': 3,
#  'psoriasis': 1,
#  'financialmarket': 1,
#  'development': 2,
#  'financialrisks': 1,
#  'pboc': 1,
#  'cbirc': 1,
#  'lujiazuiforum': 1,
#  'nonperformingassets': 1,
#  'bubble': 1,
#  'shadowbanking': 1,
#  'softpower': 1,
#  'pakistan': 2,
#  'dailytimes': 1,
#  'poland': 3,
#  'secure': 8,
#  'efficient': 7,
#  'trustworthy': 7,
#  'sector': 2,
#  'workplace': 3,
#  'affiliates': 1,
#  'goldman': 1,
#  'europeancentralbank': 1,
#  'unesco': 1,
#  'senegals': 1,
#  'currentnews': 1,
#  'amman': 2,
#  'geodata': 2,
#  'lessonslearned': 2,
#  'bananarepublicans': 1,
#  'maddow': 1,
#  'hannity': 1,
#  'teens': 4,
#  'employment': 2,
#  'dollar': 1,
#  'webinar': 4,
#  'psycholog': 1,
#  'gangof7': 1,
#  'surge': 1,
#  'coronavirusupdate': 1,
#  'newrelease': 1,
#  'comedy': 1,
#  'crime': 3,
#  'fiction': 1,
#  'millhill': 1,
#  'lockdow': 1,
#  'reentryanxiety': 1,
#  'escapism': 1,
#  'adventure': 1,
#  'autentic': 1,
#  'autenticdistribution': 1,
#  'factual': 1,
#  'docuseries': 1,
#  'documentary': 2,
#  'travelbans': 1,
#  'thoughtleadership': 1,
#  'imibhubaneswar': 1,
#  'sarawak': 4,
#  'vac': 3,
#  'eurozone': 1,
#  'worldmusicday2021': 1,
#  'music': 1,
#  'brazil': 2,
#  'copacabana': 1,
#  'riodejaneiro': 1,
#  'narratives': 5,
#  'policy': 9,
#  'westerneurope': 5,
#  'african': 1,
#  'unleashafrica': 1,
#  'finance': 2,
#  'economics': 1,
#  'africanleaders': 1,
#  'africanpolicymakers': 1,
#  'africaneconomics': 1,
#  'africanbusiness': 1,
#  'vaccinate': 1,
#  'corruption': 1,
#  'corruptiongoverment': 1,
#  'directinvestment': 1,
#  'investors': 1,
#  'digitalinfrastructure': 1,
#  'hawaiiairports': 16,
#  'hawaii': 8,
#  'maui': 8,
#  'kauai': 8,
#  'bigisland': 8,
#  'hawaiidepartmentoftransportation': 8,
#  'stopcoronavirus': 8,
#  'travelingtohawaii': 8,
#  'visitinghawaii': 8,
#  'vaccineeffectiveness': 1,
#  'covidvaccines': 2,
#  'mrna': 2,
#  'vaccineswork': 1,
#  'c': 3,
#  'businessnews': 1,
#  'resilience': 3,
#  'mayorschallenge': 1,
#  'biopharmaceuticals': 1,
#  'drugmanufacturing': 1,
#  'healthnews': 1,
#  'gastroenterologist': 1,
#  'covidpatient': 1,
#  'fbinewsreview': 7,
#  'fbinr': 7,
#  'global': 7,
#  'review': 2,
#  'insurancenews': 1,
#  'backtohealth': 1,
#  'datavault': 1,
#  'datascientist': 1,
#  'datamanagement': 1,
#  'snowflakedb': 1,
#  'cyberattack': 1,
#  'cybercriminal': 1,
#  'qacycle': 3,
#  'covaxin': 2,
#  'bharatbiotech': 1,
#  'covidvaccine': 4,
#  'asiapacific': 4,
#  'indochina': 4,
#  'southamerica': 4,
#  'middleeast': 3,
#  'cdc': 3,
#  'testing': 4,
#  'mandates': 3,
#  'deaths': 4,
#  'variants': 4,
#  'malaria': 2,
#  'dom': 5,
#  'iowa': 5,
#  'govdata': 5,
#  'newyork': 8,
#  'asadumar': 1,
#  'muradalishah': 1,
#  'ncoc': 1,
#  'sinopharm': 1,
#  'vaccinations': 2,
#  'vaccineshortage': 1,
#  'northkorea': 2,
#  'vaccineforall': 3,
#  'vaccinated': 3,
#  'assam': 3,
#  'disasters': 2,
#  'covidiot': 2,
#  'brainwashing': 1,
#  'international': 1,
#  'airport': 1,
#  'guarulhos': 1,
#  'sãopaulo': 1,
#  'dystopian': 1,
#  'feeling': 1,
#  'blackandwhite': 2,
#  'streetphotography': 2,
#  'streetphotos': 1,
#  'streetphoto': 1,
#  'urbanjungle': 1,
#  'urban': 1,
#  'urbanphotography': 1,
#  'starbucks': 1,
#  'imanagementbrazil': 1,
#  'travelrestrictions': 2,
#  'low': 2,
#  'sleep': 1,
#  'stress': 1,
#  'phdchat': 1,
#  'phdvoice': 1,
#  'neuroscience': 1,
#  'psychology': 1,
#  'vpnanywhere': 1,
#  'vpn': 1,
#  'bestvpn': 1,
#  'onlinesecurity': 1,
#  'securevpn': 1,
#  'virtualcare': 1,
#  'telehealth': 1,
#  'clinicaltrial': 1,
#  'tuesdayvibe': 3,
#  'happeningtoday': 1,
#  'painting': 2,
#  'excursionsjournal': 2,
#  'stepbystep': 2,
#  'abstractexpressionism': 2,
#  'abs': 1,
#  'sweetgreen': 1,
#  'publicoffering': 1,
#  'digitalsales': 1,
#  'vaccination': 11,
#  'nip': 1,
#  'globaleconomy': 1,
#  'supplycrunch': 1,
#  'tightsupply': 1,
#  'rawmaterials': 1,
#  'eu': 3,
#  'twitter': 2,
#  'mississauga': 2,
#  'artificialintelligence': 7,
#  'p': 4,
#  'network': 2,
#  'machinelearning': 2,
#  'sustainable': 3,
#  'funding': 3,
#  'weak': 1,
#  'virginia': 1,
#  'remote': 3,
#  'mergers': 3,
#  'legal': 5,
#  'contracts': 3,
#  'customer': 3,
#  'cx': 4,
#  'businesstransformation': 3,
#  'digitalstrategy': 3,
#  'covidhoax': 1,
#  'fearmongering': 1,
#  'borisjohnson': 2,
#  'covidcult': 1,
#  'medicaltyranny': 1,
#  'renegadepoet': 1,
#  'drama': 5,
#  'paperback': 5,
#  'kindleunlimited': 5,
#  'readingcommunity': 5,
#  'writingcommunit': 4,
#  'internationalyogaday': 3,
#  'crowd': 1,
#  'stadium': 1,
#  'simulation': 1,
#  'sports': 4,
#  'abstractexpressionist': 1,
#  'stepbysteppainting': 1,
#  '6fish': 1,
#  'exsjournalexhibition': 1,
#  'achinkoflight': 1,
#  'guwahati': 1,
#  'assamcovidupdate': 1,
#  'coronapandemic': 1,
#  'ai': 4,
#  'banking': 2,
#  'cbdc': 2,
#  'laos': 1,
#  'intled': 1,
#  'compliance': 1,
#  'digitalbanking': 1,
#  'digitalcurrency': 1,
#  'fintech': 2,
#  'mobilebanking': 1,
#  'neobanks': 1,
#  'payments': 1,
#  'riskmanagement': 1,
#  'tokyoolympics': 1,
#  'tokyo2020': 1,
#  'tokyo': 1,
#  'japan': 1,
#  'planning': 1,
#  'smartnews': 1,
#  'smartvideo': 1,
#  'american': 2,
#  'pilots': 1,
#  'furloughed': 1,
#  'retailers': 2,
#  'xglobalmarkets': 2,
#  'infodemic': 2,
#  'misinformation': 1,
#  'mythsdebunked': 1,
#  'mythsvsfacts': 1,
#  'myths': 1,
#  'indiafightscorona': 3,
#  'c2m2symposium': 3,
#  'infodose': 1,
#  'awarenes': 1,
#  'amigozpr': 1,
#  'theunstoppables': 1,
#  'campaign': 1,
#  'home': 1,
#  'nyc': 1,
#  'meded': 2,
#  'foamed': 2,
#  'juniordoctors': 2,
#  'respiratory': 2,
#  'healthtech': 2,
#  'usarmy': 1,
#  'when': 1,
#  'where': 1,
#  'pregnantladies': 1,
#  'elder': 1,
#  'seniorcitizen': 1,
#  'stopcorona': 1,
#  'stopthevirus': 1,
#  'medicine': 2,
#  'police': 1,
#  'internationaldayofyoga': 4,
#  'digitalbangladesh': 1,
#  'unstoppablebangladesh': 1,
#  'remot': 2,
#  'thankful': 1,
#  'selflessservice': 1,
#  'toughtimes': 1,
#  'besthospitals': 1,
#  'kimshospitals': 1,
#  'liftthetravelban': 2,
#  'pp10143': 2,
#  'lo': 2,
#  'srinagar': 1,
#  'stayhomesavelives': 1,
#  'maskup': 1,
#  'getvaccinated': 2,
#  'mountainprize': 2,
#  'award': 2,
#  'clinicaltrials': 1,
#  'pharmaceuticals': 1,
#  'drugdevelopment': 1,
#  'degradation': 1,
#  'unep': 1,
#  'foodsupply': 1,
#  'trading': 1,
#  'exports': 1,
#  'uktrading': 1,
#  'brexit': 1,
#  'ons': 1,
#  'boyomind': 1,
#  'blowyourmind': 1,
#  'government': 5,
#  'growth': 1,
#  'fdi': 1,
#  'investments': 1,
#  'trillion': 1,
#  'billions': 1,
#  'startups': 1,
#  'fundraising': 1,
#  'healthsecretary': 1,
#  'rajeshbhushan': 1,
#  'trumpvirus': 2,
#  'idese': 2,
#  'ifdt': 1,
#  'angažovanamisao': 1,
#  'engagaedthought': 1,
#  'moisedialogues': 1,
#  'moisepalace': 1,
#  'democracy': 2,
#  'tcrn': 2,
#  'costarica': 1,
#  'healthy': 2,
#  'caribbean': 1,
#  'environmental': 3,
#  'desertification': 1,
#  'achievement': 2,
#  'authors': 2,
#  'battle': 2,
#  'books': 2,
#  'competition': 2,
#  'co': 1,
#  'nagaland': 4,
#  'powerwarriors': 4,
#  'daybyday': 1,
#  'trump': 1,
#  'gop': 1,
#  'covidiots': 1,
#  'balderdash': 1,
#  'primarycare': 1,
#  'eatingdisorders': 3,
#  'boys': 3,
#  'children': 4,
#  'girls': 4,
#  'epidemic': 3,
#  'theatr': 2,
#  'struggles': 1,
#  'doctors': 1,
#  'support': 3,
#  'religion': 2,
#  'relief': 2,
#  'bengaluru': 1,
#  'collaboration': 1,
#  'volunteer': 1,
#  'bbmp': 1,
#  'theatre': 1,
#  'socialization': 1,
#  'virtuallearning': 1,
#  'bodyshaming': 1,
#  'longcovid': 1,
#  'tuesdaymotivations': 1,
#  'educhat': 1,
#  'quarantinaturner': 1,
#  'odisha': 2,
#  'utkarsh': 1,
#  'passtrack': 9,
#  'unite2fightcorona': 1,
#  'g7': 1,
#  'wearamask': 2,
#  'losttheroom': 1,
#  'g7summit2021': 1,
#  'insidetheietower': 1,
#  'alberta': 2,
#  'covidab': 2,
#  'calgary': 3,
#  'yyc': 2,
#  'edmonton': 3,
#  'yeg': 2,
#  'covid19ab': 1,
#  'onlinebusiness': 2,
#  'onlinebusinessideas': 2,
#  'bestecommercewebsiteatlowcost': 2,
#  'ecommerceapplication': 2,
#  'marketplace': 2,
#  'mcommerce': 2,
#  'refugees': 1,
#  'difference': 1,
#  'education': 5,
#  'pil': 1,
#  'laborshortage': 1,
#  'jobless': 1,
#  'labormarket': 1,
#  'spending': 2,
#  'priority': 1,
#  'factors': 1,
#  'executive': 1,
#  'decision': 1,
#  'product': 1,
#  'range': 1,
#  'bestfit': 1,
#  'problems': 1,
#  'management': 1,
#  'administration': 1,
#  'hospitals': 1,
#  'deltaplusvariant': 1,
#  'insacog': 1,
#  'genomic': 1,
#  'surveillance': 1,
#  'maskmandates': 1,
#  'foodtrends': 1,
#  'dominiccummings': 1,
#  '10downingstreet': 1,
#  'dominicummings': 1,
#  'failure': 1,
#  'windbag': 1,
#  'enquiry': 1,
#  'spittingimage': 1,
#  'westminster': 1,
#  'actnearn': 1,
#  'globsec2021': 4,
#  'world': 7,
#  'peugeot': 1,
#  '308sw': 1,
#  'bureaucratic': 1,
#  'overreach': 1,
#  'read': 1,
#  'creative': 2,
#  'writerslife': 1,
#  'blogging': 4,
#  'readers': 1,
#  'infected': 1,
#  'citizens': 2,
#  'guantánamobay': 1,
#  'navalbase': 1,
#  'cuba': 1,
#  'thewashingtonpost': 1,
#  'mask': 1,
#  'euro2020': 1,
#  'billygilmour': 1,
#  'benchilwell': 1,
#  'masonmount': 1,
#  'selfisolation': 1,
#  'england': 1,
#  'scotland': 2,
#  'eng': 1,
#  'scot': 1,
#  'engvind': 1,
#  'cricket': 1,
#  'movingtips': 1,
#  'publichealth': 3,
#  'socialisolation': 1,
#  'execspace': 1,
#  'execmove': 1,
#  'god': 1,
#  'comfort': 1,
#  'grace': 1,
#  'amen': 1,
#  'serve': 1,
#  'bible': 2,
#  'church': 1,
#  'prayer': 1,
#  'catholic': 1,
#  'life': 4,
#  'suicide': 1,
#  'laborlaw': 1,
#  'laborrelations': 1,
#  'hire': 1,
#  'genderequality': 3,
#  'raahtv': 1,
#  'blackfungus': 6,
#  'modi': 1,
#  'covid19india': 2,
#  'southamer': 1,
#  'covax': 1,
#  'sarscov2': 5,
#  'nominate': 1,
#  'mountain': 1,
#  'hkh': 1,
#  'prize': 1,
#  'protectthepulse': 1,
#  'pensions': 1,
#  'wealth': 1,
#  'trust': 1,
#  'unitedstates': 7,
#  'canada': 8,
#  'ban': 5,
#  'jobmarket': 1,
#  'streaming': 1,
#  'tv': 2,
#  '4k': 1,
#  'vietnamese': 1,
#  'indonesian': 1,
#  'thai': 1,
#  'burmese': 1,
#  'khmer': 1,
#  'malay': 1,
#  'filipino': 1,
#  'languagelearning': 1,
#  'alshorts': 1,
#  'shortnewsapp': 1,
#  'projectoftheyear': 1,
#  'lgbtqia': 17,
#  'drought': 1,
#  'waterstress': 1,
#  'esg': 2,
#  'activecases': 2,
#  'icu': 2,
#  'ventilator': 2,
#  'bkk': 2,
#  'clusters': 1,
#  'bangkok': 1,
#  'washyourhands': 1,
#  'keepyourdistance': 1,
#  'safeathome': 1,
#  'reforms': 1,
#  'feminism': 2,
#  'feminismiscancer': 2,
#  'traders': 1,
#  'nightmarkets': 1,
#  'mco3': 1,
#  'statistics': 1,
#  'affordablehousing': 1,
#  'britain': 1,
#  'building': 1,
#  'community': 1,
#  'economicdevelopment': 1,
#  'housing': 2,
#  'industry': 1,
#  'localgovernment': 1,
#  'ukgovernment': 2,
#  'ariananews': 1,
#  'covidー19': 1,
#  'coronaoutbreak': 1,
#  'dystopia': 1,
#  'englandsquad': 1,
#  'nhs': 1,
#  'southafrica': 3,
#  'manufacturing': 1,
#  'sharing': 1,
#  'staffspsyres': 1,
#  'research': 3,
#  'physicalactivity': 1,
#  'realestate': 2,
#  'house': 1,
#  'greatbritain': 2,
#  'medtechintegrates2021': 12,
#  'venice': 2,
#  'travelling': 2,
#  'sundayvibes': 2,
#  'response': 1,
#  'ukraine': 1,
#  'ireland': 1,
#  'portugal': 1,
#  'civilsociety': 1,
#  'healthsystems': 1,
#  'blogpost': 1,
#  'bloggerstribe': 1,
#  'blogginggals': 1,
#  'writerslift': 1,
#  'fujixt3': 1,
#  'chess': 1,
#  'speedchess': 1,
#  'gaming': 1,
#  'nightphotography': 1,
#  'expression': 1,
#  'newnormal': 1,
#  'photojournalism': 1,
#  'washingtonsquarepark': 1,
#  'fujifilm': 1,
#  'greenwichvillage': 1,
#  'westvillage': 1,
#  'citylife': 1,
#  'greaternoida': 4,
#  'verified': 4,
#  'noi': 3,
#  'lockdownextension': 1,
#  'selfemployed': 1,
#  'homelessness': 1,
#  'strongagainstcovid': 1,
#  'covidfreepakistan': 1,
#  'maskforyouandme': 1,
#  'evictionmoratorium': 1,
#  'cancelrent': 1,
#  'noida': 1,
#  'uttarpradesh': 1,
#  'covidhelp': 1,
#  'covidsecondwave': 1,
#  'covidemergencyindia': 1,
#  'covidsosindia': 1,
#  'parenting': 1,
#  'fathers': 1,
#  'fatherhood': 1,
#  'inflation': 5,
#  'indianrealestate': 1,
#  'peinvestments': 1,
#  ...}

# %% [markdown]
# ## Total Chosen Hashtags

# %%
complete_hashtags_list = ['chinaliedpeopledied', 'chinesevirus', 'fauci', 'lableaktheory', 'lableak', 'magneticpower', 'notocoronavirusvaccines', 'wuhanlab', 'ccp_is_terrorist', 'ccpbiowarfare', 'fakenewsalert', 'fbi', 'kungflu', 'plandemic', 'sideeffects', 'statemedia', 'surveillancestate', 'terrorism', 'terrorists', 'theliberalmediaistheenemy', 'vaccinesideeffects', 'covidbraindamage', 'disinformation', '5g', 'aliens', 'antivax', 'billgates', 'biologicalweapon', 'bioweapon', 'bioweapons', 'fakenews' 'capitalismisthevirus', 'ccp_is_terrorist', 'ccpliedpeopledied', 'chinamustpay', 'chinazi', 'deathsentenceforfauci', 'democratsarecorrupt', 'democratsareevil', 'fauciliedpeopledied', 'gatesfoundation', 'usaexposed', 'ccpvirus', 'hoax', 'bigpharma', 'chinaagenda', 'cyberattack', 'cybersecurity', 'cyberthreats', 'faucigate', 'communismisthevirus', 'fakenews', 'fakedemic', 'chinavirus', 'coverup', 'father_of_corona', 'fatherofcorona', 'moronavirus', 'plague', 'report_china', 'report_china_father_of_corona', 'reportchina', 'hydroxychloroquine', '5gmast', 'magnetic', 'batsoup', 'deepstate', 'covid19hoax', 'trumpvirus']

# %%
complete_hashtags_list
# Out:
# ['chinaliedpeopledied',
#  'chinesevirus',
#  'fauci',
#  'lableaktheory',
#  'lableak',
#  'magneticpower',
#  'notocoronavirusvaccines',
#  'wuhanlab',
#  'ccp_is_terrorist',
#  'ccpbiowarfare',
#  'fakenewsalert',
#  'fbi',
#  'kungflu',
#  'plandemic',
#  'sideeffects',
#  'statemedia',
#  'surveillancestate',
#  'terrorism',
#  'terrorists',
#  'theliberalmediaistheenemy',
#  'vaccinesideeffects',
#  'covidbraindamage',
#  'disinformation',
#  '5g',
#  'aliens',
#  'antivax',
#  'billgates',
#  'biologicalweapon',
#  'bioweapon',
#  'bioweapons',
#  'fakenewscapitalismisthevirus',
#  'ccp_is_terrorist',
#  'ccpliedpeopledied',
#  'chinamustpay',
#  'chinazi',
#  'deathsentenceforfauci',
#  'democratsarecorrupt',
#  'democratsareevil',
#  'fauciliedpeopledied',
#  'gatesfoundation',
#  'usaexposed',
#  'ccpvirus',
#  'hoax',
#  'bigpharma',
#  'chinaagenda',
#  'cyberattack',
#  'cybersecurity',
#  'cyberthreats',
#  'faucigate',
#  'communismisthevirus',
#  'fakenews',
#  'fakedemic',
#  'chinavirus',
#  'coverup',
#  'father_of_corona',
#  'fatherofcorona',
#  'moronavirus',
#  'plague',
#  'report_china',
#  'report_china_father_of_corona',
#  'reportchina',
#  'hydroxychloroquine',
#  '5gmast',
#  'magnetic',
#  'batsoup',
#  'deepstate',
#  'covid19hoax',
#  'trumpvirus']

# %% [markdown]
# I now want to join the following dataframes together, and make a word cloud looking at the count of the complete_hashtag_lists

# %%
coronavirus = pd.read_csv("/content/tweet_coronavirus.csv")
covid = pd.read_csv("/content/tweet_covid.csv")
covid19 = pd.read_csv("/content/tweet_covid19.csv")
pandemic = pd.read_csv("/content/tweet_pandemic.csv")
vaccine = pd.read_csv("/content/tweet_vaccine.csv")
virus = pd.read_csv("/content/tweet_virus.csv")

# %%
df1 = coronavirus.append(covid, ignore_index = True)
df2 = df1.append(covid19, ignore_index = True)
df3 = df2.append(pandemic, ignore_index = True)
df4 = df3.append(vaccine, ignore_index = True)
df = df4.append(virus, ignore_index = True)

# %%
df.shape
# Out:
# (6000, 17)

# %%
df.to_csv('covid.csv')

# %%
import ast

def conspiracy(x):
    consp_list = np.array([])

    x = ast.literal_eval(x)

    for i in x:
        if i.lower() in complete_hashtags_list:
            consp_list = np.append(consp_list, [i])
            
    print(consp_list)
    return consp_list

# %%
#create hashtag2, which only includes hashtags that are in complete_hashtags_list
df['hashtag2'] = df.hashtag.apply(conspiracy)
# Out:
# Streaming output truncated to the last 5000 lines.
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['bigpharma' 'fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BillGates']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['disinformation']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BIGPHARMA' 'FAUCI']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BillGates']
# ['BigPharma']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BigPharma']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BigPharma']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FauciLiedPeopleDied']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['TrumpVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['bioweapon']
# []
# []
# []
# ['CCPVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Disinformation']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# ['LabLeakTheory']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CyberSecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['fakenews']
# []
# []
# ['terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# ['Cybersecurity' 'Cyberattack']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['TrumpVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['TrumpVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# ['FBI' 'Terrorism']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FBI']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['wuhanlab' 'cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CyberSecurity']
# []
# []
# []
# ['CyberSecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['vaccineSideEffects']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['hydroxychloroquine']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BillGates']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# ['ChineseVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['ChinaVirus']
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BigPharma']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['vaccineSideEffects']
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# ['FakeNews']
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# ['FakeNews']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['5G']
# []
# ['fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# ['5G']
# ['5G']
# ['5G']
# []
# []
# ['5G']
# ['5G']
# ['5G']
# ['5G']
# ['5G']
# ['5G']
# ['5G']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['vaccineSideEffects']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['chinavirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['chinavirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['fauci' 'billgates']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['fauci' 'billgates']
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CyberSecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CCPVirus' 'WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cybersecurity']
# []
# ['fauci' 'billgates']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['fakenews']
# []
# []
# []
# []
# []
# []
# []
# ['CyberSecurity']
# []
# []
# []
# []
# []
# ['WuhanLab' 'ChinaLiedPeopleDied' 'chinavirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['lableak']
# ['lableak']
# []
# ['lableak']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['fauci' 'billgates']
# []
# ['fauci' 'billgates']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cyberattack']
# []
# []
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['BioWeapon']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# ['TrumpVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# ['WuhanLab']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['cybersecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['CyberSecurity']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['ChinaLiedPeopleDied']
# []
# []
# []
# []
# ['ChinaLiedPeopleDied']
# ['ChinaLiedPeopleDied']
# ['ChinaLiedPeopleDied']
# []
# []
# ['ChinaLiedPeopleDied']
# []
# []
# ['ChinaLiedPeopleDied']
# ['ChinaLiedPeopleDied']
# []
# ['ChinaLiedPeopleDied']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['ChinaLiedPeopleDied']
# ['ChinaLiedPeopleDied']
# ['ChinaLiedPeopleDied']
# []
# ['ChinaLiedPeopleDied']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['USAexposed']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# ['ChinaVirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# ['Fauci']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['plague']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['ccpvirus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Terrorists']
# ['Terrorists']
# []
# []
# []
# ['Terrorists']
# []
# ['Terrorists']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
df.head()
# Out:
#    Unnamed: 0  ... hashtag2
# 0           0  ...       []
# 1           1  ...       []
# 2           2  ...       []
# 3           3  ...       []
# 4           4  ...       []
#
# [5 rows x 17 columns]
